# %%
import pandas as pd 

program = pd.read_csv('서울 공공도서관 프로그램_all.csv')
program
# Out:
#        지역                                          제목   대상
# 0     금천구  [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내  전연령
# 1     금천구                 [독산] 8월 문화가 있는날- 김해원 깊이읽기 4  어린이
# 2     금천구              [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내  전연령
# 3     금천구                 [독산] 7월 문화가 있는날- 김해원 깊이읽기 3   성인
# 4     금천구              [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행   성인
# ...   ...                                         ...  ...
# 3131  강북구                   [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 3132  강북구                    [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 3133  강북구                    [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 3134  강북구                    [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 3135  강북구                    [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [3136 rows x 3 columns]

# %%
program['지역'].unique()
# Out:
# array(['금천구', '마포구', '광진구', '구로구', '성동구', '성북구', '동대문구', '영등포구', '중구',
#        '강서구', '양천구', '서대문구', '송파구', '강남구', '도봉구', '은평구', '용산구', '강동구',
#        '서초구', '노원구', '종로구', '동작구', '관악구', '중랑구', '강북구'], dtype=object)

# %%
geumcheon = program[program['지역']=='금천구']
mapo = program[program['지역']=='마포구']
gwangjin = program[program['지역']=='광진구']
guro = program[program['지역']=='구로구']
seongdong = program[program['지역']=='성동구']
seongbuk = program[program['지역']=='성북구']
dongdaemun = program[program['지역']=='동대문구']
yeongdeungpo = program[program['지역']=='영등포구']
jung = program[program['지역']=='중구']
gangseo = program[program['지역']=='강서구']
yangcheon = program[program['지역']=='양천구']
seodaemun = program[program['지역']=='서대문구']
songpa = program[program['지역']=='송파구']
gangnam = program[program['지역']=='강남구']
dobong = program[program['지역']=='도봉구']
eunpyeong = program[program['지역']=='은평구']
yongsan = program[program['지역']=='용산구']
gangdong = program[program['지역']=='강동구']
seocho = program[program['지역']=='서초구']
nowon = program[program['지역']=='노원구']
jongno = program[program['지역']=='종로구']
dongjak = program[program['지역']=='동작구'] 
gwanak = program[program['지역']=='관악구']
gangbuk = program[program['지역']=='강북구']

areas = [geumcheon, mapo, gwangjin, guro, seongdong, seongbuk, dongdaemun, yeongdeungpo, jung, gangseo, 
         yangcheon, seodaemun, songpa, gangnam, dobong, eunpyeong, yongsan, gangdong, seocho, nowon, 
        jongno, dongjak, gwanak, gangbuk]

# %%
program[program['지역']=='금천구']
# Out:
#      지역                                                 제목   대상
# 0   금천구         [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내  전연령
# 1   금천구                        [독산] 8월 문화가 있는날- 김해원 깊이읽기 4  어린이
# 2   금천구                     [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내  전연령
# 3   금천구                        [독산] 7월 문화가 있는날- 김해원 깊이읽기 3   성인
# 4   금천구                     [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행   성인
# 5   금천구                                 [독산] 대숲소리 북콘서트Ⅲ 안내  전연령
# 6   금천구         [독산]린드그렌이 말을 걸어 온다「이렇게 살아 보면 어때?」참여자 모집 안내   성인
# 7   금천구         [금나래] 2022 도서관 서포터즈 '나래 미디어 팩토리' 참여자 모집 안내   성인
# 8   금천구                        [독산] 6월 문화가 있는날- 김해원 깊이읽기 2  어린이
# 9   금천구                                 [독산] 대숲소리 북콘서트Ⅱ 안내  전연령
# 10  금천구                           [금나래] 가정의 달 기념 인형극 공연 안내  어린이
# 11  금천구             [독산] 길 위의 인문학 「나를 돌보는 읽기와 쓰기」참여자 모집 안내   성인
# 12  금천구                        [독산] 5월 문화가 있는날- 김해원 깊이읽기 1  어린이
# 13  금천구                                 [독산] 대숲소리 북콘서트Ⅰ 안내  전연령
# ...

# %%
geumcheon = program[program['지역']=='금천구']
mapo = program[program['지역']=='마포구']
gwangjin = program[program['지역']=='광진구']
guro = program[program['지역']=='구로구']
seongdong = program[program['지역']=='성동구']
seongbuk = program[program['지역']=='성북구']
dongdaemun = program[program['지역']=='동대문구']
yeongdeungpo = program[program['지역']=='영등포구']
jung = program[program['지역']=='중구']
gangseo = program[program['지역']=='강서구']
yangcheon = program[program['지역']=='양천구']
seodaemun = program[program['지역']=='서대문구']
songpa = program[program['지역']=='송파구']
gangnam = program[program['지역']=='강남구']
dobong = program[program['지역']=='도봉구']
eunpyeong = program[program['지역']=='은평구']
yongsan = program[program['지역']=='용산구']
gangdong = program[program['지역']=='강동구']
seocho = program[program['지역']=='서초구']
nowon = program[program['지역']=='노원구']
jongno = program[program['지역']=='종로구']
dongjak = program[program['지역']=='동작구'] 
gwanak = program[program['지역']=='관악구']
gangbuk = program[program['지역']=='강북구']

areas = [geumcheon, mapo, gwangjin, guro, seongdong, seongbuk, dongdaemun, yeongdeungpo, jung, gangseo, 
         yangcheon, seodaemun, songpa, gangnam, dobong, eunpyeong, yongsan, gangdong, seocho, nowon, 
        jongno, dongjak, gwanak, gangbuk]

# %%
gangbuk
# Out:
#        지역                               제목   대상
# 2640  강북구       할로코드로 살펴보는 인공지능 / 초등 4~6학년  어린이
# 2641  강북구      나도 할 수 있다! 일러스트레이터 / 중고생~성인  청소년
# 2642  강북구  9월 상상공작소 장비활용교육(3D프린터) / 중고생~성인  청소년
# 2643  강북구       9월 명화와 함께하는 3D펜 / 초등 4-6학년  어린이
# 2644  강북구       9월 명화와 함께하는 3D펜 / 초등 1-3학년  어린이
# ...   ...                              ...  ...
# 3131  강북구        [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 3132  강북구         [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 3133  강북구         [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 3134  강북구         [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 3135  강북구         [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [496 rows x 3 columns]

# %%
for area in areas:
    are = area.groupby('대상').count()
    print('지역:', area['지역'].unique(), '\n\n', are, '\n')
    try:
        area['중장년비율'] = are.loc['중장년'][0]/area['제목'].count()    
    except:
        pass
# Out:
# 지역: ['금천구']
#
#       지역  제목
# 대상
# 성인   12  12
# 어린이  19  19
# 전연령  10  10
# 청소년   1   1
#
# 지역: ['마포구']
#
#       지역  제목  중장년비율
# 대상
# 성인   13  13     13
# 어린이  43  43     43
# 전연령  63  63     63
# 중장년   6   6      6
# 청소년   1   1      1
#
# 지역: ['광진구']
#
#        지역   제목
# 대상
# 성인   144  144
# 어린이  170  170
# 전연령  350  350
# 청소년   24   24
#
# 지역: ['구로구']
#
#       지역  제목
# 대상
# 성인   13  13
# 어린이  14  14
# 청소년   2   2
#
# 지역: ['성동구']
#
#       지역  제목  중장년비율
# 대상
# 성인   40  40     40
# 어린이  59  59     59
# 전연령   3   3      3
# 중장년   5   5      5
# 청소년   2   2      2
#
# 지역: ['성북구']
#
#       지역  제목
# 대상
# 성인    1   1
# 어린이  32  32
# 전연령   9   9
# 청소년   2   2
#
# 지역: ['동대문구']
#
#       지역  제목  중장년비율
# 대상
# 성인    4   4      4
# 어린이   5   5      5
# 전연령   1   1      1
# 중장년   1   1      1
#
# 지역: ['영등포구']
#
#       지역  제목  중장년비율
# 대상
# 성인   19  19     19
# 어린이  28  28     28
# 전연령  47  47     47
# 중장년   1   1      1
# 청소년   4   4      4
#
# 지역: ['중구']
#
#       지역  제목
# 대상
# ...

# %%
for area in areas: 
    try:
        print(area['지역'].unique(), area['중장년비율'].unique())
    except:
        pass
# Out:
# ['마포구'] [0.04761905]
# ['성동구'] [0.04587156]
# ['동대문구'] [0.09090909]
# ['영등포구'] [0.01010101]
# ['강남구'] [0.00731707]
# ['용산구'] [0.02631579]
# ['강동구'] [0.25]
# ['노원구'] [0.00292398]
# ['강북구'] [0.01209677]

# %%
areaa = program['지역']
areaa
# Out:
# 0       금천구
# 1       금천구
# 2       금천구
# 3       금천구
# 4       금천구
#        ...
# 3131    강북구
# 3132    강북구
# 3133    강북구
# 3134    강북구
# 3135    강북구
# Name: 지역, Length: 3136, dtype: object

# %%
areaa['중장년비율']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [98], in <cell line: 1>()
# ----> 1 areaa['중장년비율']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
# ...

# %%
gangbuk
# Out:
#        지역                               제목   대상
# 2640  강북구       할로코드로 살펴보는 인공지능 / 초등 4~6학년  어린이
# 2641  강북구      나도 할 수 있다! 일러스트레이터 / 중고생~성인  청소년
# 2642  강북구  9월 상상공작소 장비활용교육(3D프린터) / 중고생~성인  청소년
# 2643  강북구       9월 명화와 함께하는 3D펜 / 초등 4-6학년  어린이
# 2644  강북구       9월 명화와 함께하는 3D펜 / 초등 1-3학년  어린이
# ...   ...                              ...  ...
# 3131  강북구        [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 3132  강북구         [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 3133  강북구         [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 3134  강북구         [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 3135  강북구         [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [496 rows x 3 columns]

# %%
are = gangbuk.groupby('대상').count()
are
# Out:
#       지역   제목
# 대상
# 성인    54   54
# 어린이  370  370
# 전연령   28   28
# 중장년    6    6
# 청소년   38   38

# %%
gangbuk['제목'].count()
# Out:
# 496

# %%
gangbuk['중장년비율'] = are.loc['중장년'][0]/gangbuk['제목'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 gangbuk['중장년비율'] = are.loc['중장년'][0]/gangbuk['제목'].sum()
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
gangbuk
# Out:
#        지역                               제목   대상     중장년비율
# 2640  강북구       할로코드로 살펴보는 인공지능 / 초등 4~6학년  어린이  0.012097
# 2641  강북구      나도 할 수 있다! 일러스트레이터 / 중고생~성인  청소년  0.012097
# 2642  강북구  9월 상상공작소 장비활용교육(3D프린터) / 중고생~성인  청소년  0.012097
# 2643  강북구       9월 명화와 함께하는 3D펜 / 초등 4-6학년  어린이  0.012097
# 2644  강북구       9월 명화와 함께하는 3D펜 / 초등 1-3학년  어린이  0.012097
# ...   ...                              ...  ...       ...
# 3131  강북구        [삼각산]2022년 겨울 독서교실(초등5학년)  어린이  0.012097
# 3132  강북구         [삼각산]2022년 겨울독서교실(초등4학년)  어린이  0.012097
# 3133  강북구         [삼각산]2022년 겨울독서교실(초등3학년)  어린이  0.012097
# 3134  강북구         [삼각산]2022년 겨울독서교실(초등2학년)  어린이  0.012097
# 3135  강북구         [삼각산]2022년 겨울독서교실(초등1학년)  어린이  0.012097
#
# [496 rows x 4 columns]
