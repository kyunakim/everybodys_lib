# %%
강동구 
강서구 
서초구
송파구
양천구
은평구
중구

# %%
import pandas as pd
kd_df = pd.DataFrame(columns = ['lib','title','target'])
kd_df
# Out:
# Empty DataFrame
# Columns: [lib, title, target]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호

for i in range(1,50): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    url = 'https://www.gdlibrary.or.kr/web/menu/10093/program/30011/lectureList.do?currentPageNo='+str(i)+'&searchCategory=&manageCd=&searchStatusCd=&lectureIdx=0'
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    kd = requests.get(url, headers = headers)
    bs = BeautifulSoup(kd.text, 'html.parser')
    
    for j in range(1,11):
        try:
            lib = bs.select_one('#contents > div.lectureWrap > ul > li:nth-child('+str(j)+') > div.title > span').text
            title = bs.select_one('#contents > div.lectureWrap > ul > li:nth-child('+str(j)+') > div.title > a').text
            target = bs.select_one('#contents > div.lectureWrap > ul > li:nth-child('+str(j)+') > div.info > span:nth-child(1)').text
            kd_df.loc[ind] = [lib, title, target]
            ind += 1
        except:
            pass


kd_df
# Out:
#     lib                                      title                    target
# 0    공통              [2022 강동북페스티벌] 이동진 김중혁의 덕후라이프               대상 : 14세이상
# 1    해공            [신중년 특화 프로그램] 9월 신중년 1:1 취업 상담              대상 : 신중년(50+)
# 2    암사                           [암사도서관 커뮤니티] 책꼬지  대상 : 그림책을 좋아하는 자녀가 있는 엄마
# 3    성내                           성내 창업성공멘토특강 [9월]                   대상 : 성인
# 4    둔촌                [모집] 힐링 독서 교실 <메타버스 북-트레일러>             대상 : 초등 4~6학년
# ..   ..                                        ...                       ...
# 485  성내             [상주작가 프로그램] 송아주작가와의 만남 (학부모대상)                  대상 : 학부모
# 486  해공         [추가모집] 한-러 수교 30주년 기념 강연 <줌 인 러시아>                 대상 : 강동구민
# 487  천호           [11월 문화가 있는 날] <집에서 Fun하게! 책놀이터>                   대상 : 유아
# 488  강일       [모집] 다문화 인식개선 프로그램 「다름을 담다」 인원 모집 안내           대상 : 초등학생 1~3학년
# 489  암사   <아트인라이브러리> AMSA Gallery -Online 앙리마티스展 -                 대상 : 강동구민
#
# [490 rows x 3 columns]

# %%
kd_df['title'].to_list()
# Out:
# ['[2022 강동북페스티벌] 이동진 김중혁의 덕후라이프',
#  '[신중년 특화 프로그램] 9월 신중년 1:1 취업 상담 ',
#  '[암사도서관 커뮤니티] 책꼬지',
#  '성내 창업성공멘토특강 [9월]',
#  '[모집] 힐링 독서 교실 <메타버스 북-트레일러>',
#  '[모집] 「엄마 심리 수업」 윤우상 작가 강연',
#  '[모집] <미물일기> 진고로호 작가 북토크 & 미물 드로잉',
#  '[9월 문화가 있는 날] 「엄마이지만, 나는 나야 (힐링 인터뷰)」',
#  "[모집] 2022년 지혜학교 특강 '도시를 디자인하다.'",
#  '[모집] 2022 북스타트 연계프로그램 <독서력 쑥쑥 오감놀이>',
#  "[문화가있는날] 사서's 책놀이 - 잠자리 만들기",
#  '[모집] 2022년 미디어교육 평생교실 「스마트폰으로 시작하는 일상기록」',
#  '[독서의달행사] 꼬물꼬물 북바인딩 : 나만의 수제노트 만들기',
#  '[독서의달행사] 실크스크린 인쇄로 RE:디자인하다',
#  '[모집] 2022 북스타트 연계프로그램 <북쿠킹 아빠랑>',
#  '[모집] 2022 북스타트 영유아 책놀이 프로그램 <책이랑 노는 날>',
#  '[모집] 2022 북스타트 부모교육 <무엇이든 물어보는 영유아기 부모교실>',
#  '[모집] 2022 북스타트 부모교육 <처음 읽는 엄마표 영어 그림책>',
#  '[모집]2022 북스타트 부모특강<아이와 부모와 책!>',
#  ' [모집] 북스타트 부모교육 특강 <그림책 어떻게 읽을까?>',
#  '[일정변경] 천호도서관 다문화 이해 전통놀이 체험 프로그램 「함께 이해하는 온마을i」',
#  ' [디지털배움터] 나도 사진 작가 되기',
#  '[디지털배움터] 구글 세계에 빠져보기 ',
#  '[독서의달] 해양환경을 지키는 바다유리공예',
#  '[추가모집] 2022 미디어교육 평생교실 「뉴스가 쏙쏙 생각이 쑥쑥 미디어 리터러시」 (초등5~6학년)',
#  "[모집] <아무튼, 피아노> '김겨울' 비대면 작가와의만남",
# ...

# %%
kd_df['target'] = kd_df['target'].str.replace('대상 :','')
kd_df
# Out:
#     lib                                          title                target
# 0    공통                  [2022 강동북페스티벌] 이동진 김중혁의 덕후라이프                14세이상
# 1    해공                [신중년 특화 프로그램] 9월 신중년 1:1 취업 상담               신중년(50+)
# 2    암사                               [암사도서관 커뮤니티] 책꼬지   그림책을 좋아하는 자녀가 있는 엄마
# 3    천호  [모집] 천호도서관 다문화 이해 전통놀이 체험 프로그램 「함께 이해하는 온마을i」           7~9세 아동 10명
# 4    해공                           [디지털배움터] 나도 사진 작가 되기              신중년(50+)
# ..   ..                                            ...                   ...
# 475  해공                          [디지털배움터] 구글 세계에 빠져보기               신중년(50+)
# 476  성내                               성내 창업성공멘토특강 [9월]                    성인
# 477  둔촌                    [모집] 힐링 독서 교실 <메타버스 북-트레일러>              초등 4~6학년
# 478  강일                      [모집] 「엄마 심리 수업」 윤우상 작가 강연                   성인
# 479  해공               [모집] <미물일기> 진고로호 작가 북토크 & 미물 드로잉             청소년이상 20명
#
# [480 rows x 3 columns]

# %%
kd_df.to_csv('kd_all.csv',encoding="utf-8-sig", index=False)

# %%
kd_df.target.unique().tolist()
# Out:
# ['대상 : 14세이상 ',
#  '대상 : 신중년(50+)',
#  '대상 : 그림책을 좋아하는 자녀가 있는 엄마',
#  '대상 : 성인',
#  '대상 : 초등 4~6학년',
#  '대상 : 성인 ',
#  '대상 : 청소년이상 20명',
#  '대상 : 영유아 양육자',
#  '대상 : 성인 50명',
#  '대상 : 12~18개월 영아와 양육자',
#  '대상 : 6~7세',
#  '대상 : 50대이상 15명',
#  '대상 : 가족 8팀',
#  '대상 : 4~6세 아동 및 아빠 7팀',
#  '대상 : 영유아 양육자 10명',
#  '대상 : 4세 이상 자녀 양육자',
#  '대상 : 양육자 40명',
#  '대상 : 7~9세 아동 10명',
#  '대상 : 초등 3-4학년',
#  '대상 : 초등학생 5~6학년',
#  '대상 : 청소년이상',
#  '대상 : 초등 3~6학년',
#  '대상 : 양육자',
#  '대상 : 초등 3 ~ 6',
#  '대상 : 초등학생 1~6학년',
#  '대상 : 초등 1-3학년',
#  '대상 : 3세 이상',
#  '대상 : 초등 1-4학년 ',
#  '대상 : 50대 성인',
#  '대상 : 6-7세 및 양육자',
#  '대상 : 가족대상 (50명)',
#  '대상 : 2030대 성인',
#  '대상 : 5세이상 어린이와 부모 1인, 총 7팀',
#  '대상 : 초등학교 저학년 이하 어린이 및 가족',
#  '대상 : 초등학생 1~2학년',
#  '대상 : 초등 3~4학년',
#  '대상 : 유‧초등 가족 5팀',
#  '대상 : 초등 2~3학년',
#  '대상 : 초등 4~5학년',
#  '대상 : 초등 3~4',
#  '대상 : 청소년 이상',
#  '대상 : 지역주민  ',
#  '대상 : 대학생 및 성인',
#  '대상 : 1, 2부 참여가족',
#  '대상 : 초등 3~5',
#  '대상 : 초등 1~6',
#  '대상 : 성인 10명 선착순',
#  '대상 : 초등학생 3~6학년',
# ...

# %%
kd = kd_df.copy()

# %%
kd.loc[kd['target'].str.contains(r" 초등 4~6학년"),'target'] = '어린이'

# %%
kd.loc[kd['target'].str.contains(r" 7~9세 아동 10명"),'target'] = '어린이'

# %%
kd.loc[kd['target'].str.contains(r" 14세이상 "),'target'] = '청소년'

# %%
kd.loc[kd['target'].str.contains(r" 성인"),'target'] = '성인'

# %%
kd.loc[kd['target'].str.contains(r" 성인 "),'target'] = '성인'

# %%
kd.loc[kd['target'].str.contains(r" 청소년이상 20명"),'target'] = '전연령'

# %%
kd.loc[kd['target'].str.contains(r" 그림책을 좋아하는 자녀가 있는 엄마"),'target'] = '성인'

# %%
kd = kd.replace(' 신중년(50+)', '중장년')

# %%
kd.target.unique().tolist()
# Out:
# ['청소년', '중장년', '성인', '어린이', '전연령']

# %%
kd.target.value_counts()
# Out:
# 중장년    144
# 성인     144
# 어린이     96
# 청소년     48
# 전연령     48
# Name: target, dtype: int64

# %%
kd.to_csv('kd_all.csv',encoding="utf-8-sig", index=False)
