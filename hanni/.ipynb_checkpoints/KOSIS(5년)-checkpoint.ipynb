# %% [markdown]
# # 도서관 이용률

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# 한글폰트 적용
import matplotlib.pyplot as plt
plt.rc("font",family="AppleGothic")

#마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus']=False

# %%
# 도서관 이용률 (성인)

import pandas as pd

df3 = pd.read_excel('../data/도서관_이용률__성인__20220915194253.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df3
# Out:
# 통계분류(2)                2013                 2015                 2017         \
# 통계분류(2)                 사례수 도서관 이용   비이용     사례수 도서관 이용   비이용     사례수 도서관 이용
# 전체           소계      2000.0   30.3  69.7  5000.0   28.2  71.8  6000.0   22.2
# 성별           남성       993.0   28.3  71.7  2478.0   26.7  73.3  2988.0   20.6
#              여성      1007.0   32.4  67.6  2522.0   29.7  70.3  3012.0   23.7
# 연령           18~29세   387.0   51.9  48.1   911.0   50.2  49.8  1070.0   42.2
#              19~29세       -      -     -       -      -     -       -      -
#              30~39세   389.0   40.5  59.5   932.0   37.9  62.1  1071.0   28.7
#              40~49세   425.0   34.1  65.9  1030.0   31.8  68.2  1218.0   23.5
#              50~59세   385.0   16.9  83.1   988.0   15.7  84.3  1190.0   13.6
#              60세 이상   414.0    9.2  90.8  1140.0   10.1  89.9  1451.0    8.4
# 학력           중졸 이하    286.0    2.0  98.0   906.0    6.9  93.1  1002.0    4.6
#              고졸, 고퇴   748.0   20.6  79.4  1904.0   22.0  78.0  2120.0   12.4
#              대재 이상    967.0   46.2  53.8  2190.0   42.3  57.7  2878.0   35.5
# 연간독서량(종이책기준) 없음       573.0    3.4  96.6  1733.0    4.4  95.6  2408.0    3.9
#              1~5권     458.0   22.0  78.0   977.0   26.8  73.2  1433.0   30.7
#              6~10권    531.0   40.6  59.4  1131.0   39.9  60.1   883.0   30.3
#              11~15권   180.0   60.4  39.6   516.0   39.2  60.8   239.0   46.1
#              16~20권    73.0   62.2  37.8   176.0   54.8  45.2   365.0   26.7
#              21권 이상   186.0   63.0  37.0   466.0   68.6  31.4   672.0   47.8
#
# 통계분류(2)                      2019                 2021
# 통계분류(2)               비이용     사례수 도서관 이용   비이용     사례수 도서관 이용   비이용
# 전체           소계      77.8  6000.0   23.9  76.1  6000.0   16.9  83.1
# 성별           남성      79.4  2990.0   20.4  79.6  2991.0   16.5  83.5
#              여성      76.3  3010.0   27.2  72.8  3009.0   17.2  82.8
# 연령           18~29세  57.8       -      -     -       -      -     -
#              19~29세     -  1057.0   46.6  53.4  1016.0   41.2  58.8
#              30~39세  71.3  1022.0   32.8  67.2   964.0   22.3  77.7
#              40~49세  76.5  1158.0   25.1  74.9  1123.0   15.9  84.1
#              50~59세  86.4  1192.0   13.5  86.5  1173.0    8.5  91.5
#              60세 이상  91.6  1571.0    9.7  90.3  1724.0    5.9  94.1
# 학력           중졸 이하   95.4   934.0    4.2  95.8   900.0    1.2  98.8
#              고졸, 고퇴  87.6  2127.0   11.7  88.3  2136.0    7.8  92.2
#              대재 이상   64.5  2939.0   38.9  61.1  2964.0   28.2  71.8
# 연간독서량(종이책기준) 없음      96.1  2872.0    4.4  95.6  3557.0    3.0  97.0
#              1~5권    69.3  1701.0   30.8  69.2  1628.0   30.0  70.0
#              6~10권   69.7   636.0   50.3  49.7   524.0   49.9  50.1
#              11~15권  53.9   233.0   57.2  42.8   147.0   54.9  45.1
#              16~20권  73.3   207.0   55.4  44.6    68.0   50.3  49.7
#              21권 이상  52.2   350.0   60.9  39.1    76.0   53.9  46.1

# %%
df3_total=df3.loc[['전체']]
df3_total
# Out:
# 통계분류(2)    2013                 2015                 2017               \
# 통계분류(2)     사례수 도서관 이용   비이용     사례수 도서관 이용   비이용     사례수 도서관 이용   비이용
# 전체 소계    2000.0   30.3  69.7  5000.0   28.2  71.8  6000.0   22.2  77.8
#
# 통계분류(2)    2019                 2021
# 통계분류(2)     사례수 도서관 이용   비이용     사례수 도서관 이용   비이용
# 전체 소계    6000.0   23.9  76.1  6000.0   16.9  83.1

# %%
total3=pd.DataFrame({'2013':['30.3','69.7'],
'2015':['28.2','71.8'],
    '2017':['22.2','77.8'],
    '2019':['23.9','76.1'],
                      '2021':['16.9','83.1']},
                    index=['도서관 이용','비이용'])
total3
# Out:
#         2013  2015  2017  2019  2021
# 도서관 이용  30.3  28.2  22.2  23.9  16.9
# 비이용     69.7  71.8  77.8  76.1  83.1

# %%
total3 = total3.apply(pd.to_numeric)

# %%
total3.plot(kind='bar', color=['pink','green','skyblue','orange','violet'], figsize=(10,5), alpha=0.5)
plt.title("도서관 이용률",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '도서관 이용'), Text(1, 0, '비이용')])

# %% [markdown]
# # 도서관 이용 목적

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# 도서관 이용 목적 (성인)

import pandas as pd

df1 = pd.read_excel('../data/도서관_이용_목적__성인__5년.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df1
# Out:
# 통계분류(2)               2013                                               \
# 통계분류(2)                사례수 독서, 도서 대출 공부,학습 자료 조사 도서관의 행사, 프로그램 참가   기 타
# 전체           소계      607.0      59.9  28.9   7.7              1.8   1.7
# 성별           남성      281.0      51.3  35.7  11.2              1.0   0.8
#              여성      326.0      67.3  23.0   4.8              2.5   2.5
# 연령별          18~29세  201.0      35.2  55.4   8.2              0.8   0.4
#              19~29세      -         -     -     -                -     -
#              30~39세  158.0      68.7  22.1   7.5              0.0   1.7
#              40~49세  145.0      74.3  12.1   8.6              2.2   2.7
#              50~59세   65.0      74.6  13.8   5.1              6.5   0.0
#              60세 이상   38.0      73.2   6.4   7.5              5.3   7.6
# 학력별          중졸 이하     6.0      52.4   7.0   0.0              7.0  33.6
#              고졸/고퇴   154.0      74.9  13.6   6.8              1.3   3.4
#              대재이상    447.0      54.8  34.4   8.2              1.9   0.7
# 연간독서량(종이책기준) 없음       19.0      38.3  49.6  12.1              0.0   0.0
#              1~5권    101.0      48.4  32.8  11.5              4.7   2.6
#              6~10권   215.0      56.6  33.0   7.7              1.6   1.1
#              11~15권  109.0      59.5  33.3   4.9              0.8   1.4
#              16~20권   45.0      70.0  20.3   5.7              0.0   4.0
#              21권 이상  117.0      75.6  13.8   7.3              1.6   1.6
#
# 통계분류(2)                2015                                   ...      2019  \
# 통계분류(2)                 사례수 독서, 도서 대출 자료 조사 도서관의 행사, 프로그램 참가  ... 독서, 도서 대출
# 전체           소계      1409.0      62.5   8.6              2.9  ...      59.8
# 성별           남성       661.0      56.5  10.3              3.0  ...      49.7
#              여성       748.0      67.7   7.0              2.8  ...      67.3
# 연령별          18~29세   457.0      42.8  11.1              1.3  ...         -
#              19~29세       -         -     -                -  ...      31.5
#              30~39세   353.0      68.8   6.4              4.4  ...      74.7
#              40~49세   328.0      71.8   8.5              3.4  ...      75.7
#              50~59세   155.0      73.3  10.2              3.0  ...      69.4
#              60세 이상   115.0      80.3   3.3              2.8  ...      77.7
# 학력별          중졸 이하     63.0      82.0   2.7              6.5  ...      65.5
#              고졸/고퇴    419.0      70.6   7.1              2.7  ...      74.5
#              대재이상     927.0      57.5   9.7              2.7  ...      56.4
# 연간독서량(종이책기준) 없음        77.0      37.1  11.7              4.9  ...      36.6
#              1~5권     262.0      63.9   9.1              3.9  ...      51.5
#              6~10권    451.0      62.7   5.3              3.1  ...      64.0
#              11~15권   202.0      62.9  13.2              1.5  ...      69.3
#              16~20권    96.0      71.9   6.6              2.3  ...      67.4
#              21권 이상   320.0      64.1   9.7              2.2  ...      77.3
#
# 통계분류(2)                                             2021                  \
# 통계분류(2)             공부,학습 자료 조사 도서관의 행사, 프로그램 참가     사례수 독서, 도서 대출 공부,학습
# 전체           소계      25.1  11.8              2.0  1013.0      63.3  24.8
# 성별           남성      30.1  18.2              1.5   494.0      57.4  27.7
#              여성      21.4   7.0              2.3   519.0      69.0  22.1
# 연령별          18~29세     -     -                -       -         -     -
#              19~29세  53.8  13.3              1.4   419.0      33.6  52.6
#              30~39세  12.2  10.5              1.0   215.0      79.2   9.7
#              40~49세   8.7  11.2              2.6   179.0      86.5   2.7
#              50~59세   8.9  17.7              2.6   100.0      83.9   2.1
#              60세 이상   9.6   4.6              4.0   101.0      91.6   3.6
# 학력별          중졸 이하   10.6   8.7              0.0    11.0      92.3   0.0
#              고졸/고퇴   11.0  10.9              3.3   166.0      83.2   7.4
#              대재이상    28.7  12.1              1.8   836.0      59.0  28.6
# 연간독서량(종이책기준) 없음      39.2  16.9              0.7   108.0      16.9  55.0
#              1~5권    29.2  15.5              3.3   487.0      61.3  26.2
#              6~10권   24.7   8.9              0.9   262.0      76.6  16.9
#              11~15권  20.7   7.0              3.0    81.0      75.9  19.2
#              16~20권  14.6  15.0              2.1    34.0      87.0   4.8
#              21권 이상  16.0   5.4              0.3    41.0      80.9   7.3
#
# 통계분류(2)
# 통계분류(2)             자료 조사 전자자료 이용 도서관의 행사, 프로그램 참가
# 전체           소계       9.0     2.5              0.2
# 성별           남성      11.5     3.0              0.0
#              여성       6.6     2.1              0.3
# 연령별          18~29세     -       -                -
#              19~29세  11.8     2.0              0.0
#              30~39세   8.6     2.1              0.3
#              40~49세   5.9     3.9              0.0
#              50~59세  10.5     3.5              0.0
#              60세 이상   1.9     1.9              0.7
# 학력별          중졸 이하    5.5     0.0              2.2
#              고졸/고퇴    5.8     3.2              0.3
#              대재이상     9.6     2.4              0.1
# 연간독서량(종이책기준) 없음      14.5    11.3              0.7
#              1~5권    10.8     1.5              0.2
#              6~10권    4.9     1.5              0.0
#              11~15권   4.9     0.0              0.0
#              16~20권   5.2     3.0              0.0
#              21권 이상   9.4     2.4              0.0
#
# [18 rows x 29 columns]

# %%
df1.index
# Out:
# MultiIndex([(          '전체',     '소계'),
#             (          '성별',     '남성'),
#             (          '성별',     '여성'),
#             (         '연령별', '18~29세'),
#             (         '연령별', '19~29세'),
#             (         '연령별', '30~39세'),
#             (         '연령별', '40~49세'),
#             (         '연령별', '50~59세'),
#             (         '연령별', '60세 이상'),
#             (         '학력별',  '중졸 이하'),
#             (         '학력별',  '고졸/고퇴'),
#             (         '학력별',   '대재이상'),
#             ('연간독서량(종이책기준)',     '없음'),
#             ('연간독서량(종이책기준)',   '1~5권'),
#             ('연간독서량(종이책기준)',  '6~10권'),
#             ('연간독서량(종이책기준)', '11~15권'),
#             ('연간독서량(종이책기준)', '16~20권'),
#             ('연간독서량(종이책기준)', '21권 이상')],
#            )

# %%
df1.columns
# Out:
# MultiIndex([('2013',              '사례수'),
#             ('2013',        '독서, 도서 대출'),
#             ('2013',            '공부,학습'),
#             ('2013',            '자료 조사'),
#             ('2013', '도서관의 행사, 프로그램 참가'),
#             ('2013',              '기 타'),
#             ('2015',              '사례수'),
#             ('2015',        '독서, 도서 대출'),
#             ('2015',            '자료 조사'),
#             ('2015', '도서관의 행사, 프로그램 참가'),
#             ('2015',     '시험 공부를 하기 위해'),
#             ('2015',              '기 타'),
#             ('2017',              '사례수'),
#             ('2017',        '독서, 도서 대출'),
#             ('2017',            '자료 조사'),
#             ('2017', '도서관의 행사, 프로그램 참가'),
#             ('2017',     '시험 공부를 하기 위해'),
#             ('2017',              '기 타'),
#             ('2019',              '사례수'),
#             ('2019',        '독서, 도서 대출'),
#             ('2019',            '공부,학습'),
#             ('2019',            '자료 조사'),
#             ('2019', '도서관의 행사, 프로그램 참가'),
#             ('2021',              '사례수'),
#             ('2021',        '독서, 도서 대출'),
#             ('2021',            '공부,학습'),
#             ('2021',            '자료 조사'),
#             ('2021',          '전자자료 이용'),
#             ('2021', '도서관의 행사, 프로그램 참가')],
#            names=['통계분류(2)', '통계분류(2)'])

# %%
df1_total=df1.loc[['전체']]
df1_total
# Out:
# 통계분류(2)   2013                                                2015            \
# 통계분류(2)    사례수 독서, 도서 대출 공부,학습 자료 조사 도서관의 행사, 프로그램 참가  기 타     사례수 독서, 도서 대출
# 전체 소계    607.0      59.9  28.9   7.7              1.8  1.7  1409.0      62.5
#
# 통계분류(2)                         ...      2019                               \
# 통계분류(2) 자료 조사 도서관의 행사, 프로그램 참가  ... 독서, 도서 대출 공부,학습 자료 조사 도서관의 행사, 프로그램 참가
# 전체 소계     8.6              2.9  ...      59.8  25.1  11.8              2.0
#
# 통계분류(2)    2021
# 통계분류(2)     사례수 독서, 도서 대출 공부,학습 자료 조사 전자자료 이용 도서관의 행사, 프로그램 참가
# 전체 소계    1013.0      63.3  24.8   9.0     2.5              0.2
#
# [1 rows x 29 columns]

# %%
df1_total['2021']
# Out:
# 통계분류(2)     사례수 독서, 도서 대출 공부,학습 자료 조사 전자자료 이용 도서관의 행사, 프로그램 참가
# 전체 소계    1013.0      63.3  24.8   9.0     2.5              0.2

# %%
total=pd.DataFrame({
    '2013':['59.9','28.9','7.7','1.7','0','1.8'],
    '2015':['62.5','23.1','8.6','2.9','0','2.9'],
    '2017':['62.6','23.5','9.3','1.3','0','3.3'],
    '2019':['59.8','25.1','11.8','0','0','2.0'],
                      '2021':['63.3','24.8','9.0','0','2.5','0.2']},
                    index=['독서, 도서 대출','공부,학습','자료 조사','기타','전자자료 이용','도서관의 행사, 프로그램 참가'])
total
# Out:
#                   2013  2015  2017  2019  2021
# 독서, 도서 대출         59.9  62.5  62.6  59.8  63.3
# 공부,학습             28.9  23.1  23.5  25.1  24.8
# 자료 조사              7.7   8.6   9.3  11.8   9.0
# 기타                 1.7   2.9   1.3     0     0
# 전자자료 이용              0     0     0     0   2.5
# 도서관의 행사, 프로그램 참가   1.8   2.9   3.3   2.0   0.2

# %%
total = total.apply(pd.to_numeric)

# %%
total.plot(kind='bar', color=['pink','green','skyblue','orange','violet'], figsize=(10,5), alpha=0.5)
plt.title("도서관 이용 목적",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '독서, 도서 대출'),
#   Text(1, 0, '공부,학습'),
#   Text(2, 0, '자료 조사'),
#   Text(3, 0, '기타'),
#   Text(4, 0, '전자자료 이용'),
#   Text(5, 0, '도서관의 행사, 프로그램 참가')])

# %%
total10=pd.DataFrame({'2013':'1.8',
'2015':'2.9',
    '2017':'3.3',
    '2019':'2.0',
                      '2021':'0.2'},
                    index=['도서관의 행사, 프로그램 참가'])
total10
# Out:
#                  2013 2015 2017 2019 2021
# 도서관의 행사, 프로그램 참가  1.8  2.9  3.3  2.0  0.2

# %%
total10 = total10.apply(pd.to_numeric)

# %%
total10.plot(kind='bar', color=['pink','green','skyblue','orange','violet'], figsize=(10,5), alpha=0.5)
plt.title('도서관의 행사, 프로그램 참가',fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0]), [Text(0, 0, '도서관의 행사, 프로그램 참가')])
