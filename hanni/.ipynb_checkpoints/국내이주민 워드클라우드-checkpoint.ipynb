# Out:
# array(['책과 함께 만나는 다문화세상',
#        "[다문화서비스지원사업] [초등1~2]9.5'나는 인도에서 왔어요' 임서경작가와의 만남",
#        "[다문화서비스지원사업] [초등3~4]9.4'우리동네 마릴리 아줌마' 함영연작가와의 만남",
#        '[다문화서비스지원사업] [초등1~2]세계시민교육 참여자 모집', '다문화랑 놀자',
#        '[다문화서비스 지원 공모사업] 다(多)문화랑 놀자', '[다문화] 다문화 올림픽', '[다문화] 다문화 인문학',
#        '엄마와 내가 함께 만드는 성장동화', '[다문화이해교육] 다르지만 같은 우리 1기',
#        '[다문화이해교육] 다르지만 같은 우리 2기', '도서관에 ON 다문화',
#        '[삼괴도서관]독서의 달- 다문화 선생님과 떠나는 세계여행', '다문화어울림',
#        '(친구야 같이 놀자!) 이야기가 있는 한국전통놀이', '한달에 한번! (한국의 미美) 전통공예교실',
#        '번역하며 배우는 한국어 교실', '김포건강가정다문화가족지원센터와 함께하는 문화다양성 이해교육 <우리는 세계 건축가>',
#        '포스트 코로나 다문화 예비학부모를 위한 행복한 초등학교 생활 이야기',
#        '포스트 코로나 다문화 예비학부모를 위한 행복한 초등학교 생활 이야기(后新冠时代为多文化家庭的小学新生家长准备的过好幸福的小学生活的演讲)',
#        '혼자보다 우리가 더 힘이 세다! 「다문화 백과사전」 채인선 작가 강연',
#        '다문화 인식개선 인형극 <알리단과 요술램프>', '송린이음터도서관 다문화프로그램 초등C',
#        '송린이음터도서관 다문화프로그램 초등B', '송린이음터도서관 다문화프로그램 초등A', '내가 만드는 우리가족 앨범',
#        '[2차시:사우디아라비아]책이랑 세계여행', '[8차시:멕시코]책이랑 세계여행', '[7차시:칠레]책이랑 세계여행',
#        '[1차시] 책이랑 세계여행', '[5차시:스페인]책이랑 세계여행', '[4차:체코]책이랑 세계여행',
#        '[3차시:남아프리카공화국] 책이랑 세계여행', '[6차시:몽골]책이랑 세계여행'], dtype=object)

# %%
import re
target = df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
pd.set_option('display.max_row', 115)

# %%
'다문화','여행','초등','서비스','지원','사업','우리','도서관','프로그램','이음'

# %%
df
# Out:
#           cnt
# 다문화        25
# 세계         13
# 여행         10
# 초등          7
# 서비스         5
# 지원          5
# 사업          5
# 교육          5
# 우리          5
# 도서관         4
# 작가          3
# 이해          3
# 이야기         3
# 송린          3
# 이음          3
# 프로그램        3
# 만남          2
# 시민          2
# 참여자         2
# 모집          2
# 문화          2
# 괴도          2
# 서관          2
# 독서          2
# 선생님         2
# 한국          2
# 전통          2
# 교실          2
# 가족          2
# 포스트         2
# 코로나         2
# 예비          2
# 학부모         2
# 초등학교        2
# 생활          2
# 세상          1
# 인도          1
# 임서          1
# 우리동네        1
# 마릴리         1
# 아줌마         1
# 공모          1
# 올림픽         1
# 인문학         1
# 엄마          1
# 성장          1
# 동화          1
# 어울림         1
# 친구          1
# 한번          1
# 공예          1
# 번역          1
# 한국어         1
# 김포          1
# 건강          1
# 가정          1
# 센터          1
# 다양성         1
# 건축가         1
# 혼자          1
# 백과사전        1
# 인선          1
# 강연          1
# 인식          1
# 개선          1
# 인형극         1
# 알리          1
# 요술          1
# 램프          1
# 앨범          1
# 사우디아라비아     1
# 멕시코         1
# 칠레          1
# 스페인         1
# 체코          1
# 남아프리카공화국    1
# 몽골          1

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = ['다문화','여행','초등','서비스','지원','사업','우리','도서관','프로그램','이음','이야기','송린','참여자','모집','시민','괴도','선생님','교실','예비']

for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

df
# Out:
#           cnt
# 세계         13
# 교육          5
# 작가          3
# 이해          3
# 만남          2
# 문화          2
# 서관          2
# 독서          2
# 한국          2
# 전통          2
# 가족          2
# 포스트         2
# 코로나         2
# 학부모         2
# 초등학교        2
# 생활          2
# 세상          1
# 인도          1
# 임서          1
# 우리동네        1
# 마릴리         1
# 아줌마         1
# 공모          1
# 올림픽         1
# 인문학         1
# 엄마          1
# 성장          1
# 동화          1
# 어울림         1
# 친구          1
# 한번          1
# 공예          1
# 번역          1
# 한국어         1
# 김포          1
# 건강          1
# 가정          1
# 센터          1
# 다양성         1
# 건축가         1
# 혼자          1
# 백과사전        1
# 인선          1
# 강연          1
# 인식          1
# 개선          1
# 인형극         1
# 알리          1
# 요술          1
# 램프          1
# 앨범          1
# 사우디아라비아     1
# 멕시코         1
# 칠레          1
# 스페인         1
# 체코          1
# 남아프리카공화국    1
# 몽골          1

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='AppleGothic')# 한글 폰트 설정

# %%
from wordcloud import WordCloud

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 4000, 
                      height = 3000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=100).generate_from_frequencies(data)
plt.figure(figsize = (11, 11))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 3999.5, 2999.5, -0.5)
