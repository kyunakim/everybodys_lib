# %%
강동구 ok 
강서구 ing
서초구
송파구 ok
양천구
은평구
중구 ok

# %%
import pandas as pd
j_df = pd.DataFrame(columns = ['lib','title','target'])
j_df
# Out:
# Empty DataFrame
# Columns: [lib, title, target]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호

for i in range(1,24): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    url = 'https://www.junggulib.or.kr/SJGL/program/lectureList.do'
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    j = requests.get(url, headers = headers)
    bs = BeautifulSoup(j.text, 'html.parser')
    
    for j in range(1,13):
        try:
            lib = bs.select_one('#contentcore > div.contentArea > div.boardWrap.culture > ul > li:nth-child('+str(j)+') > p').text
            title = bs.select_one('#contentcore > div.contentArea > div.boardWrap.culture > ul > li:nth-child('+str(j)+') > a.tit').text
            target = bs.select_one('#contentcore > div.contentArea > div.boardWrap.culture > ul > li:nth-child('+str(j)+') > div > p.state > i:nth-child(2)').text
            j_df.loc[ind] = [lib, title, target]
            ind += 1
        except:
            pass


j_df
# Out:
#          lib                                title  \
# 0       신당누리  디지털 드로잉 프로그램 <내 손으로 만드는 신당누리도서관 굿즈>
# 1         가온                     취중JOB답:채용트렌드(1차)
# 2     손기정어린이                             나도 북큐레이터
# 3         가온                      취중JOB답:면접준비(3차)
# 4         가온                    취중JOB답:자소서작성법(2차)
# ..       ...                                  ...
# 271       가온              9월 「문학산책 : 경혜원 작가와의 대화」
# 272    손기정문화       9월 토요예술무대 <힐링콘서트 : 그렇게 시작하는거야>
# 273       가온  그림책과 함께하는 가온공방 <10월 컬러 클레이로 만드는 접시>
# 274  남산타운어린이                         [가족독서클럽2기모집]
# 275     신당누리     (대기접수중)한재권 음악감독과 함께하는 영화 속 음악이야기
#
#                                                 target
# 0    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 1    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 2    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 3    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 4    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# ..                                                 ...
# 271  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 272  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 273  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 274  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
# 275  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...
#
# [276 rows x 3 columns]

# %%
j = j_df.copy()

# %%
j['target'] = j['target'].str.replace('\t','')
j['target'] = j['target'].str.replace('\n','')
j['target'] = j['target'].str.replace('\r','')
j
# Out:
#          lib                                title   target
# 0       신당누리  디지털 드로잉 프로그램 <내 손으로 만드는 신당누리도서관 굿즈>      청소년
# 1         가온                     취중JOB답:채용트렌드(1차)       성인
# 2     손기정어린이                             나도 북큐레이터      어린이
# 3         가온                      취중JOB답:면접준비(3차)       성인
# 4         가온                    취중JOB답:자소서작성법(2차)       성인
# ..       ...                                  ...      ...
# 271       가온              9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 272    손기정문화       9월 토요예술무대 <힐링콘서트 : 그렇게 시작하는거야>      누구나
# 273       가온  그림책과 함께하는 가온공방 <10월 컬러 클레이로 만드는 접시>       성인
# 274  남산타운어린이                         [가족독서클럽2기모집]      어린이
# 275     신당누리     (대기접수중)한재권 음악감독과 함께하는 영화 속 음악이야기      누구나
#
# [276 rows x 3 columns]

# %%
j.target.unique().tolist()
# Out:
# ['청소년', '성인', '어린이', '어린이,누구나', '누구나']

# %%
j.loc[j['target']=='어린이,누구나']
# Out:
#     lib                    title   target
# 7    가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 19   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 31   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 43   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 55   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 67   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 79   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 91   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 103  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 115  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 127  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 139  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 151  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 163  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 175  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 187  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 199  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 211  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 223  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 235  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 247  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 259  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 271  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나

# %%
j = j.replace('어린이,누구나', '전연령')

# %%
j = j.replace('누구나', '전연령')

# %%
j.target.value_counts()
# Out:
# 성인     115
# 어린이     69
# 전연령     69
# 청소년     23
# Name: target, dtype: int64

# %%
j.to_csv('j_all.csv',encoding="utf-8-sig", index=False)
