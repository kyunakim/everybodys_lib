# %% [markdown]
# # 노인 교육

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global news_df
    
    keyword = input('검색 키워드를 입력해주세요 ')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('추출할 뉴스기사의 숫자를 입력해주세요 '))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser') ##html_doc 데이터를 html.parser로 파싱한 뒤 BeautifulSoup 객체를 생성해서 bs 변수에 넣음 
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text.get('href')
            # news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

News()
# Out:
# 검색 키워드를 입력해주세요  시니어 교육
# 추출할 뉴스기사의 숫자를 입력해주세요  1000
#                                           title  \
# 0         동서대 시니어운동처방학과-바모스승마클럽, 재활승마지도자 양성에 박차
# 1        동서대 ‘에버그린 에이전시’ 시니어 배우, 비타500 TV 광고 출연
# 2                   국립부여박물관, 액티브 시니어 위한 프로그램 운영
# 3             영덕군, '시니어 통합 지원사' 교육 수료자 취업박람회 개최
# 4               [액티브 시니어] "단지 곳곳 안내판… 치매예방 도와요"
# ..                                          ...
# 995                    금감원, 제10기 대학생 금융교육봉사단 모집
# 996                    금감원, 대학생 금융교육봉사단 150명 모집
# 997  성남시니어산업혁신센터-한국에자이-나우- 한국리빙랩네트워크, 시니어리빙랩...
# 998                전남교육청-한국시니어클럽 전남지회 학교환경관리 협약
# 999           국토안전관리원, ‘시니어 국민생활시설점검원’ 전국 사업 시작
#
#                                                    url
# 0    https://www.asiatoday.co.kr/view.php?key=20220...
# 1    http://news.heraldcorp.com/view.php?ud=2022092...
# 2    http://www.edaily.co.kr/news/newspath.asp?news...
# 3    https://www.jeonmae.co.kr/news/articleView.htm...
# 4    https://www.viva100.com/main/view.php?key=2022...
# ..                                                 ...
# 995  http://www.babytimes.co.kr/news/articleView.ht...
# 996                http://www.inews24.com/view/1482646
# 997  http://www.kihoilbo.co.kr/news/articleView.htm...
# 998                    http://www.breaknews.com/854313
# 999  https://www.cnbnews.com/news/article.html?no=5...
#
# [1000 rows x 2 columns]

# %%
noin = news_df.copy()

# %%
import re
target = noin['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체
#text

# %%
noin['title'].unique()
# Out:
# array(['동서대 시니어운동처방학과-바모스승마클럽, 재활승마지도자 양성에 박차',
#        '동서대 ‘에버그린 에이전시’ 시니어 배우, 비타500 TV 광고 출연',
#        '국립부여박물관, 액티브 시니어 위한 프로그램 운영', "영덕군, '시니어 통합 지원사' 교육 수료자 취업박람회 개최",
#        '[액티브 시니어] "단지 곳곳 안내판… 치매예방 도와요"', '대전서부소방서, 중구시니어클럽 소방안전교육',
#        '"디지털금융 쉽게 알려드려요"…서울 어르신 대상 교육', '계룡시니어클럽, 27일 노인일자리 미니박람회 개최',
#        '[제16회 대한금융 포럼] 시늉뿐인 시니어 금융 우대', "대교, 엠쓰리솔루션과 '디지털 시니어 인지 케어' 협력",
#        "'5명중 1명꼴' 시니어 세상 온다…전방위로 확산하는 실버산업 [긱스]",
#        "창원대 BK21 뉴시니어 사업단 주최 첫 전시회 '호응'",
#        '"돈 뽑을 때는 이렇게 하세요"…BNK경남은행 시니어 자동화기기 교육',
#        '시니어와 장애인 골퍼를 위한 골프대회, 서울 PGTA 클래식 성료', '대구 액티브시니어박람회 내달 22일 개최',
#        '완주시니어클럽 명절 판매 수익금, 나눔',
#        "국립부여박물관, 노인의 날 기념 '액티브 시니어, 인생을 축제처럼 즐기다' 교...",
#        '청주 강내농협, 시니어아카데미 효도 나들이', "[B tv 대구뉴스]'소통과 휴식의 공간' 남구시니어행복센터 개소",
#        "창원대 BK21 뉴시니어 사업단, 첫 전시회 관람객 '호응'",
#        '청주 강내농협, 시니어아카데미 효도 나들이 ‘신바람’', '청주 강내농협, 시니어아카데미 효도 나들이 ‘눈길’',
#        "'시니어 스마트 데이', 마을 단위에서 이뤄지는 전국적 스마트폰 교육 캠페인",
#        '전주시, 시니어 금융복지상담가 양성', '[액티브 시니어] 스마트뱅킹·키오스크 은행업무 함께 배워요',
#        'BNK경남은행, ‘자동화기기(ATM) 거래 금융교육’ 지원',
#        "[액티브 시니어] 서초구, 코로나 우울 극복 '어르신 힐링 프로그램'",
#        '계양 계산노인문화센터-청운대학교 시니어 드론 교육 활성화 업무협약',
#        '대구액티브시니어박람회 10월22일 개막…웰에이징 실현',
#        '상생나무 ‘브라보 시니어 디지털 마을 행복학교’ 2기 운영 시작',
#        '서울도서관, 어르신 대상 모바일뱅킹 금융사기 예방 등 디지털 금융교육 운영',
#        "MKYU×당근마켓, '찾아가는 당근 사장님 학교' 프로젝트 실시…디지털 마케팅...",
#        '[액티브 시니어] 성동구 경로당 어르신은 치매걱정 뚝!', '전주시, 퇴직 은행원 ‘시니어 금융복지 상담가’로 양성',
#        '일산 가원시니어도서관, 개관 1주년 기념식 개최', '국가교육위원회를 아십니까[우보세]',
#        "[유나콘Q의 칼럼] 코로나19 위기를 기회로 '시니어 라이브커머스 힐링공작소'...",
#        '원주한지테마파크, 신노년을 위한 한지 문화교육 시행', "한전KPS, 어르신 디지털교육 공간 '노노케어 설치' 후원",
#        '대치도서관, "시니어 스마트폰 활용 교육" 2차시 참여자 모집',
#        '안동시치매안심센터, 안동시니어 클럽 치매극복 선도단체 지정',
#        '창원대 BK21 뉴시니어 사업단, 14~18일 첫 전시회', '청운대, 미추홀노인복지관과 시니어 교육 협약',
#        '‘대구 액티브시니어박람회’ 10월 22~25일 엑스코서 개최',
#        '카뱅모임통장 14%가 50대…핀테크에 눈뜬 뉴시니어',
#        "한국동서발전, 함월노인복지관에 '시니어 스마트센터' 3호점 개점",
#        '2022 서울 PGTA 클래식 20일 성료 "장애인·시니어들의 소통과 기회의장으로"',
#        "[GJ포토] 시니어 모델 김고실, '탑포즈의 정석'", '의정부시, 시니어 맞춤형 직업교육 실시',
#        '중앙대 능력개발 시니어모델·성우되는법 수강생 모집', '언론진흥재단, 시니어프로그램 교육생 미디어 교육',
#        'BNK경남은행, 시니어 고객 혜택 강화…"ATM 현금인출 수수료 면제"',
#        "성남시 '5060 신중년' 인생·은퇴 설계...평생교육 강좌 마련",
#        '10월 8일 폴포츠 콘서트에 40명의 탑 시니어 모델 군단 출격',
#        '대전교육청, 세계주니어수영선수권 메달리스트 양하정 선수 장학금 전달', '거제시니어클럽, 사업 참여 노인 대상 교육',
#        '안용모 교수 “떠날자유! 머무를 용기! 나만의 여행방법” 시니어아카데미특강',
#        '부산연제시니어클럽, 바리스타 교육 등 사회활동지원사업 수료',
#        "제주 영어교육도시 인근 테라스하우스 '한일 베라체 인비디아' 공급",
#        '[액티브 시니어] "어르신, 강남서 VR·AR 체험하세요"',
#        '백석대 “융복합 교육으로 미래 경쟁력 높이고 지역사회 기여”',
#        '명절 취직 스트레스 60대도 마찬가지, IT 시니어 프로그램에 주목하는 이유',
#        '국내 유일 액티브시니어 박람회, 오는 10월 대구 엑스코 개최',
#        '세계 예술교육실천가들 모였다…ITAC6 한국·노르웨이 성료',
#        '[액티브 시니어] "토요일 힐링숲 걸으며 스트레스 날려요"',
#        "'오세훈표 교육플랫폼' 서울런, 진화한다…2.0버전 추진",
#        '[보은소식] 시니어건강장수대학, 개강 9→10월로 연기 등',
#        '한국시니어연구소-서남돌봄종사자센터, 돌봄 종사자 지원 맞손', '대구가톨릭대, 월드시니어모델 아카데미 개강',
#        '김열경 대한노인회 경기 수원시영통구지회장 "경로당 회장이 바로 서야 경로당...',
#        '바이엘, 방문요양 ‘브라보 시니어케어’ 출시', '한국교통안전공단, 고령자 맞춤 교통안전교육',
#        '제6회 국제예술교육실천가대회, 온라인·현장 컨퍼런스 성료',
#        '한일건설, 제주 영어교육도시 인근 ‘한일 베라체 인비디아’ 분양 중',
#        'JKL클래스아카데미,액티브시니어 쇼핑호스트 1기 성황리 종료',
#        "제주영어교육도시 수요 증가…'한일 베라체 인비디아' 분양 중",
#        '창원대 BK21 뉴시니어 스마트라이프 혁신인재양성 사업단 첫 전시회.. 9월13~...',
#        '온·오프라인에서 만나는 ‘시니어 문화 한마당’',
#        '대전교육청, 세계주니어선수권수영대회 메달 획득 양하정 선수 장학금 전달',
#        '퇴직 후 건강한 시니어로! ... 포항시, 인생2막 농촌생활 위한 교육 실시',
#        "고양 대화도서관, 미디어 리터러시 교육 '시니어를 위한 팩트체크' 운영",
#        "대구가톨릭대, '월드시니어모델 아카데미' 개강", '보은시니어건강장수대학 하반기개강 10월 연기',
#        '서초구 유휴 공간 시니어 바리스타 위한 늘봄 카페로 재탄생', '청주상당경찰서, 찾아가는 어르신 교통안전교육 실시',
#        '“연극계도 시니어 모델 분야처럼 스타 탄생해야”', '서울시립중랑노인종합복지관, 시니어 스마트폰 활용 교육',
#        '[김태우의 ‘시니어 라이프 플러스’]나의 카타미, 아버지의 낡은 비망록',
#        '인천시 동구, 민·관·학 협력 ‘시니어 정보화 건강 드론 교육’ 수료식 개최',
#        '한전KPS, 어르신 디지털 친화 교육체험 공간 설치 후원',
#        '창원소방본부, 화재취약계층 대상 맞춤형 소방안전교육 실시', "바이엘, 방문요양 서비스 '브라보 시니어케어' 출시",
#        '송파 무대광풍 연기학원, 시니어 대상 연기 레슨 과정 신설',
#        "광양실버주택복지관·광양중앙도서관, '독서의 맛, 노년의 멋 시니어 스타트'...",
#        '좋은케어, 유니메오 프리미엄 간병보호사 4차 정기교육 실시',
#        '"이것이 ESG 표본이다"…KB 이재근式 시니어라운지 서울 찍고 수도권으로',
#        '사천시니어클럽, 2022년 노인일자리 참여자 직무교육 실시',
#        "[GJ포토] 시니어 모델 정찬연, '고급스러운 비주얼'", '전주시 시니어 금융복지상담가 양성 본격',
#        '국내 유일 시니어展···대구액티브시니어박람회, 내달 22일 개막',
#        "[GJ포토] 시니어 모델 이경숙, '갈대밭 패션 장인'",
#        "[GJ포토] 시니어 모델 최미곤-비바영, '독보적인 걸크러시'", "동서발전, '시니어 스마트센터' 3호점 준공",
#        '엑스코, 대구액티브시니어박람회 개최', "'세계주니어수영 첫 메달' 대전체고 양하정 선수, 대전시교육청 장학금 받아",
#        '청운대-미추홀노인복지관·노인회 교육 협약', "성남시 '5060 신중년' 인생·은퇴 설계 위한 평생교육 강좌 마련",
#        '한국언론진흥재단, 대구시립중앙도서관 시니어프로그램 교육생 미디어 교육',
#        "'대구액티브시니어박람회' 10월 22일 엑스코서 개막", '동서발전, 시니어 스마트센터 3호점 개점',
#        '성남, ‘5060\xa0신중년’\xa0인생·은퇴설계 평생교육 강좌 운영',
#        '[기업사회활동] 한전KPS, 어르신 디지털 친화 교육체험 공간 설치 후원',
#        "전북은행, 금융취약계층 자립 지원 나서..전주시와 '시니어 금융복지상담가' ...",
#        '제6회 국제예술교육실천가대회(ITAC6), 온라인·현장 컨퍼런스 성료',
#        '한전KPS, 어르신 디지털 격차 해소 위한 교육체험 공간 설치 후원',
#        "오세훈표 교육 '서울런' 정부 승인…본격 확대", '한국시니어연구소, 서울 서남권 돌봄 종사자 돕는다',
#        '동서발전, 울산 함월노인복지관에 ‘시니어 스마트센터’ 3호점 개점',
#        "오세훈표 교육 복지 '서울런' 정부 공식 승인..'2.0' 진화 가속화",
#        '시니어연구소- 서남어르신돌봄종사자지원센터, 상호지원 맞손',
#        '대전시교육청, 한국 최초 세계주니어수영선수권 메달 획득 양하정 선수에 장학...',
#        "전 세계 예술교육실천가 교류의 장…'ITAC6' 한국·노르웨이 성황",
#        '보은군, 시니어건강장수대학 하반기 개강 10월로 연기',
#        '한국시니어연구소, 서울시 서남어르신돌봄종사자센터와 업무협약',
#        "한국동서발전, 지역 어르신 위한 '시니어 스마트센터' 3호점 개점\xa0",
#        "오세훈표 교육플랫폼 '서울런 2.0' 본격 출격...지원대상 확대",
#        "'퇴직 후 건강한 시니어로!'...포항시, 인생2막 농촌생활 교육",
#        '영덕군, ‘시니어 통합 지원사 육성과정’ 수료자 취업박람회 열려', '보은군, 시니어 건강 장수대학 개강 연기',
#        '포항시 농업기술센터, 인생2막 농촌생활 위한 교육 실시', "의정부시, '일반 경비원 신임교육' 참여자 15명 선발",
#        '제6회 국제예술교육실천가대회(ITAC6), 온라인ㆍ현장 컨퍼런스 개최',
#        '한전KPS, 어르신 디지털 친화 교육 공간 마련', '보은군, 하반기 시니어건강장수대학 10월 개강',
#        'BNP파리바 카디프생명, 중학생·미혼모 대상 신용관리 교육 제공',
#        '[액티브시니어] 성동구, ‘치매안심경로당’ 37곳 지정·현판 부착',
#        '제6회 국제예술교육실천가대회(ITAC6), 온라인 현장 컨퍼런스 성료', '청주상당경찰서 어르신 교통안전교육',
#        '한국시니어연구소·서남센터, 돌봄종사자 역량 강화 업무협약', '65세에 워킹강사, 시니어모델, 뮤지컬배우',
#        '베이비붐 세대 은퇴 ‘뉴시니어’ 관심…롯데건설 VL르웨스트 등 ‘주목’',
#        "2022 시니어 노후준비지원사업 '노후 스케치' 운영",
#        '[이용기 교수의 ESG 경영 이야기] ESG 혁신의 단계-창업역량 교육과 탄주지어...',
#        '시니어세대 디지털 정보 격차 이대로 좋은가?', '숙명여대 미래교육원, 일반과정 프로그램 2학기 수강생 모집',
#        '익산시, 지역 작가와 함께 시니어 문화 창작 지원',
#        '베이비붐 세대 은퇴 앞두고 있는 지금 건설업계 지각 변동 일으킬 ‘뉴시니어...',
#        '[액티브시니어] 홍보·상담 통해 치매환자 인식 바꾼다… 경희대병원, ‘동대...',
#        '진주경찰서, 시니어클럽 어르신 대상 교통안전교육 실시',
#        '한양사이버대학교 실버산업학과, 대한민국 문화경영대상 실버산업교육 대상 수...',
#        '한국시니어연구소, 돌봄 종사자의 역량강화와 권익 증진위해 서울시 서남어르...',
#        '고양 대화도서관, 미디어교육 평생교실 운영', "강동노인종합복지관, 시니어 노후준비 지원 '노후 스케치' 운영",
#        "성남시니어산업혁신센터, '메타버스, 정보서비스 혁신의 가능성' 포럼 열어",
#        '금융권, 시니어 전용 서비스 속속 선봬', '진주경찰서, 어르신 대상 교통안전교육',
#        "국립현대미술관-대한치매학회 '일상예찬-다시 만나는 미술관’ 재개",
#        '김동수 동덕여대 모델과 교수, 평생교육원 시니어모델 과정 2기 오픈',
#        "교육업계 초고령화시대 맞아 '시니어' 사업 강화",
#        '간병인 매칭 플랫폼 좋은케어, 유니메오 간병보호사 4차 정기교육 실시',
#        "시니어에 주목한 교육업계…'먹거리 발굴' 잰걸음", '[액티브 시니어] 품위를 지켜야 존경받는다',
#        '[액티브시니어] 도전! 배우의 꿈… 동대문구, 시니어 배우학교 수강생 모집',
#        '좋은케어, 유니메오 전속 간병보호사 4차 정기교육 진행', '[포토뉴스] 계명시민교육원 시니어모델 아카데미 패션쇼',
#        '한국시니어연구소, 서울시 서남어르신돌봄종사자지원센터와 맞손',
#        '청주청원시니어클럽, 9988행복지키미 참여자 치매예방교육', '시니어 고객 디지털 편의성 높여 보험 사각지대 해소',
#        "[GJ포토] 권화숙, '미시즈·미스터·시니어 투어리즘 강원도모델교육협회상 수...",
#        '고양시니어클럽, 응급 대처 교육 진행', '신갈오거리 시니어 바리스타팀, 경기도체육대회 성공 개최 힘 보태',
#        "시니어헬스케어 스타트업 바이엘, 브랜드 '브라보'로 요양서비스 시장 공략",
#        '간병인 매칭 플랫폼 ‘좋은케어’, 유니메오 전속 간병보호사 정기교육 진행',
#        "가톨릭관동대 평생교육원 '2022 가을학기 수강생 모집'.. 시니어모델양성/푸드...",
#        "이태인 동대문구의회 의장, '동대문시니어클럽 어르신 일자리 참여자 교육' 참...",
#        '양산경찰서, 웅상시니어클럽 교통안전 교육', "[포토] '당당한 워킹' 계명대 시니어 패션쇼",
#        '동덕여대 모델과, 시니어모델 과정 2기 연다', '정읍시니어클럽 환경 개선공사 완료…일자리 발굴·교육 전담',
#        '금산소방서, 금산시니어클럽 어르신 소방안전교육 실시',
#        "용인시 '신갈오거리 시니어 바리스타팀', 경기도체육대회 성공 개최 힘 보태",
#        '양산경찰서, 웅상시니어클럽 안전 교육', '동덕여대 모델과 김동수 교수 시니어모델 과정 2기 오픈',
#        '시니어 일자리 창출을 위한 업무협약 체결', "서귀포시, 시니어 '맞춤형 일자리' 교육 추진",
#        '더컬쳐앤, 영풍문고빌딩 지하 라운지 오픈…시니어 전문 교육시장 확대 기여',
#        '나주경찰, 노안면서 시니어 교통안전 교육', "대전대 평생교육원 '시니어모델 패션쇼' 성료",
#        '서울여성병원 마더비문화원, 임산부·영유아·시니어 위한 복합 교육·문화 공...',
#        "[GJ포토] 양송희 전임 교수, '미시즈·미스터·시니어 투어리즘 심사위원 위촉...",
#        '노인일자리 참여자 대상 영천시니어, 교육 실시', '대전대 평생교육원, 시니어패션쇼 성료',
#        '동덕여대 김동수 교수, 시니어모델 과정 2기 오픈', '금산시니어클럽 노인 소방안전교육',
#        '"탄소중립 교육 강사로 제2의 인생을"...동서발전, 시니어 강사 양성 돕는다',
#        '호남백과사전, 액티브시니어 쇼핑호스트 교육모집',
#        "동덕여대 평생교육원, '모델 김동수의 시니어 아카데미' 수료패션쇼 성료",
#        '인하대 평생교육원, 드론조종자·시니어플래너지도사 등 가을학기 수강생 모집',
#        "양천어르신종합복지관, '시니어 노후준비 지원사업' 운영", '시니어 모델들의 런웨이',
#        '상주시 화서면, 찾아가는 시니어 스마트폰 교육', "부안, '시니어 위한 정보화 교육 프로그램' 운영",
#        "동덕여대 평생교육원 '모델 김동수의 시니어 아카데미' 수료패션쇼 성료", '함안 시니어 가스안전 관리원 현장교육',
#        '가톨릭관동대, 시니어모델 양성 등 평생교육원 수강생 모집', "충주 '시니어 모델' 양성 교육 첫발 내디뎌",
#        '위덕대 요양보호사교육원, 시니어통합지원사 육성 교육 종강',
#        "'서울여자대학교와 함께 스마트폰 활용교육' 시니어 서포터즈 양성",
#        "백석대 평생교육원 '시니어 모델 아카데미' 개설", "백석대 평생교육원, '시니어 모델 아카데미' 개설",
#        '동덕여대 평생교육원, ‘모델 김동수의 시니어 아카데미’ 수료패션쇼 13일 개...',
#        '부안군, 2022 시니어 정보화 교육 운영', '(주)파파나나, 구로 G페스티벌 패션쇼 참여',
#        '대전대 평생교육원 시니어 모델들 패션쇼', '상주시, 찾아가는 실버 시니어 스마트폰 교육 호응',
#        '강남문화재단, 시니어정보화교육 내달 11일까지 진행',
#        "동덕여대 평생교육원, '모델 김동수의 시니어 아카데미' 수료패션쇼 오는 13일...",
#        '백석대 평생교육원, ‘시니어 모델 아카데미’ 개설', '통영소방서, 통영시니어클럽 소방안전교육',
#        '찰나의 가을, 슬로우 비디오처럼 즐길 수 있는 곳',
#        "청년사업협동조합, 서대문구 시니어 위한 '과학으로 세대를 잇다' 교육 개최",
#        '[김수형의 시니어비즈니스 이야기9] 케어기버(caregiver) 친화적인 기업 환경',
#        '경남대 평생교육원, 시니어모델 입문 아카데미 개설', '정읍 시니어클럽 증축, 환경개선공사 마무리',
#        '평범한 부산 할매·할배들, 유명 TV광고 배우 데뷔', '상주, 시니어 스마트폰 교육 ‘호응’',
#        '정읍 시니어클럽, 증축·환경 개선공사 마무리',
#        '강남구 도곡정보문화도서관, 시니어 정보화 교육 ‘신중년의 스마트폰 정복기...',
#        '“어르신, 이제 편하게 ATM 사용하세요”',
#        '"노인 일자리 창출 산실"..정읍시니어클럽, 증축·환경 개선공사 마무리 \'본격...',
#        '상주시, 실버 시니어 스마트폰 교육 추진', '대치도서관, 김민주 강사 초청 "시니어 스마트폰 활용 교육" 진행',
#        '노인 일자리 창출의 산실! 정읍시니어클럽 증축 · 환경 개선공사 마무리',
#        '(재)송파문화재단, 송파어린이도서관 시니어 대상 미디어 리터러시(문해력) 프...',
#        '[포토뉴스] 기장소방서, 기장시니어클럽 소방안전교육 실시', '임실군, 시니어 안전전문가 양성교육 추진',
#        '부여시니어클럽, 노인일자리 참여자 교육', '정읍시 시니어클럽 증축 노인 일자리 참여 편의 확대',
#        '상주시, 여름철 농한기 ‘찾아가는 실버 시니어 스마트폰 교육’ 추진',
#        "도곡정보문화도서관, 시니어 정보화 교육 '신중년의 스마트폰 정복기' 선보여",
#        '10년 뒤 초등학생 절반..애니 만들고 시니어 사업 나선 교육업체',
#        '“교육·도전으로 문화예술 ‘품격’ 높여 구민 행복 추구”', '함안군자원봉사센터, 시니어봉사단 양성교육 실시',
#        '[포토뉴스] 바르게살기운동 부산광역시협의회, ‘시니어 디지털 활용교육’ 실...',
#        '[에너지 뉴스] 동서발전, 시니어 대상 ‘탄소중립 전문강사’ 양성 지원 外',
#        '시니어 치매예방교육 솔루션 기업 와이에스콘텐츠, 전국 지사 모집 본격화',
#        '동서발전, 시니어 ‘1.5℃를 지켜라’ 강사 양성 지원',
#        '동서발전, 시니어대상 탄소중립 전문강사 양성·일자리 창출 지원',
#        "'치매공감 NEWS'가 떴다...시니어기자단이 만드는 치매전문 지역신문",
#        '부산과학기술대 평생교육원, ‘부산 뉴-시니어스쿨 제2기 수료식’ 가져',
#        '풀무원재단, 시니어 대상 맞춤형 바른 먹거리 교육', '“나이는 숫자에 불과…우리는 ‘시니어 모델’”',
#        '한국노년봉사단, 스마트 시니어 정보화교육',
#        '풀무원, ‘시니어 생활습관 변화 프로젝트’ 실시…"도심 거주 시니어 맞춤형...',
#        '한국노인인력개발원, 시니어카페 역량 강화 앞장', '시니어 일자리 창출 돕는 시니어벤처협회, 성남시에 새 둥지 틀어',
#        '라파엘나눔, 시니어 의료진 사회참여 온라인 강의 마련',
#        "바르게살기운동 광주시協, 시니어 디지털 포용 교육 '성료'",
#        '용인시 신갈오거리 시니어 바리스타팀, 경기도체육대회 성공 개최 힘 보태', '동서발전, 시니어, 탄소중립 강사 양성',
#        "시니어 모델 `당당한 워킹'",
#        "'시니어센터 2022 SS 패션쇼' 개최한 문선웅 명지대 미래교육원 원장, “오늘...",
#        '부여시니어클럽 일자리 노인 교육', "송파어린이도서관, 시니어 미디어 리터러시 '우리 동네 환경 알리미' 운영",
#        '양천구 목동시니어 스마트교육센터 전격 운영', '대덕대학교, 평생교육원 시니어모델 수료 기념 패션쇼',
#        "양천구, '목동시니어 스마트교육센터'\xa0프로그램 운영",
#        'BNK경남은행, “어르신, ATM 사용법 알려드릴게요!”',
#        "지스트, 8월부터 오는 11월까지 월 1회 '시민과 함께하는 시니어 대상 100세 ...",
#        '대교, \'마이 시니어\' 다이어리∙아트 도서 출시…"치매예방"',
#        "서귀포시, '다시 잡(Job)'는 시니어 아카데미 운영",
#        '[현장탐방] ‘행복충전’ 서경대 시니어모델들…“허리 ‘잘록’ 활력도 UP”',
#        '안산시, 찾아가는 시니어교실 ‘불어라, 풍도학습’운영', '함안군자원봉사센터， 시니어봉사단 양성교육',
#        '대교, 시니어 두뇌건강 위한 다이어리∙아트 도서 2종 출시',
#        '"어르신이 행복한 도시" 이현재 하남시장 시니어맞춤형 정책 추진',
#        '시니어헬스케어 스타트업 바이엘, 방문요양 서비스 ‘브라보시니어케어’ 론칭',
#        "부산과기대 평생교육원 '뉴-시니어스쿨' 제2기 수료식", '양산경찰서 양산시니어클럽 교통안전 교육',
#        "MMCA-대한치매학회 '2022 일상예찬-다시 만나는 미술관' 운영",
#        '신한은행, 시니어 대상 디지털 금융교육 실시',
#        '[액티브 시니어] 시니어 모델들의 당당한 워킹… 노후생활 활력·자신감 충전',
#        '양천구, 목동시니어 스마트교육센터…디지털 장벽 허문다', '시니어들의 사이버대학생',
#        "인사동에 펼쳐지는 5060 시니어들의 인생 런웨이 '마이마이(MY MY)-나의책, 나...",
#        '화성 수현중학교와 화성 시니어 클럽 업무협약 후, 함께 문화 예술 공유',
#        '5060 시니어 인생책 런웨이 ‘마이마이’ 발표회, 21일 인사동 코트(KOTE)에서...',
#        '[포토] 세종시민장애인평생교육원, 시니어클럽과 업무협약', "5060 시니어 인생책 런웨이 '마이마이' 발표회 열려",
#        '천안교육지원청, 시니어 스마트폰 활용법 특강', "동덕여대, '모델 김동수의 시니어 아카데미' 수료패션쇼",
#        '강남시니어플라자, 시니어 인생의 꿈 실현을 위한 노후설계 교육 실시', '경남대 시니어모델,문경패션왕 대상 수상',
#        '창원대 이주은 학생 국제학술대회 논문발표 입상',
#        '금융 사기 예방·디지털 체험...신한은행, 시니어 대상 교육 진행',
#        '[중기info] 한국시니어연구소-강동새일센터, 실버산업 여성인재 육성 나선다',
#        "세종시립도서관, 매주 수요일 '금쪽같은 우리 손주' 교육 운영...선착순 15명",
#        '디지털 격차 해소 위해 교육 프로그램 외 시스템 간소화 필요',
#        "고령층 고객 위한 디지털 금융 체험…신한은행, '시니어 대상 디지털 금융교육...",
#        '한국시니어연구소-강동여성인력개발센터, 여성 일자리 창출 MOU체결',
#        "[BBS PLAZA] 부산연제시니어클럽, '꿈꾸는 로스터와 베이커' 사회활동지원사업...",
#        '한국복지정보통신협의회, 시니어 취업연계 인공지능 무료 교육생 100명 모집',
#        '신한은행, 서울디지털재단과 업무협약 "시니어 대상 디지털 금융교육"',
#        '[B tv abc뉴스]신중년 인생 2막..."시니어모델을 꿈꾼다"',
#        'SKB, 어르신에 디지털 교육…시니어 맞춤형 콘텐츠 제공', "함양 용평리 '시니어카페 바리스타 교육' 수료",
#        '‘시니어를 잡아라’ 접점 늘리는 은행들', '"스마트폰 글자 이렇게 키워요"…SKB, 시니어 디지털 교육 돕는다',
#        '한국시니어연구소, 강동여성인력개발센터와 여성 일자리 창출 MOU체결',
#        '함양 용평리, ‘’시니어카페 바리스타 교육“ 수료',
#        '한국시니어연구소·강동여성인력개발센터, 여성 일자리 창출 MOU', '신한은행, 시니어 대상 디지털 금융교육',
#        "KRX국민행복재단, 복지시설 아동교육 '시니어 강사' 모집", '풀무원푸드머스, 시니어 조리원 양성 교육',
#        '풀무원, 도심 거주 시니어 맞춤형 ‘시니어 생활습관 변화 프로젝트’ 실시',
#        '풀무원푸드머스, 남양주시니어클럽과 조리원 양성 교육 시작',
#        '[CEO초대석] 발아부터 개화·결실까지… 창업의 게임체인저', '당진시니어클럽, 노인복지시설 공기정화',
#        '“내나이가 어때서”, 광진 시니어 모델 패션쇼 열려', '풀무원푸드머스, 남양주시니어클럽과 조리원 양성 교육',
#        "[오늘의 유통가] 풀무원, '시니어 생활습관 변화 프로젝트' 실시 外",
#        '[B tv 서울뉴스] "인생 2막을 응원합니다"...\'광진 시니어 모델\' 패션쇼',
#        '광진구, 시니어모델 양성과정 수료 기념 패션쇼 개최',
#        '[게시판] KRX국민행복재단, 복지시설 교육지원 시니어 강사 모집',
#        '후케어스코리아, 제이액터스와 시니어 시장 강화를 위한 MOU 체결',
#        '배우고 싶은데... 손주 손 빌려 디지털 공부하는 시니어들', "풀무원, '시니어 생활습관 변화 프로젝트' 진행",
#        '케어닥, 국내 최대 규모 시니어타운에 돌봄 서비스 선보인다', '[포토뉴스]바르게살기운동 도협의회 디지털 포용 교육',
#        '대한노인회 경기 고양시 일산서구지회, 가원시니어도서관과 협약식', "풀무원, '시니어 생활습관 변화 프로젝트' 실시",
#        '광진구,\xa0어르신이 어르신에게 배우는 ‘시니어 스마트폰 교육’\xa0운영',
#        "광진구, '50+ 슬기로운 대학생활' 시니어모델 패션쇼 개최",
#        '유병진 명지대학교 총장, “시니어 패션쇼는 중장년층의 못다 이룬 꿈에 도전...',
#        '63세의 시니어모델 명지대 김미란 교수, "삶이 의무가 아니라 충만함으로 채워...',
#        '시니어모델 68명의 아름다운 도전 "인생2막 건강하고 즐겁게!"', '군포도시공사, 시니어 일자리창출 앞장',
#        '디지털튜터, 5월부터 시니어들 직접 찾아가는 대면 교육 본격화',
#        '‘시니어모델계의 황신혜’ 채미화, 명지대 ‘2022 SS 패션쇼’에서 화려한 자...',
#        '임실군-임실시니어클럽-(사)임실군마을가꾸기협의회, 노인 일자리 창출 MOU',
#        '군포도시공사,한국노인인력개발원과 업무협약…시니어 일자리 창출 지원',
#        "[액티브 시니어] 마곡레포츠센터 시니어 카페 '한담' 오픈",
#        '임실시니어클럽 농촌형 노인일자리 네트워크 협의체 구성', "대교, 적자 탈출 키워드는 '디지털·시니어교육'",
#        '충주시, 9월 시민정보화교육 수강생 모집',
#        '나눔다우리 사회적협동조합 조희정 대표, 시니어와 장애인을 위한 나눔 실천',
#        "상주시니어클럽 노인일자리사업 추진 '착착'",
#        "'시니어 디지털 교육'...대한디지털교육협회, 상주시노인회와 업무협약 체결",
#        "국민은행, 어르신 찾아가는 은행 'KB 시니어 라운지' 개설",
#        '울산과학대, 시니어 맞춤 스포츠·인문 교양 교육 실시',
#        "울산과학대 시니어 세대의 스포츠 및 인문 교양 교육 위해 'UC 시니어 아카데...",
#        '‘갇혀 있기 싫어’ 시니어 강좌 붐빈다', '광명 여성새로일하기센터, 유아·시니어 놀이돌봄 전문가 20명 배출',
#        '강서구, 마곡레포츠센터에 시니어 카페·매점 조성',
#        '하남시미사강변종합사회복지관-하남시니어클럽, 노인일자리 활성화를 위한 업...',
#        '‘1.5℃를 지켜라’ 탄소중립 교육 강사로 제2인생 출발', '국립제주박물관과 제주시니어클럽 MOU',
#        '경남대 평생교육원, ‘문경 패션왕 공모전’ 대상 수상', "상주 '찾아가는 실버 시니어 스마트폰 교육' 각광",
#        "대덕대 '시니어모델 강좌 수료식·패션쇼", "시니어산업협회, 시니어 재도전 위한 '창업·퇴직설계' 대면교육 재개",
#        '하남시, 2022년 시니어기자단 전문가 양성교육 실시', "하남시, '2022년 시니어기자단 전문가 양성교육' 실시",
#        '구리시, 2022년 노인일자리사업 참여자 소양교육 실시',
#        '상주시,\xa0 찾아가는 실버 시니어 스마트폰 교육\xa0시작',
#        '상주\xa0‘찾아가는 실버 시니어 스마트폰 교육’\xa0시작',
#        "동서발전, '탄소중립교육 전문강사 양성 프로그램' 지원자 모집",
#        "시니어전문교육기관 '익어가다', 시니어스마트폰활용지도사 과정 오픈", 'KT, 느린학습아동 맞춤형 디지털 교육',
#        '상주시 "찾아가는 실버 시니어 스마트폰 교육" 첫걸음', 'KT, 느린학습아동 맞춤형 디지털 교육 추진',
#        "[문화소식] '고창 병바위 일원' 명승 지정 기념행사",
#        '대한노인회 경기연합회, 2022년 찾아가는 경로당 디지털 서포터즈 직무교육 실...',
#        '[오늘의 주요일정] 부산(19일, 월)', "산청군 '노인사회활동 지원사업' 참여자 교육 실시",
#        '"탄소중립교육 전문강사로 제2인생 시작하세요"', '투교협, 시니어를 위한 디지털 교육영상 공개',
#        "동서대 '에버그린' 소속 배우, 비타500 TV 광고 출연",
#        '상주시, 찾아가는 실버 시니어 스마트폰 교육 첫걸음을 떼다',
#        '[기고] KDB시니어브리지아카데미 10주년 워크숍 성황리에 마치다!',
#        "극단 열정, 시니어 연극 '인생 제2막' 참여자 모집", "동서발전, 노령층 디지털 교육 '시니어 스마트센터' 확대",
#        'SK브로드밴드,\xa0민관 합동으로 시니어 디지털 격차 해소 나서', '함양 한들거점센터， 시니어 바리스타 탄생',
#        '서귀포시, 노인취업교육센터 취업프로그램 운영',
#        "SK브로드밴드, 시니어 디지털 격차 해소에 팔 걷었다…서울디지털재단과 '맞손...",
#        '투교협, 시니어 맞춤형 디지털 교육 영상 공개',
#        "[더벨][대교 포스트 오너십 진단]강호준 총대 '디지털교육·시니어' 재편 승계...",
#        '인천시, 전문시니어 양성교육 지원', '디지털 금융 시대, “소외되는 시니어 돌봐야”',
#        '세종대 미래교육원 광진구청과 시니어 교육 프로그램 운영', '라온문화예술교육원 우아한 시니어 연극단',
#        "안산시, 풍도·육도지역 어르신 '문해교육 지원'", 'SK브로드밴드, 시니어 디지털 격차 해소 지원',
#        '상주 화서면, 스마트폰 교육 실시', '서귀포시, 노인취업교육센터 취업프로그램 운영 개시',
#        'SK브로드밴드, 시니어 디지털 격차 해소 나서', '풀무원푸드머스, 시니어 일자리 창출 지원 확대',
#        '세종시립도서관, 시니어 대상 스마트폰 활용법 교육 운영',
#        '세종대 미래교육원, 광진구청과 시니어 교육 프로그램 운영', 'SKB, 시니어와 동행한다',
#        '동서발전, 티치포 울산에 지원금 전달...탄소중립교육 전문강사 양성 프로그램...',
#        '"1.5℃를 지켜라" 탄소중립 교육 강사로 제2인생 출발', '산청군 ‘노인사회활동 지원사업’ 참여자 교육',
#        '영덕문화관광재단, “스마트폰이 쉬워 졌어요” 시니어 스마트폰 교육 열기 후...', '옥천, 노인사회활동 교육 실시',
#        "구리시, '2022년 노인일자리사업 참여자' 소양교육 실시",
#        '“사회적 합의” 보고서 무시한 교육부… ‘국교위 카드’로 출구 찾기',
#        '용인시 \xa0신갈오거리 시니어 바리스타팀, 용인미르스타디움에 음료 나눔 부스...',
#        '인천시 미추홀노인인력개발센터, 시니어가스안전관리원 업무협약 및 양성교육...', '사학연금-시니어금융교육협 업무협약',
#        "은평구 은뜨락도서관, '시니어 영상 제작 교육 : 지금은 1인 1미디어 시대' 프...",
#        "사학연금, 시니어금융교육협의회와 '은퇴금융교육 협력' 업무협약",
#        '사학연금, 시니어금융교육협의회와 은퇴금융교육 협력 위한 MOU',
#        '[액티브 시니어] 은평구, 어르신 일자리사업 참여자에 안전 교육', '세종시립도서관, 시니어 스마트폰 활용법 교육',
#        '은퇴한 시니어들의 구석구석 공정여행', '상주시, 찾아가는\xa0시니어 스마트폰 교육 시행',
#        '(재)춘천지혜의숲, 시니어 상담센터·아카데미 기관장 위촉',
#        '창원대 뉴시니어 스마트라이프 혁신인재양성 교육연구단, ㈜나루강과 학생 인...',
#        '사학연금, 시니어금융교육협의회와 은퇴금융교육 위한 업무협약',
#        '중앙대 미래교육원 능력개발과정, 직장인 자기계발 돕는다',
#        '[동정] 김양호 삼척시장, 시니어클럽 일자리 참여자 직무교육',
#        '[기고] KDB 시니어브리지 아카데미 10주년 맞아 5월 20일~21일 홍천 퀘렌시아...',
#        '창원대 뉴시니어 스마트라이프 혁신인재양성 교육연구단 나루강과 학생 인턴십...',
#        '충북종합사회복지센터, 시니어 인권 위촉 강사 보수교육', '중앙대 미래교육원 “은퇴 후 직업 찾는 중년 도전한다”',
#        '충주경찰서, 교통사고·보이스피싱 예방 교육', '메이크인, 한국노인인력개발원에서 시니어일자리창출 교육',
#        '함양군도시재생센터 시니어 바리스타 수료식',
#        '[강좌돋보기] 은평구 시니어 영상 제작 교육 : 지금은 1인 1미디어 시대',
#        "세종시립도서관 '시니어 스마트폰 교육' 신청자 접수", "양천어르신종합복지관, '스마트정보화교육' 수강생 모집",
#        '의정부시, 시니어 맞춤형 직업교육 참여자 모집 실시', "공주 구석기 축제서 '시니어모델 코리아 패션쇼' 열린다",
#        '여수교육청, 여수시니어클럽과 학교환경관리 협약 체결해', '시니어 맞춤형 취미 플랫폼 “소통부터 일자리 연계까지”',
#        '옥천署, 어르신 전화금융사기 예방교육', "석장리 구석기 축제 '시니어모델 코리아 패션쇼' 개최",
#        "[GJ포토] 시니어 모델 성유진, '멋스러운 포즈'(WAPA 갈라쇼)",
#        '석장리 구석기 축제때 시니어모델코리아 패션쇼 개최',
#        "시니어모델과 문화예술클래스를 결합한 ‘마이마이MyMy', 12일부터 당산동 이...",
#        '옥천경찰서, 관내 어르신 대상 전화금융사기 예방 교육 실시', '의정부시, 시니어 맞춤형 직업교육 참여자 모집',
#        '여수교육청, 여수시니어클럽과 MOU',
#        '100세 시대, 새로운 직업을 만들어 볼까?…제1회 시니어플래너 포럼 열린다',
#        'MKYU 디지털튜터협회, 스마트폰 교육봉사로 요양병원의 문을 열다',
#        '"플랫폼 개발에 시니어 사업까지"…교육업계, 신사업에 도전장',
#        '김동수 동덕여대 모델과 교수, 평생교육원 시니어모델 과정 오픈',
#        "[GJ포토] 시니어 모델 여정순, '당당한 런웨이'(WAPA 갈라쇼)",
#        '인천시 중구노인복지관, ‘시니어안전모니터링단’ 참여자 대상 활동 교육 실...',
#        '죽음 준비 전문가 22명 배출…소망소사이어티 5기 교육 마쳐', '[오늘의 주요 일정]경남(9월22일 목요일)',
#        '동덕여대 모델과 김동수 교수, 평생교육원 시니어모델 과정 오픈',
#        '김총리 "지방에도 시니어 지원사업 확대"…첫 홈플러스 카페마을 개소',
#        "한밭도서관, 시니어 강좌 '뇌를 춤추게 하는 전래놀이' 개설",
#        '(주)이글에듀 변화영 대표의 이어지는 사랑... 2021년 사랑의 열매 대상 기부...',
#        '시니어교육플래너협동조합 조연미 이사장, 언론선진화포럼 전문위원 위촉',
#        '임실군, 농촌형 일자리 창출에 총력 실버 안전전문가 양성교육도 실시',
#        '파파나나, 시니어모델 에이전시 설립 "언제든 무대에 설 수 있어"',
#        'MKYU 디지털튜터협회, 스마트폰 교육봉사 실시', '상주시, 여름철 농한기에 찾아가는 스마트폰 교육 실시',
#        '주류판매 업소·식당 종사자 강화된 의무교육', '서민금융진흥원, 시니어 금융사기 예방 체험형 교구재 출시',
#        "인화로협동조합, '시니어패션모델 양성과정' 참가자 모집",
#        '[2022 대한민국 교육대상] 시니어를 위한 콘텐츠 개발 주력',
#        '법령 정비하고 지원 늘리면 시니어 기술창업이 활성화될까?',
#        '서울시어르신취업지원센터, 시니어 노동법률상담 서비스 첫 선',
#        '시니어교육플래너협동조합 조연미 이사장, 언론선진화포럼 전문위원 위촉 밝혀',
#        '시니어 기술창업자 평균 50.8세에 창업…84%는 회사경험 기반',
#        "[신향숙의 시니어 이야기] 고령사회 최대의 적 '치매', 인지발달 교육의 필요...",
#        '금감원‧시니어금융교육협의회, 50대 이상 ‘금융골든벨’ 개최',
#        "대교, 농민신문사와 치매 예방 등 시니어 지원 '맞손'",
#        '중앙대 미래교육원, 부동산 공경매 재테크과정·시니어모델과정 3월 수강생 모...',
#        '\'지구 인 더 하우스\' 정가은, New 직업 공개 "시니어모델과 교수로 활동"',
#        '대교, 치매인지재활 전문기업 엠쓰리솔루션과 MOU', '[액티브 시니어] "신중년 취업교육 인생 2막 설계 돕죠"',
#        '[제15회 대한금융 포럼] 금융 교육으로 노인 빈곤 해결하자',
#        '노블리즈 뷰티아카데미 원생, 연세대 미래교육원 모델연기과정 수료발표회 메...',
#        "울산중구시니어클럽 노노케어사업단, '손엽서그리기'활동 진행",
#        "2022 민간제안 일자리사업 선정기업 '센트오브사운드' 도내 최초 조향교육센터...",
#        "서민금융진흥원, 시니어 금융사기 예방 '체험형 교구재' 개발",
#        '정가은 "대학교 교수됐다, 시니어 모델 워킹 가르쳐" (지구인 더 하우스)',
#        '한국디지털페이먼츠, 시니어를 위한 교육용 키오스크 무상대여 캠페인 이어간...',
#        "충주시 '시니어 정보화교육'…스마트기기와 친해지기", '[독자의 눈] 시니어 금융교육이 필요하다',
#        '계룡시, 보이스피싱 예방 교육·캠페인 전개',
#        "서울시어르신취업지원센터, '열악한 시니어 노동환경개선' 발 벗고 나선다",
#        '중앙대학교 미래교육원 능력개발, 1학기 수강생 모집...시니어 전문교육 실시',
#        '[오서희] 우리는 모두 시니어가 된다', '대한노인회 서울 강동구지회, 노인사회활동지원사업 참여자 소양교육',
#        '제4회 시니어모델 코리아 수료식 패션쇼... 세종수목원서 피날레', '양천구, 노인 디지털 교육·체험 프로 제공',
#        '대한노인회 충북 충주시지회, 9988행복지키미 팀장 활동 교육 실시', '‘죽음준비교육’ 세미나',
#        "대교, 엠쓰리솔루션과 치매 예방 콘텐츠 '맞손'",
#        '부산시, 도로교통공단·시니어클럽과 시니어 일자리 600개 만든다',
#        '부산시 도로교통공단·시니어클럽과 함께 시니어 일자리 600개 만든다',
#        '부산시, 도로교통공단·시니어클럽과 함께 시니어 일자리 600개 만든다', '옥천시니어클럽, 치매예방 교육 운영',
#        '시니어벤처협회, 대면수업 재개', 'SMK CLASS 시니어모델 코리아 수료식 패션쇼',
#        '중앙대학교 미래교육원 능력개발, 부동산·사진·시니어모델과정 수강생 모집', '광주서구시니어클럽 노인일자리 소양교육',
#        '충주시, 시니어 정보화 교육 실시', "바르게살기운동세종협의회 '바르게살기운동 기본소양 교육 실시'",
#        '송파구, 노인 대상 스마트폰 및 키오스크 활용 교육 운영',
#        '인천 미추홀노인인력개발센터, 시니어가스안전관리원 업무협약 진행',
#        '송파구, 어르신 대상 스마트폰·키오스크 교육 운영',
#        "(주)오렌지베어-국제대학교,\xa0'세종시 시니어 문화 발전을 위한 업무협약' 체...",
#        '대덕대 평생교육원, "제3회 시니어 모델 패션쇼" 개최', '진안시니어클럽 일자리 참여자 안전교육 실시',
#        '“우크라이나에 평화를” 시니어 모델들 반전 화보 선보여', '시니어 따봉 연주단 운영 추진',
#        '시니어·청소년 금융 교육 등 지속적 CSR 전개하는 오준석 사장', '서울시, 어르신 1:1 스마트폰 무료 교육',
#        '서울시, 어르신 1대 1 스마트폰 무료 교육…전화로 신청하세요', '대덕대 평생교육원, 시니어 모델 패션쇼 열어',
#        '“70대 부모님도 ‘인생네컷’ 찍어요” 힙한 노후 책임질 시니어 여행사업 2',
#        '“은퇴 시니어는 새 직장서 활력 찾고, 기업은 고급 인력 활용”',
#        '동작구, ‘대학과 함께하는’평생교육 수강생 모집',
#        '[人사이트]최진규 엑스알터치 대표 “메타버스 직무교육 신시장 열겠다”',
#        "46년 '교육 한길' 대교, 시니어 공략에 나선다",
#        "어르신들 'QR코드'에 진땀 뺐지만... 이체 성공하자 '배시시'",
#        '“어르신 ‘스마트폰 교육’ 전화로 신청하세요”', "대덕대학교 평생교육원, '제3회 시니어 모델 패션쇼' 개최",
#        "[더벨]대교, 신성장동력 '시니어사업' 키운다",
#        '동네 복지관서 ‘모델 수업’? “여든에도 몰랐던 내 모습 찾아요”', "동작구, '대학연계 평생교육' 수강생 모집",
#        '부산디지털역량교육 사업단, 부산월드엑스포 유치 위한 응원캠페인 실시',
#        '대한노인회 경기 고양시 일산서구지회, 보육시설도우미 직무·소양교육', "국립세종수목원, '시니어가드너' 교육생 모집",
#        '신한은행, 고령층 대상 디지털 금융교육', "시니어 위한 대교만의 교육 노하우…'대교 뉴이프' 론칭",
#        '증평군 농업기술센터, 농촌노인 취미교육 실시', '[부산소식]부산교육청, 찾아가는 해양아카데미 운영 등',
#        "동명대 중장년층 대상 '컴퓨터 기초 활용 역량강화 교육' 시행", '지능정보원 주관 시니어 취업연계 ICT교육 성과',
#        '인천시, 60+ 전문시니어 양성교육 올해도 일냈다', '인천시 전문시니어 양성교육, 어르신들에게 기쁨 선사',
#        "[충남 사랑의열매 나눔이야기] 5. 시니어 위한 IT문화 교육 '시그널 TV' 프로...",
#        '신한금융, 하계동지점서 고령층 디지털 교육', '울산 북구, 시니어 데이터크리에이터 양성과정 개강',
#        '공주시, 노인일자리 및 사회활동 지원사업 참여자 직무교육', '순천교육지원청-순천시니어클럽, ‘업무협약식’ 체결',
#        '[경성대] 평생교육원 어르신 안전교육 위한 구급·재난 체험교육 外',
#        '대한노인회 경북 문경시지회, 경로당 임원 순회교육 실시', '이제 TV로도 스마트폰 교육을 받을 수 있다',
#        '광양제철소, 지역 시니어 계층 일자리 교육지원', '빅데이터가 뽑은 시니어 추천 교육과정',
#        "광명시 여성새로일하기센터, '유아·시니어 놀이돌봄 전문가 양성 과정' 운영",
#        "시니어에게 창업·창직 기회를… '커머스 크리에이터 클래스' 과정 개설",
#        '대교, 퍼시스와 시니어 데이케어센터 구축 위한 MOU 체결', '광양제철소, 지역 시니어 계층 일자리 교육지원 나서',
#        'SK브로드밴드-서울디지털재단, 어르신 교육 콘텐츠 제공 위해 맞손',
#        "광양제철소, 지역 시니어 계층 '일자리 교육지원' 나서... 은퇴자들 '인생 2막...",
#        '경성대 평생교육원 어르신 안전교육 위한 구급/재난 체험교육 실시', "달서구, 평생고등직업교육 거점화사업 '착착'",
#        '광주남구시니어클럽 사회서비스형사업단 본격 활동',
#        "시니어에게 창업·창직 기회 제공...'커머스 크리에이터 클래스' 과정 개설",
#        '인천 시니어유튜버 사업단, 생애 첫 메타버스 선거퀴즈 대회 출전',
#        '동국대 고양 미래융합교육원, 시니어패션모델학과 수료식 진행', '인천 시니어유튜버 메타버스 선거 퀴즈대회 첫 참가',
#        '"어르신들 스마트폰 이용 편리하게"..SKB, 시니어용 교육 콘텐츠 제공',
#        '달서구, 평생고등직업교육 거점화사업 선정', '신한은행, 시니어 고객 위한 디지털 금융 교육 실시',
#        '신한은행, 시니어 고객 대상 디지털 금융 교육 실시',
#        "[#금융톡톡] KB국민은행 '공인전자문서중계자 인증'·신한은행 '시니어 디지털...",
#        '야놀자 여행대학, ‘꿈꾸는 여행자’ 모집…韓 최초 시니어 전문', '한밭대, 시니어 창의교육 전문가 과정 성료',
#        '신한은행, 시니어 고객 디지털 금융교육 시행', '인천시, 60+ 전문시니어 양성교육 올해 155명 교육 수료',
#        "신한은행, 고령층 대상 '디지털 금융교육' 실시", '목원대 미래창의평생교육원 시니어 모델 스쿨 수료 발표회 개최',
#        '화순군, 소상공인ㆍ시니어 크리에이터 심화교육 성료',
#        "시니어가 패션모델로 등장?… 목원대 미래창의평생교육원 시니어패션쇼 '화제...",
#        '경남대 평생교육원, ‘인터내셔널 슈퍼퀸 모델 콘테스트’서 다수 수상',
#        '신한은행, 시니어 고객 디지털 금융 교육 실시', '“꼰대는 NO” 시니어 인턴십 도전하기',
#        "광주·전남 만 60세 이상 '시니어인턴십' 추진", '한밭대, 시니어 창의교육 전문가 과정 운영',
#        '광양제철, 시니어 일자리 교육지원', "경남대 평생교육원, '인터내셔널 슈퍼퀸 모델 콘테스트'서 수상",
#        '전남도교육청-한국시니어클럽 전남지회 학교환경관리 협약', "백석대 평생교육원 '50+시니어모델' 수료식 개최",
#        '대한노인회 경남 창원시 마산지회, 시니어를 위한 디지털 교육 업무협약 체결',
#        '백석대 평생교육원 ‘50+시니어모델과정’, 패션쇼 및 발전기금 기탁', '미디어센터내일, 밀양 시니어 스마트 교육',
#        '완주서, 노인교통사고 예방 현장교육을 가다!',
#        '[학원차량이 위험하다 ③] "시니어 인솔이나 전문 아웃소싱 업체 연결 모색"',
#        "BNP파리바카디프생명, 시니어금융교육 캠페인 '2021 도전! 금융미션챌린지' 성...",
#        "스마트폰 교육도 '노노(老老)케어'", '전남교육청-한국시니어클럽 전남지회 학교환경관리 협약',
#        '전남교육청-한국시니어클럽 전남지회, 학교환경관리 협약 체결',
#        '미술로 다시만나는 일상…국립현대미술관, 치매 환자 위한 프로그램',
#        "4년 뒤면 '초고령 사회'…시니어 타운부터 바리스타 교육까지", '어르신, 디지털 금융 어려워 하지 마세요',
#        '백석대 평생교육원 50+시니어 모델과정 수료생 ‘대학발전기금 350만 원 기탁...',
#        '금감원, 제10기 대학생 금융교육봉사단 모집', '금감원, 대학생 금융교육봉사단 150명 모집',
#        '성남시니어산업혁신센터-한국에자이-나우- 한국리빙랩네트워크, 시니어리빙랩...',
#        '국토안전관리원, ‘시니어 국민생활시설점검원’ 전국 사업 시작'], dtype=object)

# %%
pd.set_option('display.max_row', 500)

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =['메타버스','메타버스','메타버스','메타버스','메타버스','메타버스','메타버스','메타버스','메타버스','메타버스','키오스크','키오스크','키오스크','키오스크','리터러시','리터러시','리터러시','리터러시',]
stop_word = [
'디지털',
'평생교육',
'스마트폰',
'일자리',
'사업',
'양성',
'인생',
'사회',
'미래',
'케어',
'문화',
'발전',
'활동',
'업무',
'스마트',
'개발',
'안전교육',
'바리스타',
'체험',
'전문가',
'치매',
'은퇴',
'예술',
'취업',
'복지',
'포토',
'정보화',
'직업',
'은행',
'미디어',
'건강',
'서비스',
'도전',
'행복',
'직무',
'창업',
'인력',
'여행',
'봉사',
'운동',
'노후',
'크리에이터',
'배우',
'온라인',
'요양',
'농촌',
'유아',
'패션모델',
'사기',
'도서',
'기업',
'격차',
'해소',
'역량',
'준비',
'개선',
'영상',
'힐링',
'퇴직',
'영어',
'지능',
'튜터',
'극단',
'스트레스',
'드론',
'수영',
'기술',
'독서']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

df
# Out:
#        cnt
# 디지털    111
# 평생교육    72
# 스마트폰    64
# 일자리     62
# 사업      62
# 양성      44
# 인생      37
# 사회      34
# 미래      28
# 케어      27
# 문화      26
# 발전      26
# 활동      26
# 업무      25
# 스마트     24
# 개발      24
# 안전교육    23
# 바리스타    23
# 체험      23
# 전문가     23
# 치매      22
# 은퇴      21
# 예술      21
# 취업      20
# 복지      19
# 포토      19
# 정보화     19
# 직업      17
# 은행      16
# 미디어     15
# 건강      14
# 서비스     13
# 도전      13
# 행복      12
# 직무      12
# 창업      12
# 인력      12
# 여행      11
# 봉사      11
# 메타버스    10
# 운동      10
# 노후      10
# 크리에이터   10
# 배우       9
# 온라인      9
# 요양       8
# 농촌       8
# 유아       8
# 패션모델     8
# 사기       7
# 기업       7
# 격차       7
# 해소       7
# 역량       7
# 준비       7
# 개선       7
# 영상       7
# 힐링       6
# 퇴직       6
# 영어       6
# 지능       6
# 튜터       6
# 극단       6
# 스트레스     5
# 키오스크     4
# 리터러시     4
# 드론       4
# 수영       4
# 기술       4
# 독서       3
# 도서       2

# %%
df.index.to_list()
# Out:
# ['일자리',
#  '소방',
#  '안전',
#  '치매',
#  '건강',
#  '사회',
#  '디지털',
#  '독거',
#  '문화',
#  '금융',
#  '교통',
#  '평생교육',
#  '역량',
#  '인권',
#  '양성',
#  '인력',
#  '소양',
#  '키오스크',
#  '성교육',
#  '여가',
#  '스마트폰',
#  '예술',
#  '의료',
#  '공예',
#  '회계',
#  '정신건강',
#  '역사',
#  '만들기',
#  '환경',
#  '재무',
#  '농업',
#  '보이스피싱',
#  '식생활',
#  '취업',
#  '간호',
#  '심리',
#  '실생활',
#  '포토',
#  '미디어',
#  '푸드',
#  '테크',
#  '글로벌',
#  '기술',
#  '우울증',
#  '대화',
#  '기초과학',
#  '취미',
#  '주문',
#  '반찬',
#  '영화관',
#  '힐링',
#  '식단',
#  '농기',
#  '가정',
#  '재활',
#  '커피',
#  '운동',
#  '고혈압',
#  '당뇨병',
#  '지능',
#  '말동무',
#  '자영업자',
#  '휴머니튜드',
#  '전문교육',
#  '요리',
#  '응급처치',
#  '말벗',
#  '장비',
#  '목공',
#  '노래',
#  '축산물',
#  '포장',
#  '반려동물',
#  '도시농업',
#  '학업',
#  '가르침',
#  '지식',
#  '인간관계',
#  '치료',
#  '식사',
#  '농촌',
#  '농장',
#  '식중독',
#  '은퇴',
#  '생활고',
#  '일터',
#  '알바',
#  '로봇',
#  '외국어',
#  '트롯',
#  '체육',
#  '재배',
#  '극단',
#  '수영',
#  '골프',
#  '피아노',
#  '상담',
#  '플랫폼',
#  '소통',
#  '예약',
#  '도시락',
#  '빨래',
#  '옥천군',
#  '시화',
#  '전서',
#  '최기문',
#  '영천시장',
#  '시사회',
#  '생수',
#  '충북도',
#  '게재',
#  '교육자',
#  '동서',
#  '중립',
#  '신현원창동',
#  '강의',
#  '불교',
#  '정관',
#  '주체',
#  '기여',
#  '이모저모',
#  '대한의사협회',
#  '창울',
#  '이도영',
#  '목포시',
#  '차단',
#  '이천',
#  '부원',
#  '방법',
#  '부산시',
#  '제주시',
#  '마산',
#  '일자',
#  '리창',
#  '휴먼시아',
#  '종로',
#  '황인',
#  '장관',
#  '가세',
#  '한밭',
#  '춘추',
#  '바람',
#  '창립총회',
#  '성황',
#  '장성군',
#  '부천시',
#  '옥천',
#  '동물',
#  '브레인',
#  '화서면',
#  '보은',
#  '여고',
#  '학생회',
#  '가톨릭',
#  '선종',
#  '이장우',
#  '청년',
#  '공약',
#  '축소',
#  '전망',
#  '재원',
#  '이충호',
#  '경찰청장',
#  '방해',
#  '삼호동',
#  '구슬',
#  '중대',
#  '재해',
#  '처벌',
#  '서종면',
#  '브이',
#  '이노베이션',
#  '주변',
#  '학점은행제',
#  '에듀',
#  '사이버',
#  '관교',
#  '특색',
#  '승학골',
#  '서당',
#  '영광군',
#  '송정동',
#  '조기',
#  '알림',
#  '공검면',
#  '회분',
#  '포항',
#  '포항시',
#  '소화기',
#  '모델',
#  '간호사',
#  '연구',
#  '실습',
#  '노동자',
#  '제천',
#  '아세아',
#  '시멘트',
#  '꾸러미',
#  '권선구',
#  '반정',
#  '누리',
#  '레시피',
#  '북면',
#  '육성',
#  '공음면',
#  '창선',
#  '마술',
#  '여행',
#  '프로그램관리자',
#  '광진구',
#  '산청군',
#  '청춘',
#  '부평',
#  '강남구',
#  '담양',
#  '집중인터뷰',
#  '초등학교',
#  '입학',
#  '반응',
#  '아트',
#  '페스티벌',
#  '작가',
#  '백년',
#  '대계',
#  '달도',
#  '인제',
#  '기린',
#  '상남점',
#  '매화',
#  '상주면',
#  '서포터즈',
#  '감자',
#  '삼만리',
#  '동해시',
#  '노봉',
#  '영상',
#  '촬영',
#  '폭력',
#  '신곡',
#  '상당',
#  '플러스',
#  '광명시',
#  '한바탕',
#  '웃음',
#  '잔치',
#  '매개',
#  '인기',
#  '무인',
#  '단말기',
#  '외서면',
#  '상관면',
#  '장흥군']

# %%
df[:500]
# Out:
#           cnt
# 일자리       120
# 소방         52
# 안전         47
# 치매         46
# 건강         42
# 사회         40
# 디지털        31
# 독거         29
# 문화         29
# 금융         29
# 교통         27
# 평생교육       27
# 역량         24
# 인권         23
# 양성         22
# 인력         17
# 소양         16
# 키오스크       14
# 성교육        14
# 여가         13
# 스마트폰       13
# 예술         11
# 의료         10
# 공예         10
# 회계          9
# 정신건강        9
# 역사          8
# 만들기         8
# 환경          8
# 재무          8
# 농업          7
# 보이스피싱       6
# 식생활         6
# 취업          6
# 간호          6
# 심리          5
# 실생활         5
# 포토          5
# 미디어         5
# 푸드          5
# 테크          5
# 글로벌         5
# 기술          5
# 우울증         5
# 대화          4
# 기초과학        2
# 취미          2
# 주문          2
# 반찬          2
# 영화관         2
# 힐링          2
# 식단          2
# 농기          2
# 가정          2
# 재활          2
# 커피          2
# 운동          2
# 고혈압         2
# 당뇨병         2
# 지능          2
# 말동무         2
# 중풍          2
# 휴머니튜드       1
# 전문교육        1
# 요리          1
# 응급처치        1
# 단양          1
# 말벗          1
# 단양군         1
# 과목          1
# 정기영         1
# 계장          1
# 구역          1
# 약자          1
# 조물          1
# 식도락         1
# 볶음          1
# 합천          1
# 노출          1
# 장비          1
# 중앙          1
# 수립          1
# 춘해보건대       1
# 목공          1
# 명지전문대       1
# 노래          1
# 포천          1
# 가까이         1
# 나기          1
# 김치          1
# 삼문동         1
# 보조금         1
# 정산          1
# 귀감          1
# 부여          1
# 인세          1
# 수도권         1
# 관계자         1
# 재난          1
# 화성          1
# 청렴          1
# 축산물         1
# 인증          1
# 마늘          1
# 공급          1
# 배기          1
# 비중          1
# 위중          1
# 다소          1
# 감소          1
# 깜짝          1
# 홍천군         1
# 기반          1
# 아라뱃길        1
# 지사          1
# 중요          1
# 영화로         1
# 그린          1
# 보급          1
# 포장          1
# 금성면         1
# 구룡          1
# 기기          1
# 부지          1
# 투여          1
# 아세트아미노펜     1
# 성분          1
# 해열제         1
# 부족          1
# 이창호         1
# 선임          1
# 김해시         1
# 반려동물        1
# 특성          1
# 티켓          1
# 보기          1
# 청리면         1
# 사전          1
# 죽음          1
# 공부          1
# 오히려         1
# 몰락          1
# 바다          1
# 자랑          1
# 도시농업        1
# 개설          1
# 대학생         1
# 봉사자         1
# 요리실         1
# 동진면         1
# 송두환         1
# 위원장         1
# 보장          1
# 포용          1
# 상황          1
# 주정          1
# 영암          1
# 금정구         1
# 장수          1
# 료후          1
# 공동          1
# 작업장         1
# 강남          1
# 대한민국        1
# 대표          1
# 브랜드         1
# 부문          1
# 간소화         1
# 남용          1
# 후견인         1
# 도구로         1
# 황산면         1
# 강서          1
# 보수          1
# 경복대         1
# 위생          1
# 예치          1
# 김송          1
# 고씨          1
# 학업          1
# 진드기         1
# 사망          1
# 활동가         1
# 가스          1
# 태백          1
# 성황리         1
# 합창단         1
# 일산동구        1
# 여개          1
# 부처          1
# 가르침         1
# 복지로         1
# 목소리         1
# 촘촘          1
# 복지부         1
# 홍보          1
# 건국          1
# 지식          1
# 편입          1
# 복지사         1
# 가정사         1
# 동시          1
# 패키지         1
# 인간관계        1
# 극복          1
# 선도          1
# 스쿨존         1
# 제한          1
# 한수          1
# 구청          1
# 문화센터        1
# 설명          1
# 감수성         1
# 진원          1
# 사람          1
# 인생          1
# 스토리         1
# 구술          1
# 생애          1
# 최신          1
# 외국          1
# 발간          1
# 아이          1
# 상대          1
# 아동권리        1
# 보호자         1
# 대상자         1
# 치료          1
# 생리          1
# 원금          1
# 식사          1
# 더위          1
# 대림          1
# 천진          1
# 조선족         1
# 어제          1
# 안산          1
# 드림          1
# 스타트         1
# 학령기         1
# 농촌          1
# 농장          1
# 사과          1
# 수호천사        1
# 교종          1
# 인류          1
# 지속          1
# 도시          1
# 북이면         1
# 체조          1
# 구로구         1
# 인플레         1
# 감축          1
# 통과          1
# 영주시         1
# 식중독         1
# 경산          1
# 개소          1
# 장안구         1
# 소속          1
# 향기          1
# 나무          1
# 인격          1
# 형성          1
# 죽곡          1
# 은퇴          1
# 생활고         1
# 일터          1
# 몰리          1
# 자영          1
# 업자          1
# 알바          1
# 편의          1
# 학년          1
# 선교사         1
# 얼굴          1
# 집단          1
# 사기          1
# 흥덕면         1
# 협동조합        1
# 동양          1
# 레이더         1
# 다시          1
# 나선          1
# 폐지          1
# 수집          1
# 냉방          1
# 바둑          1
# 일도          1
# 오금동         1
# 진해          1
# 로봇          1
# 리쿠          1
# 다문화         1
# 무릎          1
# 관절          1
# 수술          1
# 매입          1
# 살피          1
# 모동면         1
# 임시          1
# 총회          1
# 여론          1
# 명분          1
# 홍천          1
# 영귀          1
# 맹호          1
# 수영구         1
# 스위스         1
# 대신          1
# 선택          1
# 팔달구         1
# 대치          1
# 신안          1
# 우체국         1
# 파산          1
# 집착          1
# 희생          1
# 셀프          1
# 서영아         1
# 옥시          1
# 가짜          1
# 주장          1
# 피의자         1
# 사진          1
# 도민          1
# 아파트         1
# 시작          1
# 박상수         1
# 도계          1
# 점검          1
# 행안부         1
# 규제          1
# 액티브         1
# 친절          1
# 죽곡면         1
# 부산외국어대학교    1
# 외국어         1
# 바탕          1
# 융합          1
# 교류          1
# 영통구         1
# 학술          1
# 포럼          1
# 워크샵         1
# 봉양면         1
# 손길          1
# 호평          1
# 인프라         1
# 접근성         1
# 꼴찌          1
# 스카이라이프      1
# 영업          1
# 사은          1
# 미끼          1
# 중계          1
# 영천시         1
# 투맨          1
# 삼척          1
# 도계읍         1
# 관광          1
# 치아          1
# 급증          1
# 강릉          1
# 트롯          1
# 근황          1
# 공개          1
# 선린대         1
# 재학생         1
# 인천광역시       1
# 유아          1
# 체육          1
# 종이접기        1
# 글쓰기         1
# 정규          1
# 인월면         1
# 등급          1
# 획득          1
# 김진아         1
# 금발          1
# 신문          1
# 재배          1
# 자애          1
# 덕양          1
# 극단          1
# 춘천인형극제      1
# 관왕          1
# 초인종         1
# 부천          1
# 사용          1
# 관심          1
# 상영          1
# 만전          1
# 양양군         1
# 밀착          1
# 개그맨         1
# 오정태         1
# 간다          1
# 김현주         1
# 더봄          1
# 고흥군         1
# 점암면         1
# 위촉          1
# 화천군         1
# 지지          1
# 부진          1
# 능력          1
# 수분          1
# 섭취          1
# 휴식          1
# 학성동         1
# 동물복지        1
# 무상급식        1
# 인상          1
# 수영          1
# 골프          1
# 피아노         1
# 오누이         1
# 상담          1
# 총력          1
# 특화          1
# 방안          1
# 목장          1
# 류창현         1
# 익산시         1
# 대피          1
# 먼저          1
# 창녕          1
# 민간          1
# 위탁          1
# 수탁          1
# 동한          1
# 춘천시         1
# 분기          1
# 직장          1
# 정자          1
# 나주          1
# 세종시         1
# 이사회         1
# 비대          1
# 면화          1
# 가속          1
# 학당          1
# 소크라테스       1
# 자원봉사단       1
# 강범석         1
# 청장          1
# 여건          1
# 플랫폼         1
# 보행자         1
# 관람          1
# 경주          1
# 이병기         1
# 서로          1
# 격려          1
# 소통          1
# 시간          1
# 자원          1
# 순환          1
# 경영          1
# 자원봉사자       1
# 부안읍         1
# 바로          1
# 논산시         1
# 신규          1
# 택시          1
# 잡기          1
# 열차          1
# 예약          1
# 속수무책        1
# 권익          1
# 파주시         1
# 의왕시         1
# 내면          1
# 근력          1
# 시각장애인       1
# 권역          1
# 무협          1
# 규칙          1
# 경도          1
# 인지장애        1
# 도움          1
# 장수군         1
# 마이          1
# 패밀리         1
# 도시락         1
# 빨래          1
# 옥천군         1
# 시화          1
# 전서          1
# 최기문         1
# 영천시장        1
# 시사회         1
# 생수          1
# 충북도         1
# 게재          1
# 교육자         1
# 동서          1
# 중립          1
# 신현원창동       1

# %%
df.cnt.unique()
# Out:
# array([120,  52,  47,  46,  42,  40,  31,  29,  27,  24,  23,  22,  17,
#         16,  14,  13,  11,  10,   9,   8,   7,   6,   5,   4,   2,   1])

# %%
df_test= df[df['cnt'] > 10]  #몇 번 이상 등장한 단어를 뽑아낼 건지 정하기
len(df_test)
# Out:
# 21

# %%
df_stop_words = df_test
df_stop_words = df_stop_words.reset_index()
df_stop_words
# Out:
#    index  cnt
# 0    일자리  120
# 1     소방   52
# 2     안전   47
# 3     치매   46
# 4     건강   42
# 5     사회   40
# 6    디지털   31
# 7     독거   29
# 8     문화   29
# 9     금융   29
# 10    교통   27
# 11  평생교육   27
# 12    역량   24
# 13    인권   23
# 14    양성   22
# 15    인력   17
# 16    소양   16
# 17   성교육   14
# 18    여가   13
# 19  스마트폰   13
# 20    예술   11

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='AppleGothic')# 한글 폰트 설정

# %%
from wordcloud import WordCloud

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 3000, 
                      height = 4000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=100).generate_from_frequencies(data)
plt.figure(figsize = (9, 9))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 2999.5, 3999.5, -0.5)
