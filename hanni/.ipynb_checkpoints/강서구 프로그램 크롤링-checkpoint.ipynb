# %%
강동구 
강서구 
서초구
송파구
양천구
은평구
중구

# %%
ks = pd.read_excel('강서구손크롤링.xlsx')
ks
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                        길꽃천문교실(10월)        NaN        NaN
# 1                                   [문화가있는날]입체미디어북으로       들려주는      평화이야기
# 2    나는_나를_돌봅니다 박진영 작가와의 만남 [한 주제 함께 읽기 릴레이 작가와의 만남]        NaN        NaN
# 3                                         [연극&체험]우리가       사랑하는        도서관
# 4                                            [6학년]초등      온라인으로         매일
# ..                                               ...        ...        ...
# 194                                            [2020      정규문화]       질문으로
# 195                                            [2020      정규문화]        사고력
# 196                                            [2020      정규문화]        꼼지락
# 197                                            [2020      정규문화]         힐링
# 198                                            [2020      정규문화]         초등
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
ks.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'title', 'target'],
#       dtype='object')

# %%
ks.drop(labels=['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],axis=1,inplace=True)

# %%
ks
# Out:
#                                                  title target
# 0                                   길꽃천문교실(10월)           전연령
# 1                [문화가있는날]입체미디어북으로 들려주는 평화이야기 _너영나영        전연령
# 2    나는_나를_돌봅니다 박진영 작가와의 만남 [한 주제 함께 읽기 릴레이 작가와의 만남...     성인
# 3                          [연극&체험]우리가 사랑하는 도서관 이야기        전연령
# 4                            [6학년]초등 온라인으로 매일 고전읽기        어린이
# ..                                                 ...    ...
# 194                        [2020 정규문화] 질문으로 만나는 한국사       어린이
# 195                             [2020 정규문화] 사고력 체스        어린이
# 196                          [2020 정규문화] 꼼지락 그림책 여행       어린이
# 197                           [2020 정규문화] 힐링 캘리그라피         성인
# 198                           [2020 정규문화] 초등 시사 토론        어린이
#
# [199 rows x 2 columns]

# %%
ks.to_csv('ks_all.csv',encoding="utf-8-sig", index=False)
