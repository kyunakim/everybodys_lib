# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_excel('도봉구도서관.xlsx')

df
# Out:
#      Unnamed: 0                                      title target
# 0          1082     [1기-추가모집] 포토샵 (초급) ☞ 1/25 10:00부터 접수시작     성인
# 1          1084                              [1기] 책놀이 (7세)    어린이
# 2          1085                               [1기] 교양한문 시경     성인
# 3          1086                               [1기] 교양한문 논어     성인
# 4          1087                             [1기] 스마트폰 사진촬영     성인
# ..          ...                                        ...    ...
# 151        1234  2021년 4기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-    어린이
# 152        1235            2021년 행복한영어 4분기 - 줌(zoom) 화상강의-    어린이
# 153        1236          2021년 4기 한자교실(3~6학년)-줌(zoom)화상강의-    어린이
# 154        1237  2021년 4기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-    어린이
# 155        1238            2021년 행복한영어 4분기 - 줌(zoom) 화상강의-    어린이
#
# [156 rows x 3 columns]

# %%
df['title'].unique()
# Out:
# array(['[1기-추가모집] 포토샵 (초급) ☞ 1/25 10:00부터 접수시작', '[1기] 책놀이 (7세)',
#        '[1기] 교양한문 시경', '[1기] 교양한문 논어', '[1기] 스마트폰 사진촬영', '[1기] 캘리그라피 (금)',
#        '[1기] POP&캘리그라피 (수)', '[1기] 포토샵 (초급)', '[1기] 엑셀활용',
#        '[1기] 잉글리쉬 카페 (원어민 영어) 수요반', '[1기] 잉글리쉬 카페 (원어민 영어) 월요반',
#        '[1기] 중국어회화 목금', '[1기] 영어회화 수목', '[1기] 영어회화 월목', '[1기] 영어회화 월수',
#        '[1기-추가모집] 책놀이 (7세)  ☞ 1/25(월) 10:00부터 접수시작',
#        '[1기-추가모집] 교양한문 시경 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 교양한문 논어 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 스마트폰 사진촬영☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 캘리그라피 (금) ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] POP&캘리그라피 (수) ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 엑셀활용 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 잉글리쉬 카페 (원어민 영어) 수요반 ☞ 기존 수강생만 추가접수 가능',
#        '[1기-추가모집] 잉글리쉬 카페 (원어민 영어) 월요반 ☞ 기존 수강생만 추가접수 가능',
#        '[1기-추가모집] 중국어회화 목금 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 영어회화 수목 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 영어회화 월목 ☞ 1/25 10:00부터 접수시작',
#        '[1기-추가모집] 영어회화 월수 ☞ 1/25 10:00부터 접수시작', '[2기] 책놀이 (7세)',
#        '[2기] 그림책상상 그림책 여행 (초등4~6학년)', '[2기] 교양한문 시경', '[2기] 교양한문 논어',
#        '[2기] 스마트폰 사진,', '[2기] 날숨 캘리그라피 (이미지반)', '[2기] 들숨 캘리그라피 (일상반)',
#        '[2기] 인터넷 활용', '[2기] 쉽게 배우는 한글', '[2기] 쉽게 배우는 엑셀', '[2기] 포토샵 중급',
#        '[2기] 컴퓨터 입문', '[2기] 잉글리쉬 카페 수요반 (원어민영어)',
#        '[2기] 잉글리쉬 카페 월요반 (원어민영어)', '[2기] 중국어 회화', '[2기] 일본어회화 초급',
#        '[2기] 영어회화 수목', '[2기] 영어회화 월목', '[2기] 영어회화 월수',
#        '[2기-추가모집] 스마트폰 사진,', '[2기-추가모집] 인터넷 활용', '[2기-추가모집] 쉽게 배우는 한글',
#        '[2기-추가모집] 포토샵 중급', '[2기-추가모집] 컴퓨터 입문',
#        '[2기-추가모집] 잉글리쉬 카페 월요반 (원어민영어)', '[2기-추가모집] 중국어 회화',
#        '[2기-추가모집] 영어회화 월목', '[3기] 책놀이 (7세)',
#        '[3기] 그림책 상상 그림책 여행 (초등4~6학년)', '[3기] 교양한문 시경', '[3기] 교양한문 논어',
#        '[3기] 날숨 캘리그라피 (금)', '[3기] 들숨 캘리그라피 (수)',
#        '[3기] (PC와 스마트폰을 활용한) 사진,영상 제작 기초반 /★대면강의★',
#        '[3기] 쉽게 배우는 엑셀 / ★대면강의★', '[3기] 쉽게 배우는 한글 / ★대면강의★',
#        '[3기] 포토샵 초급 / ★대면강의★', '[3기] 컴퓨터 입문 / ★대면강의★',
#        '[3기] 잉글리쉬 카페 (수) - 원어민회화 (신규 접수시 6/23사전 인터뷰)',
#        '[3기] 잉글리쉬 카페 (월) - 원어민회화 (신규 접수시 6/23사전 인터뷰)', '[3기] 중국어회화',
#        '[3기] 일본어회화 초급', '[3기] 영어회화 수·목', '[3기] 영어회화 월·목', '[3기] 영어회화 월·수',
#        '[4기] 책놀이 (7세)', '[4기] 그림책 상상 그림책 여행 (4-6학년)', '[4기] 교양한문 시경',
#        '[4기] 교양한문 논어', '[4기] 날숨 캘리그라피 (금)', '[4기] 들숨 캘리그라피 (수)',
#        '[4기] 인터넷&스마트폰 정복하기', '[4기] 쉽게 배우는 한글', '[4기] 쉽게 배우는 엑셀',
#        '[4기] 포토샵 중급', '[4기] 컴퓨터 입문',
#        '[4기] 잉글리쉬 카페 (수) - 원어민회화 (신규접수시 9/17 사전 인터뷰)',
#        '[4기] 잉글리쉬 카페 (월) - 원어민회화 (신규접수시 9/17 사전 인터뷰)', '[4기] 중국어회화',
#        '[4기] 일본어회화 초급', '[4기] 영어회화 수목', '[4기] 영어회화 월목', '[4기] 영어회화 월수',
#        '2021년 1기 한국사B(3~4학년)-줌(zoom)화상강의',
#        '2021년 1기 한국사A(3~4학년)-줌(zoom)화상강의',
#        '2021년 1기 한자교실(3~6학년)-줌(zoom)화상강의-',
#        '2021년 1기 마음쑥쑥 그림책영어(1~3학년)-줌(ZOOM) 화상강의-',
#        '2021년 1기 두근두근 처음영어(7~8세) -줌(ZOOM) 화상강의-',
#        '2021년 1기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-',
#        '2021년 1기 꿈과자신감을 키워주는 동화놀이(7세)-줌(ZOOM)화상강의-',
#        '2021년 1기 꿈과자신감을 키워주는 동화놀이(6세)-줌(ZOOM)화상강의-',
#        '2021년 행복한영어 1분기 - 줌 화상강의(총8회차시)-',
#        '2021년 2기 꿈과자신감을 키워주는 동화놀이(6세)-줌(ZOOM)화상강의-',
#        '2021년 2기 꿈과자신감을 키워주는 동화놀이(7세)-줌(ZOOM)화상강의-',
#        '2021년 2기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-',
#        '2021년 2기 두근두근 처음영어(7~8세) -줌(ZOOM) 화상강의-',
#        '2021년 2기 마음쑥쑥 그림책영어(1~3학년)-줌(ZOOM) 화상강의-',
#        '2021년 2기 한자교실(3~6학년)-줌(zoom)화상강의-',
#        '2021년 2기 한국사A(3~4학년)-줌(zoom)화상강의',
#        '2021년 2기 한국사B(3~4학년)-줌(zoom)화상강의',
#        '2021년 행복한영어 2분기 - 줌(zoom) 화상강의-',
#        '2021년 3기 한국사B(3~4학년) - 줌(zoom)화상강의',
#        '2021년 3기 한국사A(3~4학년) - 줌(zoom)화상강의',
#        '2021년 3기 한자교실(3~6학년)-줌(zoom)화상강의-',
#        '2021년 3기 마음쑥쑥 그림책영어(9~10세) - 줌(ZOOM) 화상강의-',
#        '2021년 3기 두근두근 처음영어(7~8세) -줌(ZOOM) 화상강의-',
#        '2021년 3기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-',
#        '2021년 행복한영어 3분기 - 줌(zoom) 화상강의-',
#        '2021년 3기 마음쑥쑥 그림책영어<나라반>(8~10세) - 줌(ZOOM) 화상강의-',
#        '2021년 4기 한국사B(3~4학년) - 줌(zoom)화상강의',
#        '2021년 4기 한국사A(3~4학년) - 줌(zoom)화상강의',
#        '2021년 4기 한자교실(3~6학년)-줌(zoom)화상강의-',
#        '2021년 4기 마음쑥쑥 그림책영어<나라반>(8~10세) - 줌(ZOOM) 화상강의-',
#        '2021년 4기 마음쑥쑥 그림책영어)<아이반>(9~10세 - 줌(ZOOM) 화상강의-',
#        '2021년 4기 두근두근 처음영어(7~8세) -줌(ZOOM) 화상강의-',
#        '2021년 4기 우뇌발달에 좋은 클레이아트(7~9세)-온라인 동영상 강의-',
#        '2021년 행복한영어 4분기 - 줌(zoom) 화상강의-'], dtype=object)

# %%
import re
target = df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
text
# Out:
# 논어       7
# 신규       7
# 수시       7
# 사전       7
# 인터뷰      7
# 스마트폰     6
# 엑셀       6
# 한글       6
# 컴퓨터      6
# 입문       6
# 한자       6
# 교실       6
# 마음       6
# 활용       5
# 수목       5
# 월목       5
# 상상       5
# 여행       5
# 날숨       5
# 일본어      5
# 발달       5
# 클레이      5
# 아트       5
# 온라인      5
# 동영상      5
# 분기       5
# 월수       4
# 들숨       4
# 처음       4
# 자신감      4
# 동화       4
# 수요       3
# 초등       3
# 사진       3
# 인터넷      3
# 사진촬영     2
# 목금       2
# 기존       2
# 수강생      2
# 가능       2
# 나라       2
# 이미지      1
# 상반       1
# 영상       1
# 제작       1
# 초반       1
# 정복       1
# 아이       1

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = [
'강의',
'교양',
'화상',
'추가',
'모집',
'학년',
'접수',
'카페',
'부터',
'시작',
'대면',
'시경',
'신규',
'수시',
'사전',
'인터뷰',
'스마트폰',
'입문',
'교실',
'마음',
'활용',
'수목',
'월목',
'상상',
'여행',
'날숨',
'온라인',
'동영상',
'분기',
'월수',
'들숨',
'처음',
'수요',
'목금',
'기존',
'수강생',
'가능',
'나라',
'이미지',
'상반',
'초반',
'정복',
'아이']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

df
# Out:
#        cnt
# 영어      40
# 회화      38
# 그림책     16
# 한문      14
# 잉글리쉬    14
# 원어민     14
# 캘리그라피   13
# 포토샵      8
# 중국어      8
# 한국사      8
# 논어       7
# 엑셀       6
# 한글       6
# 컴퓨터      6
# 한자       6
# 일본어      5
# 발달       5
# 클레이      5
# 아트       5
# 자신감      4
# 동화       4
# 초등       3
# 사진       3
# 인터넷      3
# 사진촬영     2
# 영상       1
# 제작       1

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='AppleGothic')# 한글 폰트 설정

# %%
from wordcloud import WordCloud

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 4000, 
                      height = 3000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=100).generate_from_frequencies(data)
plt.figure(figsize = (11, 11))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 3999.5, 2999.5, -0.5)
