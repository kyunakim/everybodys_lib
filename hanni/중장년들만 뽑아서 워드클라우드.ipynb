# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_csv('서울 공공도서관 프로그램_all.csv',encoding="utf-8-sig")

df
# Out:
#        지역                                          제목   대상
# 0     금천구  [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내  전연령
# 1     금천구                 [독산] 8월 문화가 있는날- 김해원 깊이읽기 4  어린이
# 2     금천구              [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내  전연령
# 3     금천구                 [독산] 7월 문화가 있는날- 김해원 깊이읽기 3   성인
# 4     금천구              [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행   성인
# ...   ...                                         ...  ...
# 3131  강북구                   [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 3132  강북구                    [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 3133  강북구                    [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 3134  강북구                    [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 3135  강북구                    [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [3136 rows x 3 columns]

# %%
df['대상'].unique()
# Out:
# array(['전연령', '어린이', '성인', '청소년', '중장년'], dtype=object)

# %%
df = df[df['대상']=='중장년']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 62 to 2971
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      55 non-null     object
#  1   제목      55 non-null     object
#  2   대상      55 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
df['제목'].unique()
# Out:
# array(['지혜학교 - 「언어에서 배우는 지혜-언어로 보는 인간의 과거, 현재 그리고 미래」',
#        '창조성 워크숍 (아티스트 웨이)', '[★온라인강연] 화요미시회(8회강연)',
#        '“나의 인생을 영상자서전으로 만들기” 특강', '[도서관 지혜학교] 중국의 옛 노래로 배우는 즐겁게 살기의 지혜',
#        " '아티스트웨이' 프로그램",
#        ' [길 위의 인문학] 100세 시대, 노년을 위한 도서관 경제인문학 (3차, 행복한 노후 매뉴얼)',
#        ' [길 위의 인문학] 100세 시대, 노년을 위한 도서관 경제인문학 (2차, 부자는 매일 아침 경제기사를 읽는다)',
#        ' [어르신문화프로그램] 2022 디지털 문해 학습',
#        ' [어르신문화프로그램] 어르신 청춘 문화 프로젝트 ‘미술과 공예로 행복만들기’',
#        ' [독서회] 용답도서관 실버독서동아리 모집', '디지털 세상과 소통하기',
#        '[어르신대상 고전강독프로그램] 도덕경으로 마음 돌아보기', "어르신 동극단 공연'훨훨 간다'",
#        '(지식정보취약계층)찾아가는 도서관', "꿈나무도서관 어르신 프로그램 '시화와 함께하는 인생'",
#        '영미명작을 통해 보는 욕망과 희망',
#        '<※비대면전환 가능※>[문래] 2021년도 생애주기 프로그램 「미래계획Ⅲ : 취미_원예」  <향기로운 마음보듬>',
#        '어르신들을 위한 스마트폰, 키오스크 활용교육',
#        "[통합]\xa0[양원] 기본독서생활 지원 '일상의 독서' 참여 안내",
#        "[통합]\xa0[상봉] '9월 독서클럽-다정하게 나이 드는 삶 ' 참여자 모집 안내",
#        '[통합]\xa0[상봉] 7월 인문강연:「이 약 한번 잡숴봐!」최규진 교수 강연 안내',
#        "[통합]\xa0[양원] 독서생활 지원 '일상의 독서' 참여 안내",
#        "[통합]\xa0'22 중랑상봉도서관 <다시배움1750> '7월 독서클럽' 참여…",
#        "[통합]\xa02022년 중랑상봉도서관 '다시배움1750' 디지털 리터러시 교육 참여자…",
#        '[통합]\xa02022 중랑상봉도서관 다시배움1750 6월 인문강연 안내',
#        '[통합]\xa02022 중랑상봉도서관 다시배움1750 6월 독서클럽 참여자 모집 안내',
#        '[통합]\xa02022 중랑상봉도서관 다시배움1750 5월 인문강연 안내',
#        "[양원숲]\xa0[양원] 낭讀 2090 - '5090 낭독 함께읽기'",
#        '[상봉]\xa02022 중랑상봉도서관 다시배움1750 4월 인문강연 안내',
#        '[중랑]\xa0[중랑] 시니어의 행복한 책놀이 교실 안내',
#        '[상봉]\xa02022 중랑상봉도서관 다시배움1750 4월 독서클럽 참여자 모집 안내',
#        "[상봉]\xa0[모집마감] 2022 중랑상봉도서관 '다시배움1750' 디지털 리터러시 교…",
#        '[중랑]\xa0[중랑] 11월 조부모의 행복한 책놀이 교실 안내',
#        '[상봉]\xa0[다시배움1750] 독서클럽 2기 모집 안내',
#        '[중랑]\xa0[중랑] 10월 조부모의 행복한 책놀이 교실 안내',
#        "[양원숲]\xa0[양원] 2021년 양원숲속도서관 기본 독서생활 지원 프로젝트 '일상의 독…",
#        '[상봉]\xa0[다시배움1750] 인문·독서법 강연 안내',
#        '[중랑]\xa0[중랑] 9월 조부모의 행복한 책놀이 교실 안내',
#        '[중랑]\xa0[중랑] 8월 조부모의 행복한 책놀이 교실 안내',
#        '[중랑]\xa0[중랑] [일정 연기] 7월 조부모의 행복한 책놀이 교실 안내',
#        "[양원숲]\xa0[양원] 양원숲속도서관 '낭讀3090' - 5090낭독! 책 함께 읽기! 모집…",
#        '[중랑]\xa0[중랑] 6월 조부모의 행복한 책놀이 교실 안내',
#        '[중랑]\xa0[중랑] 서울형 독서문화 프로그램 지원 사업 「낭독의 시간」 안내',
#        '[중랑]\xa0[중랑] 5월 조부모의 행복한 책놀이 교실 안내',
#        '[통합]\xa0[중랑] 4월 조부모의 행복한 책놀이 교실 안내',
#        "[통합]\xa0[중랑상봉] 중장년 인문독서기획 '다시배움1750' 독서클럽 모집 안내",
#        "[통합]\xa0[중랑상봉] 중장년 인문독서기획 '다시배움1750' 기초교육 모집 안내",
#        '[통합]\xa0[중랑] 3월 조부모의 행복한 책놀이 교실 안내', '독서동아리 문장수집가 추가 모집',
#        '[대면]공기정화식물이오난사 조명등 메이킹 / 어르신', "독서동아리(40대 이상) '문장수집가' 회원 모집"],
#       dtype=object)

# %%
import re
target = df['제목'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
text
# Out:
# '지혜학교 언어에서 배우는 지혜 언어로 보는 인간의 과거 현재 그리고 미래 창조성 워크숍 아티스트 웨이 온라인강연 화요미시회 회강연 나의 인생을 영상자서전으로 만들기 특강 도서관 지혜학교 중국의 옛 노래로 배우는 즐겁게 살기의 지혜 아티스트웨이 프로그램 길 위의 인문학 세 시대 노년을 위한 도서관 경제인문학 차 행복한 노후 매뉴얼 길 위의 인문학 세 시대 노년을 위한 도서관 경제인문학 차 부자는 매일 아침 경제기사를 읽는다 어르신문화프로그램 디지털 문해 학습 어르신문화프로그램 어르신 청춘 문화 프로젝트 미술과 공예로 행복만들기 독서회 용답도서관 실버독서동아리 모집 디지털 세상과 소통하기 어르신대상 고전강독프로그램 도덕경으로 마음 돌아보기 어르신 동극단 공연 훨훨 간다 지식정보취약계층 찾아가는 도서관 꿈나무도서관 어르신 프로그램 시화와 함께하는 인생 영미명작을 통해 보는 욕망과 희망 비대면전환 가능 문래 년도 생애주기 프로그램 미래계획 취미 원예 향기로운 마음보듬 어르신들을 위한 스마트폰 키오스크 활용교육 통합 양원 기본독서생활 지원 일상의 독서 참여 안내 통합 상봉 월 독서클럽 다정하게 나이 드는 삶 참여자 모집 안내 통합 상봉 월 인문강연 이 약 한번 잡숴봐 최규진 교수 강연 안내 통합 양원 독서생활 지원 일상의 독서 참여 안내 통합 중랑상봉도서관 다시배움 월 독서클럽 참여 통합 년 중랑상봉도서관 다시배움 디지털 리터러시 교육 참여자 통합 중랑상봉도서관 다시배움 월 인문강연 안내 통합 중랑상봉도서관 다시배움 월 독서클럽 참여자 모집 안내 통합 중랑상봉도서관 다시배움 월 인문강연 안내 양원숲 양원 낭 낭독 함께읽기 상봉 중랑상봉도서관 다시배움 월 인문강연 안내 중랑 중랑 시니어의 행복한 책놀이 교실 안내 상봉 중랑상봉도서관 다시배움 월 독서클럽 참여자 모집 안내 상봉 모집마감 중랑상봉도서관 다시배움 디지털 리터러시 교 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 상봉 다시배움 독서클럽 기 모집 안내 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 양원숲 양원 년 양원숲속도서관 기본 독서생활 지원 프로젝트 일상의 독 상봉 다시배움 인문 독서법 강연 안내 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 중랑 중랑 일정 연기 월 조부모의 행복한 책놀이 교실 안내 양원숲 양원 양원숲속도서관 낭 낭독 책 함께 읽기 모집 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 중랑 중랑 서울형 독서문화 프로그램 지원 사업 낭독의 시간 안내 중랑 중랑 월 조부모의 행복한 책놀이 교실 안내 통합 중랑 월 조부모의 행복한 책놀이 교실 안내 통합 중랑상봉 중장년 인문독서기획 다시배움 독서클럽 모집 안내 통합 중랑상봉 중장년 인문독서기획 다시배움 기초교육 모집 안내 통합 중랑 월 조부모의 행복한 책놀이 교실 안내 독서동아리 문장수집가 추가 모집 대면 공기정화식물이오난사 조명등 메이킹 어르신 독서동아리 대 이상 문장수집가 회원 모집 독서동아리 문장수집가 추가 모집 대면 공기정화식물이오난사 조명등 메이킹 어르신 독서동아리 대 이상 문장수집가 회원 모집'

# %%
pd.set_option('display.max_row', 500)

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =['리터러시','키오스크']
stop_word = ['중랑','안내','교실','어르신','중장','이상','회원','이오','난사','추가','프로그램','상봉','클럽','도서관','모집','생활','리터','러시','일상','동아리','기본','학교','통합','노년','기획','다시','대면','공기','정화','양원','지원','참여자','참여','웨이','프로젝트','시대',
'온라인',
'화요',
'미시',
'특강',
'매뉴얼',
'매일',
'아침',
'기사',
'용답',
'실버',
'세상',
'대상',
'훨훨',
'간다',
'계층',
'나무',
'통해',
'비대',
'전환',
'가능',
'년도',
'생애',
'주기',
'계획',
'오스',
'활용',
'한번',
'최규진',
'교수',
'시니어',
'마감',
'일정',
'연기',
'서울',
'사업',
'시간',
'기초',      ]

for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

df
# Out:
#       cnt
# 독서     21
# 배움     12
# 조부모     9
# 강연      8
# 인문      7
# 지혜      4
# 인문학     4
# 문화      4
# 디지털     4
# 문장      4
# 수집가     4
# 교육      3
# 낭독      3
# 언어      2
# 미래      2
# 아티스트    2
# 인생      2
# 만들기     2
# 경제      2
# 마음      2
# 숲속      2
# 식물      2
# 조명등     2
# 메이킹     2
# 리터러시    1
# 키오스크    1
# 인간      1
# 과거      1
# 현재      1
# 창조성     1
# 워크숍     1
# 영상      1
# 자서전     1
# 중국      1
# 노래      1
# 살기      1
# 노후      1
# 부자      1
# 문해      1
# 학습      1
# 청춘      1
# 미술      1
# 공예      1
# 행복      1
# 소통      1
# 강독      1
# 도덕경     1
# 극단      1
# 공연      1
# 지식      1
# 정보      1
# 취약      1
# 시화      1
# 영미      1
# 명작      1
# 욕망      1
# 희망      1
# 문래      1
# 취미      1
# 원예      1
# 스마트폰    1
# 나이      1

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='AppleGothic')# 한글 폰트 설정

# %%
from wordcloud import WordCloud

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 4000, 
                      height = 3000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=100).generate_from_frequencies(data)
plt.figure(figsize = (11, 11))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 3999.5, 2999.5, -0.5)
