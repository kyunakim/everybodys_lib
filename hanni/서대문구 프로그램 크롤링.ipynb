# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_excel('서대문 도서관 손크롤링.xlsx')

df
# Out:
#                                        제목   대상 Unnamed: 2
# 0               [가족 DAY] 이야기 톡! 그림책 TALK!  전연령        NaN
# 1                        2021년 깨비독서회 회원모집  어린이        NaN
# 2                            두근두근 우리들의 시점   성인        학부모
# 3                     [학부모캠퍼스]그림책지도사 자격과정  청소년        장애인
# 4                           빅히스토리와 지구의 미래  전연령        NaN
# 5   [강좌][마감[가족 DAY] 이야기 톡! 그림책 TALK! (4월)  어린이        NaN
# 6                                 북스타트DAY  어린이        NaN
# 7                             출발~ 한국사 탐험대  어린이        NaN
# 8                     스마트폰-게임 찐갈등 제대로 학습법   성인        학부모
# 9                    한 학기 한 권 역사 읽기 운영 계획  어린이        NaN
# 10                                다함께 책놀이  어린이        NaN
# 11             「나는 매일 책 읽어주는 엄마입니다」 저자강연회   성인        학부모
# 12                           친구와 함께하는 책놀이  어린이        NaN
# 13                 「당·근·독(당신 근처의 마을독서동아리」   성인        NaN
# 14             인공지능시대 새로운 그림책교육과 인문예술적 가치   성인        NaN
# 15                                지구를 지켜라  어린이        NaN
# 16                  다 같이 돌자 지구 한 바퀴 : 베트남  어린이        NaN
# 17                             방구석 세계테마여행  전연령        NaN
# 18                     다같이 돌자 지구 한 바퀴: 일본  어린이        NaN
# 19                청소년을 위한 대중매체 연계 특화자료 읽기  청소년        NaN
# 20                          우리가족은 지구를 지겨요  어린이        NaN
# 21                          여름독서교실(제103회)  어린이        NaN
# 22                         순국선열, 나의 별이 되다  어린이        NaN
# 23               다같이 돌자 지구 한 바퀴:필리핀(8/10)  어린이        NaN
# 24                              긴긴밤 함께 읽기  어린이        NaN
# 25                           인증샷 '빅북과 함께'  전연령        NaN
# 26                    ]랜선으로 떠나는 다섯색깔이야기여행  어린이        NaN
# 27             MBTI로 알아보는 ‘Real Me’진로메타인지   성인        학부모
# 28                            행복하개 같이 살자옹  전연령        NaN
# 29                   재택근무시대에 유용한 디지털도구배우기   성인        NaN
# 30                   2021년 「우리 아이 첫 독서학교」   성인        학부모
# 31              도시와 건축으로 보는 개항과 근대의 우리 서울   성인        NaN
# 32                           함께 읽는 노자 도덕경   성인        NaN
# 33                 다같이 돌자 지구 한 바퀴: 키르기스스탄  어린이        NaN
# 34                      코로나 이후 뉴노멀 세상 이야기   성인        NaN
# 35          「방구석, 세계테마여행」:인문지리로 읽는 세계와 역사  전연령        NaN
# 36                       팬데믹시대, 슬기로운 자녀교육   성인        학부모
# 37                               시소 함께 읽기  어린이        NaN
# 38                              독서 독립 지도법   성인        학부모
# 39                    「1일 1환경 챌린지」 저자 강연회  어린이        어린이
# 40                    ]아무도 들어오지 마시오 함께 읽기  청소년        NaN
# 41                「그래프로 보는 도서관」 시청 소감 이벤트  전연령        NaN
# 42                  「여럿이 함께」 : 소중한 내 한 표!  청소년        NaN
# 43                 북세통(BOOK, 세상과의 통로] 어린이  어린이        NaN
# 44              내가 원하는 것을 나도 모를 때(with필사)   성인        NaN

# %%
df = df.drop(['Unnamed: 2'],axis=1)
df.head()
# Out:
#                           제목   대상
# 0  [가족 DAY] 이야기 톡! 그림책 TALK!  전연령
# 1           2021년 깨비독서회 회원모집  어린이
# 2               두근두근 우리들의 시점   성인
# 3        [학부모캠퍼스]그림책지도사 자격과정  청소년
# 4              빅히스토리와 지구의 미래  전연령

# %%
df.to_csv('sdm.csv', encoding="utf-8-sig", index=False)

# %%
df['제목'].unique()
# Out:
# array(['[가족 DAY] 이야기 톡! 그림책 TALK!', '2021년 깨비독서회 회원모집', '두근두근 우리들의 시점',
#        '[학부모캠퍼스]그림책지도사 자격과정', '빅히스토리와 지구의 미래',
#        '[강좌][마감[가족 DAY] 이야기 톡! 그림책 TALK! (4월)', '북스타트DAY', '출발~ 한국사 탐험대',
#        '스마트폰-게임 찐갈등 제대로 학습법', '한 학기 한 권 역사 읽기 운영 계획', '다함께 책놀이',
#        '「나는 매일 책 읽어주는 엄마입니다」 저자강연회', '친구와 함께하는 책놀이',
#        '「당·근·독(당신 근처의 마을독서동아리」', '인공지능시대 새로운 그림책교육과 인문예술적 가치', '지구를 지켜라',
#        '\xa0다 같이 돌자 지구 한 바퀴 : 베트남', '방구석 세계테마여행', '다같이 돌자 지구 한 바퀴: 일본',
#        '청소년을 위한 대중매체 연계 특화자료 읽기', '우리가족은 지구를 지겨요', '여름독서교실(제103회)',
#        '순국선열, 나의 별이 되다', '다같이 돌자 지구 한 바퀴:필리핀(8/10)', '긴긴밤 함께 읽기',
#        "인증샷 '빅북과 함께'", ']랜선으로 떠나는 다섯색깔이야기여행',
#        'MBTI로 알아보는 ‘Real Me’진로메타인지', '행복하개 같이 살자옹',
#        '재택근무시대에 유용한 디지털도구배우기', '2021년 「우리 아이 첫 독서학교」',
#        '도시와 건축으로 보는 개항과 근대의 우리 서울', '함께 읽는 노자 도덕경',
#        '다같이 돌자 지구 한 바퀴: 키르기스스탄', '코로나 이후 뉴노멀 세상 이야기',
#        '「방구석, 세계테마여행」:인문지리로 읽는 세계와 역사', '팬데믹시대, 슬기로운 자녀교육', '시소 함께 읽기',
#        '독서 독립 지도법', '「1일 1환경 챌린지」 저자 강연회', ']아무도 들어오지 마시오 함께 읽기',
#        '「그래프로 보는 도서관」 시청 소감 이벤트', '\xa0「여럿이 함께」 : 소중한 내 한 표!',
#        '북세통(BOOK, 세상과의 통로] 어린이', '내가 원하는 것을 나도 모를 때(with필사)'],
#       dtype=object)

# %%
import re
target = df['제목'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
text
# Out:
# ' 가족 이야기 톡 그림책 년 깨비독서회 회원모집 두근두근 우리들의 시점 학부모캠퍼스 그림책지도사 자격과정 빅히스토리와 지구의 미래 강좌 마감 가족 이야기 톡 그림책 월 북스타트 출발 한국사 탐험대 스마트폰 게임 찐갈등 제대로 학습법 한 학기 한 권 역사 읽기 운영 계획 다함께 책놀이 나는 매일 책 읽어주는 엄마입니다 저자강연회 친구와 함께하는 책놀이 당 근 독 당신 근처의 마을독서동아리 인공지능시대 새로운 그림책교육과 인문예술적 가치 지구를 지켜라 다 같이 돌자 지구 한 바퀴 베트남 방구석 세계테마여행 다같이 돌자 지구 한 바퀴 일본 청소년을 위한 대중매체 연계 특화자료 읽기 우리가족은 지구를 지겨요 여름독서교실 제 회 순국선열 나의 별이 되다 다같이 돌자 지구 한 바퀴 필리핀 긴긴밤 함께 읽기 인증샷 빅북과 함께 랜선으로 떠나는 다섯색깔이야기여행 로 알아보는 진로메타인지 행복하개 같이 살자옹 재택근무시대에 유용한 디지털도구배우기 년 우리 아이 첫 독서학교 도시와 건축으로 보는 개항과 근대의 우리 서울 함께 읽는 노자 도덕경 다같이 돌자 지구 한 바퀴 키르기스스탄 코로나 이후 뉴노멀 세상 이야기 방구석 세계테마여행 인문지리로 읽는 세계와 역사 팬데믹시대 슬기로운 자녀교육 시소 함께 읽기 독서 독립 지도법 일 환경 챌린지 저자 강연회 아무도 들어오지 마시오 함께 읽기 그래프로 보는 도서관 시청 소감 이벤트 여럿이 함께 소중한 내 한 표 북세통 세상과의 통로 어린이 내가 원하는 것을 나도 모를 때 필사 '

# %%
pd.set_option('display.max_row', 115)

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = []
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

df
# Out:
#         cnt
# 지구        7
# 이야기       4
# 그림책       4
# 우리        4
# 독서        4
# 바퀴        4
# 가족        3
# 시대        3
# 세계        3
# 여행        3
# 역사        2
# 인문        2
# 구석        2
# 테마        2
# 세상        2
# 비독        1
# 회원        1
# 모집        1
# 시점        1
# 학부모       1
# 캠퍼스       1
# 지도사       1
# 자격        1
# 과정        1
# 히스토리      1
# 미래        1
# 강좌        1
# 마감        1
# 스타트       1
# 출발        1
# 한국사       1
# 탐험대       1
# 스마트폰      1
# 게임        1
# 갈등        1
# 제대로       1
# 학습        1
# 학기        1
# 운영        1
# 계획        1
# 매일        1
# 엄마        1
# 자강        1
# 연회        1
# 친구        1
# 당신        1
# 근처        1
# 마을        1
# 동아리       1
# 인공        1
# 지능        1
# 교육        1
# 예술        1
# 가치        1
# 베트남       1
# 일본        1
# 청소년       1
# 대중매체      1
# 자료        1
# 여름        1
# 교실        1
# 순국선열      1
# 필리핀       1
# 인증샷       1
# 빅북        1
# 랜선        1
# 색깔        1
# 진로        1
# 메타        1
# 재택근무      1
# 디지털       1
# 도구        1
# 아이        1
# 학교        1
# 도시        1
# 건축        1
# 개항        1
# 근대        1
# 서울        1
# 노자        1
# 도덕경       1
# 키르기스스탄    1
# 코로나       1
# 이후        1
# 노멀        1
# 지리        1
# 팬데믹       1
# 자녀교육      1
# 시소        1
# 독립        1
# 도법        1
# 환경        1
# 린지        1
# 저자        1
# 강연        1
# 아무        1
# 그래프       1
# 도서관       1
# 시청        1
# 소감        1
# 이벤트       1
# 여럿        1
# 통로        1
# 어린이       1
# 필사        1

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =['빅히스토리','북스타트','강연회','지구','이야기','인공지능']
stop_word = [
'지구',
'이야기',
'우리',
'바퀴',
'시대',
'여행',
'구석',
'테마',
'세상',
'비독',
'회원',
'모집',
'시점',
'캠퍼스',
'과정',
'히스토리',
'마감',
'스타트',
'출발',
'탐험대',
'제대로',
'학기',
'운영',
'계획',
'매일',
'자강',
'연회',
'당신',
'근처',
'마을',
'가치',
'자료',
'여름',
'교실',
'인증샷',
'학교',
'이후',
'도법',
'린지',
'아무',
'그래프',
'도서관',
'시청',
'소감',
'이벤트',
'여럿',
'통로',
'노자',
'필사',
'순국선열',
'시소',
'메타',
'저자',
'키르기스스탄',
'빅북',
'도덕경',
'도구',
'인공',
'지능',
'독서'

]
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기


data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='AppleGothic')# 한글 폰트 설정

# %%
from wordcloud import WordCloud

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 4000, 
                      height = 3000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=100).generate_from_frequencies(data)
plt.figure(figsize = (11, 11))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 3999.5, 2999.5, -0.5)
