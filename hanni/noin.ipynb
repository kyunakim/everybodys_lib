# %%
import pandas as pd

df = pd.read_excel('../data/2022년(21년 실적) 공공도서관 통계데이터 최종.xlsx',
                )

df.head()
# Out:
#    번호   도서관명      구분  지역  시군구 설립주체         설립기관명 운영방식         운영기관명 분관내용  ...  \
# 0   1  더불어 숲  공공(일반)  대구   북구   사립  지역문화공간 더불어 숲   직영  지역문화공간 더불어 숲   본관  ...
# 1   2  가람도서관  공공(일반)  경기  파주시  지자체          파주시청   위탁     느티나무도서관재단   본관  ...
# 2   3  가양도서관  공공(일반)  대전   동구  지자체      대전광역시 동구   직영           NaN   본관  ...
# 3   4  가온도서관  공공(일반)  서울   중구  지자체        서울 중구청   위탁        중구문화재단   본관  ...
# 4   5  갈마도서관  공공(일반)  대전   서구  지자체      대전광역시서구청   직영           NaN   본관  ...
#
#    지식정보취약계층 관련 예산_노인(천원) 지식정보취약계층 관련 예산_다문화(천원) 어린이실 유무 어린이서비스이용자수 어린이자료수  \
# 0                   2100                      0       유        630  24500
# 1                      0                      0       유      63129  25762
# 2                      0                      0       유      46478  33151
# 3                      0                      0       유       3341  31953
# 4                    516                   2160       유      15771  81010
#
# ...

# %%
df.columns
# Out:
# Index(['번호', '도서관명', '구분', '지역', '시군구', '설립주체', '설립기관명', '운영방식', '운영기관명',
#        '분관내용',
#        ...
#        '지식정보취약계층 관련 예산_노인(천원)', '지식정보취약계층 관련 예산_다문화(천원)', '어린이실 유무',
#        '어린이서비스이용자수', '어린이자료수', '어린이연간증가자료수', '메타데이터 구축 건수_도서자료',
#        '메타데이터 구축 건수_연속간행물', '메타데이터 구축 건수_비도서자료', '메타데이터 구축 건수_기타'],
#       dtype='object', length=290)

# %%
df['구분'].unique()
# Out:
# array(['공공(일반)', '공공(어린이)'], dtype=object)

# %%
list(df)
# Out:
# ['번호',
#  '도서관명',
#  '구분',
#  '지역',
#  '시군구',
#  '설립주체',
#  '설립기관명',
#  '운영방식',
#  '운영기관명',
#  '분관내용',
#  '개관년도',
#  '주소',
#  '상세주소',
#  '전화번호',
#  '팩스',
#  '홈페이지',
#  '개관시간',
#  '휴관일',
#  '상위본관명',
#  '분류체계',
#  '목록형식_국내서',
#  '목록형식_국외서',
#  '목록규칙_국내서',
#  '목록규칙_국외서',
#  '저자기호_국내서',
#  '저자기호_국외서',
#  '도서관코드',
#  '이동도서관_도서관수',
#  '이동도서관_장서수',
#  '이동도서관_이용자수',
#  '작은도서관_협력도서관수',
#  '작은도서관_협력인력수',
#  '작은도서관_협력예산액',
#  '작은도서관_협력장서수',
#  '작은도서관_협력프로그램수',
#  '도서(인쇄)자료수_국내서_총류',
#  '도서(인쇄)자료수_국내서_철학',
#  '도서(인쇄)자료수_국내서_종교',
#  '도서(인쇄)자료수_국내서_사회과학',
#  '도서(인쇄)자료수_국내서_순수과학',
#  '도서(인쇄)자료수_국내서_기술과학',
#  '도서(인쇄)자료수_국내서_예술',
#  '도서(인쇄)자료수_국내서_언어',
#  '도서(인쇄)자료수_국내서_문학',
#  '도서(인쇄)자료수_국내서_역사',
#  '도서(인쇄)자료수_국외서_총류',
#  '도서(인쇄)자료수_국외서_철학',
#  '도서(인쇄)자료수_국외서_종교',
#  '도서(인쇄)자료수_국외서_사회과학',
#  '도서(인쇄)자료수_국외서_순수과학',
#  '도서(인쇄)자료수_국외서_기술과학',
#  '도서(인쇄)자료수_국외서_예술',
#  '도서(인쇄)자료수_국외서_언어',
#  '도서(인쇄)자료수_국외서_문학',
#  '도서(인쇄)자료수_국외서_역사',
#  '지역자료수_국내_지역자료',
#  '지역자료수_국내_기타',
#  '비도서자료수_국내외_시청각자료',
# ...

# %%
df['도서관명',
'구분',
'지역',
'시군구',
'좌석수_총좌석수_총좌석수',
'좌석수_총좌석수',
'총좌석수중노인및장애인열람석',
'회원등록자수_연령별회원등록_어린이',
'회원등록자수_연령별회원등록_청소년',
'회원등록자수_연령별회원등록_성인',
'가족단위회원등록자수',
'이용자수_도서관방문자수',
'이용자 교육_오프라인_교육건수',
'이용자 교육_오프라인_교육시간',
'이용자 교육_오프라인_교육참가자수',
'이용자 교육_온라인_교육건수',
'이용자 교육_온라인_교육시간',
'이용자 교육_온라인_교육참가자수',
'오프라인_문화프로그램_강좌수_실시횟수',
 '오프라인_문화프로그램_강좌수_참가자수',
 '오프라인_문화프로그램_1회성프로그램_실시횟수',
 '오프라인_문화프로그램_1회성프로그램_참가자수',
 '오프라인_도서관및독서관련프로그램_강좌수_실시횟수',
 '오프라인_도서관및독서관련프로그램_강좌수_참가자수',
 '오프라인_도서관및독서관련프로그램_1회성_실시횟수',
 '오프라인_도서관및독서관련프로그램_1회성_참가자수',
 '온라인_문화프로그램_강좌수_실시횟수',
 '온라인_문화프로그램_강좌수_참가자수',
 '온라인_문화프로그램_1회성프로그램_실시횟수',
 '온라인_문화프로그램_1회성프로그램_참가자수',
 '온라인_도서관및독서관련프로그램_강좌수_실시횟수',
 '온라인_도서관및독서관련프로그램_강좌수_참가자수',
 '온라인_도서관및독서관련프로그램_1회성_실시횟수',
 '온라인_도서관및독서관련프로그램_1회성_참가자수',
 '도서관 동아리_독서_동아리수',
 '도서관 동아리_학습_동아리수',
 '도서관 동아리_기타_동아리수',
 '도서관 동아리_독서_참가자수',
 '도서관 동아리_학습_참가자수',
 '도서관 동아리_기타_참가자수',
 '지식정보취약계층 봉사대상자수_장애인',
 '지식정보취약계층 봉사대상자수_노인',
 '지식정보취약계층 봉사대상자수_다문화',
 '지식정보취약계층 서비스 이용자수_장애인',
 '지식정보취약계층 서비스 이용자수_노인',
 '지식정보취약계층 서비스 이용자수_다문화',
 '도서관총예산(21년도 결산액)',
 '지식정보취약계층 관련 예산_장애인(천원)',
 '지식정보취약계층 관련 예산_노인(천원)',
 '지식정보취약계층 관련 예산_다문화(천원)',
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
