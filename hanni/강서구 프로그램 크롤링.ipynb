# %%
강동구 
강서구 
서초구
송파구
양천구
은평구
중구

# %%
import pandas as pd
ks_df = pd.DataFrame(columns = ['title','target','date'])
ks_df
# Out:
# Empty DataFrame
# Columns: [title, target, date]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호

for i in range(1,11): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    url = 'https://lib.gangseo.seoul.kr/LibProgramApply?libCode=TOL'
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    ks = requests.get(url, headers = headers)
    bs = BeautifulSoup(ks.text, 'html.parser')
    
    for j in range(2,22):
        try:
            title = bs.select_one('#app > div > div > section > section > article > div > section > article > div > div > ul > li:nth-child('+str(j)+') > div > span.cell.tit').text
            target = bs.select_one('#app > div > div > section > section > article > div > section > article > div > div > ul > li:nth-child('+str(j)+') > div > span.cell.ctg').text
            date = bs.select_one('#app > div > div > section > section > article > div > section > article > div > div > ul > li:nth-child('+str(j)+') > div > span:nth-child(5)').text
            ks_df.loc[ind] = [title, target, date]
            ind += 1
        except:
            pass


ks_df
# Out:
# Empty DataFrame
# Columns: [title, target, date]
# Index: []

# %%
j = j_df.copy()

# %%
j['date'] = j['date'].str.replace('\t','')
j['date'] = j['date'].str.replace('\n','')
j['date'] = j['date'].str.replace('\r','')
j
# Out:
#         lib                                title  \
# 0      신당누리  디지털 드로잉 프로그램 <내 손으로 만드는 신당누리도서관 굿즈>
# 1        가온                     취중JOB답:채용트렌드(1차)
# 2    손기정어린이                             나도 북큐레이터
# 3        가온                      취중JOB답:면접준비(3차)
# 4        가온                    취중JOB답:자소서작성법(2차)
# ..      ...                                  ...
# 271    다산성곽                  (접수중) 포토에세이 원데이 클래스
# 272      가온              9월 「문학산책 : 경혜원 작가와의 대화」
# 273   손기정문화       9월 토요예술무대 <힐링콘서트 : 그렇게 시작하는거야>
# 274      가온                      벽돌책읽기:우리본성의선한천사
# 275      가온  그림책과 함께하는 가온공방 <10월 컬러 클레이로 만드는 접시>
#
#                                                 target                   date
# 0    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...  2022.09.27~2022.09.30
# 1    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...             2022.10.05
# 2    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t...  2022.10.04~2022.10.25
# ...

# %%
j['target'] = j['target'].str.replace('\t','')
j['target'] = j['target'].str.replace('\n','')
j['target'] = j['target'].str.replace('\r','')
j
# Out:
#         lib                                title   target  \
# 0      신당누리  디지털 드로잉 프로그램 <내 손으로 만드는 신당누리도서관 굿즈>      청소년
# 1        가온                     취중JOB답:채용트렌드(1차)       성인
# 2    손기정어린이                             나도 북큐레이터      어린이
# 3        가온                      취중JOB답:면접준비(3차)       성인
# 4        가온                    취중JOB답:자소서작성법(2차)       성인
# ..      ...                                  ...      ...
# 271    다산성곽                  (접수중) 포토에세이 원데이 클래스       성인
# 272      가온              9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나
# 273   손기정문화       9월 토요예술무대 <힐링콘서트 : 그렇게 시작하는거야>      누구나
# 274      가온                      벽돌책읽기:우리본성의선한천사      누구나
# 275      가온  그림책과 함께하는 가온공방 <10월 컬러 클레이로 만드는 접시>       성인
#
#                       date
# 0    2022.09.27~2022.09.30
# 1               2022.10.05
# 2    2022.10.04~2022.10.25
# 3               2022.10.18
# 4               2022.10.11
# ..                     ...
# 271  2022.09.14~2022.09.25
# 272             2022.09.24
# ...

# %%
j.loc[13]
# Out:
# lib                     가온
# title     취중JOB답:채용트렌드(1차)
# target                  성인
# date            2022.10.05
# Name: 13, dtype: object

# %%
j.target.unique().tolist()
# Out:
# ['청소년', '성인', '어린이', '어린이,누구나', '누구나']

# %%
j.loc[j['target']=='어린이,누구나']
# Out:
#     lib                    title   target        date
# 8    가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 20   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 32   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 44   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 56   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 68   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 80   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 92   가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 104  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 116  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 128  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 140  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 152  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 164  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 176  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# 188  가온  9월 「문학산책 : 경혜원 작가와의 대화」  어린이,누구나  2022.09.24
# ...

# %%
j = j.replace('어린이,누구나', '전연령')

# %%
j = j.replace('누구나', '전연령')

# %%
j.target.value_counts()
# Out:
# 성인     115
# 어린이     69
# 전연령     69
# 청소년     23
# Name: target, dtype: int64

# %%
j.to_csv('j_all.csv',encoding="utf-8-sig", index=False)
