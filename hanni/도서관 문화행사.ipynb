# %%
import pandas as pd
df = pd.read_csv('(ㅆ최종)서울시 공공 도서관 문화행사.csv', encoding="utf-8-sig")

# %%
df
# Out:
#        지역                                          제목     대상
# 0     금천구  [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내    전연령
# 1     금천구                 [독산] 8월 문화가 있는날- 김해원 깊이읽기 4    어린이
# 2     금천구              [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내    전연령
# 3     금천구                 [독산] 7월 문화가 있는날- 김해원 깊이읽기 3     성인
# 4     금천구              [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행     성인
# ...   ...                                         ...    ...
# 5693  은평구                          [프로그램 ] 나를 치유하는 미술     성인
# 5694  은평구                [프로그램] "그림책 지도사 과정" 실시(접수마감)  국내이주민
# 5695  은평구                  [동아리] 어린이 독서/토론 '원페이지북' 모집    어린이
# 5696  은평구                  [동아리] 어린이 독서 동아리 '상상낙서' 모집    어린이
# 5697  은평구                  [동아리] 어린이 과학독서동아리 '메아리' 모집    어린이
#
# [5698 rows x 3 columns]

# %%
df.replace({'성인': '사회 초년생', '중장년': '시니어'}, inplace = True)

# %%
df
# Out:
#        지역                                          제목      대상
# 0     금천구  [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내     전연령
# 1     금천구                 [독산] 8월 문화가 있는날- 김해원 깊이읽기 4     어린이
# 2     금천구              [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내     전연령
# 3     금천구                 [독산] 7월 문화가 있는날- 김해원 깊이읽기 3  사회 초년생
# 4     금천구              [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행  사회 초년생
# ...   ...                                         ...     ...
# 5693  은평구                          [프로그램 ] 나를 치유하는 미술  사회 초년생
# 5694  은평구                [프로그램] "그림책 지도사 과정" 실시(접수마감)   국내이주민
# 5695  은평구                  [동아리] 어린이 독서/토론 '원페이지북' 모집     어린이
# 5696  은평구                  [동아리] 어린이 독서 동아리 '상상낙서' 모집     어린이
# 5697  은평구                  [동아리] 어린이 과학독서동아리 '메아리' 모집     어린이
#
# [5698 rows x 3 columns]
