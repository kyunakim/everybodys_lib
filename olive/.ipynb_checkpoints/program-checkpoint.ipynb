# %%
import pandas as pd

# %%
jan = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202101.csv')
feb = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202102.csv')
mar = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202103.csv')
apr = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202104.csv')
may = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202105.csv')
jun = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202106.csv')
jul = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202107.csv')
aug = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202108.csv')
sep = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202109.csv')
octo = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202110.csv')
nov = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202111.csv')
dec = pd.read_csv('/Users/thing/Desktop/dddd/NL_CUL_PROGRAM_202112.csv')

# %%
program = pd.concat([jan, feb, mar, apr, may, jun, jul, aug, sep, octo, nov, dec])

# %%
program
# Out:
#         no  lib_code                                       title  \
# 0       28      6100                         [비대면]성인 독서동아리 '어울림'
# 1       29      6100                               [비대면 정기강좌]펩아트
# 2       30      6100                         [비대면 정기강좌]시가 꽃피는 시간
# 3       31      6100                          [비대면 정기강좌]그림책 하브루타
# 4       32      6100                        [비대면]청소년 독서동아리 '두드림'
# ..     ...       ...                                         ...
# 951  43619     29990                      「독서교육」 그림책을 읽자 아이들을 읽자
# 952  43620      4505                         (아이와 행복한 소통) 그림책 육아
# 953  43621      4505  [공모] 2021 지식정보취약계층 도서관 서비스 개선 사업 - 나의 식물친구
# 954  43622      4505                             생각이 쑥쑥 행복한 동화나라
# 955  43623      4505                                  그림책 인형 공작소
#
#                  from_date                to_date  user_limit  \
# 0               2020-08-24             2020-09-03        20.0
# 1               2020-08-24             2020-09-03        30.0
# 2               2020-08-26             2020-09-03        30.0
# 3               2020-08-26             2020-09-03        15.0
# 4               2020-08-28             2020-09-03        15.0
# ..                     ...                    ...         ...
# 951  2021-08-18 12:00:00.0  2021-08-22 12:00:00.0        20.0
# 952  2021-08-03 12:00:00.0  2021-09-05 12:00:00.0        30.0
# 953  2021-08-31 12:00:00.0  2021-08-31 12:00:00.0         5.0
# 954  2021-10-28 12:00:00.0  2021-11-14 12:00:00.0        10.0
# 955  2021-11-15 12:00:00.0  2021-11-30 12:00:00.0        12.0
#
#             from_work_date           to_work_date price teacher_code  remark  \
# 0               2020-09-04             2020-12-06     0           24     NaN
# 1               2020-09-04             2020-12-06     0           25     NaN
# 2               2020-09-04             2020-11-06     0           26     NaN
# 3               2020-09-05             2020-10-31     0           27     NaN
# 4               2020-09-05             2020-10-31     0           28     NaN
# ..                     ...                    ...   ...          ...     ...
# 951  2021-09-02 12:00:00.0  2021-10-21 12:00:00.0     0       4711.0     NaN
# 952  2021-09-06 12:00:00.0  2021-09-06 12:00:00.0     0          NaN     NaN
# 953  2021-09-01 12:00:00.0  2021-10-27 12:00:00.0     0          NaN     NaN
# 954  2021-11-15 12:00:00.0  2021-12-13 12:00:00.0     0          NaN     NaN
# 955  2021-12-02 12:00:00.0  2021-12-23 12:00:00.0     0          NaN     NaN
#
#                 place work_time              target  \
# 0                 NaN         0                  성인
# 1                 NaN         0                  성인
# 2                 NaN         0                  성인
# 3                 NaN         0         초1~2 자녀와 부모
# 4                 NaN         0                 중학생
# ..                ...       ...                 ...
# 951       달성군립도서관 강좌실         0                  성인
# 952  실시간 온라인 수업(ZOOM)         0  0~7세 자녀를 둔 양육자 30명
# 953               NaN         0     서울정애학교 독서동아리 회원
# 954  실시간 온라인 수업(ZOOM)         0            6-7세 10명
# 955  실시간 온라인 수업(ZOOM)         0                  성인
#
#                                                content
# 0    2020 하반기 독서동아리 운영 (비대면 온라인 모임)   o 신청기간 : 8. 2...
# 1    2020 독서문화프로그램 하반기 정기강좌(8회 수업) o 신청기간 : 8. 26.(...
# 2    2020 독서문화프로그램 하반기 정기강좌(8회 수업) o 신청기간 : 8. 26.(...
# 3    2020 독서문화프로그램 하반기 정기강좌(8회 수업) o 신청기간 : 8. 26.(...
# 4    2020 하반기 독서동아리 운영 (비대면 온라인 모임)   o 신청기간 : 8. 2...
# ..                                                 ...
# 951                                               정보없음
# 952                                               정보없음
# 953                                               정보없음
# 954                                               정보없음
# 955                                               정보없음
#
# [41516 rows x 15 columns]

# %%
area = pd.read_csv('NL_CD_LIBRARY_202206 (3) (1).csv')
area
# Out:
#       LBRRY_CD      LBRRY_NM                LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1         1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                       ...        ...         ...
# 1386     33413  전라북도교육청무주도서관       전라북도 무주군 무주읍 향한로 37  36.010656  127.660441
# 1387     33414  전라북도교육청장수도서관       전라북도 장수군 장수읍 호비로 58  35.651032  127.521415
# 1388     33415  전라북도교육청임실도서관      전라북도 임실군 임실읍 봉황로 145  35.613882  127.278782
# 1389     33416  전라북도교육청순창도서관      전라북도 순창군 순창읍 장류로 379  35.376605  127.144051
# 1390     33417  전라북도교육청고창도서관     전라북도 고창군 고창읍 천변북로 109  35.434142  126.703975
#
#      ONE_AREA_NM TWO_AREA_NM  LBRRY_NO  API_LBRRY_NO         TELNO  ...  \
# 0            경기도         포천시  141333.0      141333.0  031-538-3911  ...
# 1            경기도         포천시  141172.0      141172.0  031-538-3952  ...
# 2            경기도         포천시  141094.0      141094.0  031-538-3932  ...
# 3            경기도         포천시  141102.0      141102.0  031-538-3945  ...
# 4            경기도         포천시  141520.0      141520.0  031-538-3972  ...
# ...          ...         ...       ...           ...           ...  ...
# 1386        전라북도         무주군  145006.0      145006.0  063-322-4635  ...
# 1387        전라북도         장수군  145015.0      145015.0  063-351-5488  ...
# 1388        전라북도         임실군  145014.0      145014.0  063-643-3525  ...
# 1389        전라북도         순창군  145008.0      145008.0  063-652-0994  ...
# 1390        전라북도         고창군  145001.0      145001.0  063-563-2720  ...
#
#      LBRRY_NCM_NM ETC_LBRRY_CD AREA_CD         ETC_LBRRY_ADDR  ETC_LBRRY_NM  \
# 0              중앙           MA       7    경기도 포천시 신북면 가채리 770     포천시립중앙도서관
# 1              소흘           MB       7  경기도 포천시 소흘읍 송우리 728-7     포천시립소흘도서관
# 2              일동           MC       7  경기도 포천시 일동면 기산리 284-3     포천시립일동도서관
# 3              영중           MD       7  경기도 포천시 영중면 양문리 833-2  포천시립영중어린이도서관
# 4              영북           ME       7  경기도 포천시 영북면 운천리 540-2    포천시립영북도서관
# ...           ...          ...     ...                    ...           ...
# 1386          NaN           MR       9                    NaN           NaN
# 1387          NaN           MS       9                    NaN           NaN
# 1388          NaN           MT       9                    NaN           NaN
# 1389          NaN           MU       9                    NaN           NaN
# 1390          NaN           MV       9                    NaN           NaN
#
#      TWO_ETC_LBRRY_NM REPRSNT_YN ONE_AREA_CD TWO_AREA_CD WETHER_ARCD
# 0           포천시립중앙도서관          Y         경기도         포천시         동두천
# 1               소흘도서관          N         경기도         포천시         동두천
# 2               일동도서관          N         경기도         포천시         동두천
# 3            영중꿈나무도서관          N         경기도         포천시         동두천
# 4               영북도서관          N         경기도         포천시         동두천
# ...               ...        ...         ...         ...         ...
# 1386              NaN          N        전라북도         무주군          무주
# 1387              NaN          N        전라북도         장수군          장수
# 1388              NaN          N        전라북도         임실군          임실
# 1389              NaN          N        전라북도         순창군          복흥
# 1390              NaN          N        전라북도         고창군          고창
#
# [1391 rows x 34 columns]

# %%
area = area[['LBRRY_CD', 'LBRRY_NM', 'ONE_AREA_NM','TWO_AREA_NM']]
area
# Out:
#       LBRRY_CD      LBRRY_NM ONE_AREA_NM TWO_AREA_NM
# 0         1500     포천시립중앙도서관         경기도         포천시
# 1         1501     포천시립소흘도서관         경기도         포천시
# 2         1502     포천시립일동도서관         경기도         포천시
# 3         1503  포천시립영중꿈나무도서관         경기도         포천시
# 4         1504     포천시립영북도서관         경기도         포천시
# ...        ...           ...         ...         ...
# 1386     33413  전라북도교육청무주도서관        전라북도         무주군
# 1387     33414  전라북도교육청장수도서관        전라북도         장수군
# 1388     33415  전라북도교육청임실도서관        전라북도         임실군
# 1389     33416  전라북도교육청순창도서관        전라북도         순창군
# 1390     33417  전라북도교육청고창도서관        전라북도         고창군
#
# [1391 rows x 4 columns]

# %%
area.rename(columns={'LBRRY_CD':'lib_code'}, inplace=True)
area
# Out:
# /var/folders/_8/kpzxjvhd1fngdcdmt3xb1hym0000gn/T/ipykernel_98125/2002324875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   area.rename(columns={'LBRRY_CD':'lib_code'}, inplace=True)
#       lib_code      LBRRY_NM ONE_AREA_NM TWO_AREA_NM
# 0         1500     포천시립중앙도서관         경기도         포천시
# 1         1501     포천시립소흘도서관         경기도         포천시
# 2         1502     포천시립일동도서관         경기도         포천시
# 3         1503  포천시립영중꿈나무도서관         경기도         포천시
# 4         1504     포천시립영북도서관         경기도         포천시
# ...        ...           ...         ...         ...
# 1386     33413  전라북도교육청무주도서관        전라북도         무주군
# 1387     33414  전라북도교육청장수도서관        전라북도         장수군
# 1388     33415  전라북도교육청임실도서관        전라북도         임실군
# 1389     33416  전라북도교육청순창도서관        전라북도         순창군
# 1390     33417  전라북도교육청고창도서관        전라북도         고창군
#
# [1391 rows x 4 columns]

# %%
culture_program = pd.merge(area, program, on='lib_code', how='inner')
culture_program
# Out:
#        lib_code       LBRRY_NM ONE_AREA_NM TWO_AREA_NM     no  \
# 0          1500      포천시립중앙도서관         경기도         포천시   7793
# 1          1500      포천시립중앙도서관         경기도         포천시   8427
# 2          1500      포천시립중앙도서관         경기도         포천시   8428
# 3          1500      포천시립중앙도서관         경기도         포천시   8434
# 4          1500      포천시립중앙도서관         경기도         포천시   8435
# ...         ...            ...         ...         ...    ...
# 41171     31117  경상남도교육청 합천도서관        경상남도         합천군  11967
# 41172     31117  경상남도교육청 합천도서관        경상남도         합천군  12061
# 41173     31117  경상남도교육청 합천도서관        경상남도         합천군  41721
# 41174     31117  경상남도교육청 합천도서관        경상남도         합천군  41899
# 41175     31117  경상남도교육청 합천도서관        경상남도         합천군  42634
#
#                                    title              from_date  \
# 0       [전국책읽는도시협의회]'낭만 in 도서관' - 낭만 영화관  2021-08-06 12:00:00.0
# 1      [2021 독서의 달]그림책과 뉴스로 배우는 미디어 탐구생활  2021-08-17 12:00:00.0
# 2           [2021 독서의 달]학부모를 위한 미디어 리터러시  2021-08-17 12:00:00.0
# 3      [2021 독서의 달]체험행사 <반짝반짝 빛나는> '아이편'  2021-09-01 12:00:00.0
# 4      [2021 독서의 달]체험행사 <반짝반짝 빛나는> '어른편'  2021-09-01 12:00:00.0
# ...                                  ...                    ...
# 41171                            그림책 공작소  2021-09-17 12:00:00.0
# 41172                           그림책 보드게임  2021-09-17 12:00:00.0
# 41173                       도서관에서 역사랑 놀자  2021-10-19 12:00:00.0
# 41174                         마술과 그림자 공연  2021-11-09 12:00:00.0
# 41175                         마술과 그림자 공연  2021-11-09 12:00:00.0
#
#                      to_date  user_limit         from_work_date  \
# 0      2021-08-19 12:00:00.0        20.0  2021-08-20 12:00:00.0
# 1      2021-08-31 12:00:00.0        20.0  2021-09-01 12:00:00.0
# 2      2021-08-31 12:00:00.0        20.0  2021-09-01 12:00:00.0
# 3      2021-09-30 12:00:00.0        50.0  2021-09-01 12:00:00.0
# 4      2021-09-30 12:00:00.0        50.0  2021-09-01 12:00:00.0
# ...                      ...         ...                    ...
# 41171  2021-09-30 12:00:00.0        10.0  2021-10-16 12:00:00.0
# 41172  2021-09-30 12:00:00.0        10.0  2021-10-08 12:00:00.0
# 41173  2021-10-28 12:00:00.0        10.0  2021-10-30 12:00:00.0
# 41174  2021-11-26 12:00:00.0        40.0  2021-11-27 12:00:00.0
# 41175  2021-11-26 12:00:00.0        40.0  2021-11-27 12:00:00.0
#
#                 to_work_date price teacher_code  remark              place  \
# 0      2021-08-27 12:00:00.0   NaN          NaN     NaN           온라인 ZOOM
# 1      2021-09-29 12:00:00.0   NaN          NaN     NaN          온라인(ZOOM)
# 2      2021-09-29 12:00:00.0   NaN          NaN     NaN                  줌
# 3      2021-09-30 12:00:00.0   NaN          NaN     NaN             어린이자료실
# 4      2021-09-30 12:00:00.0   NaN          NaN     NaN              종합자료실
# ...                      ...   ...          ...     ...                ...
# 41171  2021-12-04 12:00:00.0    0원          NaN     NaN  합천도서관 본관 2층 평생학습실
# 41172  2021-11-26 12:00:00.0    0원          NaN     NaN  합천도서관 본관 2층 평생학습실
# 41173  2021-11-13 12:00:00.0    0원          NaN     NaN         2층 시청각 자료실
# 41174  2021-11-27 12:00:00.0    0원          NaN     NaN   합천도서관 본관 2층 시청각실
# 41175  2021-11-27 12:00:00.0    0원          NaN     NaN   합천도서관 본관 2층 시청각실
#
#             work_time    target content
# 0         19:00~21:30        성인    정보없음
# 1         16:30~18:00  초등 4~6학년    정보없음
# 2         14:00~16:00        성인    정보없음
# 3         09:00~21:00        아동    정보없음
# 4         09:00~21:00  청소년 ~ 성인    정보없음
# ...               ...       ...     ...
# 41171  토  10:00~12:20  하반기 평생학습    정보없음
# 41172  금  15:53~17:73  하반기 평생학습    정보없음
# 41173  토  10:00~12:20     문화/예술    정보없음
# 41174  토  14:40~15:50     문화/예술    정보없음
# 41175  토  14:40~15:50     문화/예술    정보없음
#
# [41176 rows x 18 columns]

# %%
culture_program.drop(labels=['no', 'price','teacher_code','remark', 'work_time', 'content','user_limit','from_date', 'to_date', 'from_work_date','to_work_date'], axis=1, inplace=True)

# %%
culture_program['TWO_AREA_NM'].unique()
# Out:
# array(['포천시', '서구', '동대문구', '양산시', '영등포구', '중구', '서초구', '강서구', '양천구',
#        '서대문구', '송파구', '부천시', '강남구', '안성시', '천안시 동남구', '천안시 서북구',
#        '고양시 일산동구', '고양시 덕양구', '고양시 일산서구', '도담동', '원주시', '강릉시', '정선군',
#        '삼척시', '속초시', '춘천시', '양양군', '태백시', '홍천군', '횡성군', '평창군', '철원군',
#        '화천군', '인제군', '고성군', '동해시', '도봉구', '남구', '북구', '양주시', '청주시 상당구',
#        '은평구', '동두천시', '김포시', '의정부시', '화성시', '홍성군', '군산시', '용산구', '강동구',
#        '김해시', '성남시 분당구', '성남시 수정구', '성남시 중원구', '구미시', '영도구', '시흥시',
#        '창원시 의창구', '동작구', '동구', '달성군', '부여군', '구례군', '무주군', '남해군', '과천시',
#        '거창군', '공주시', '창원시', '사천시', '산청군', '의령군', '진주시', '밀양시', '함안군',
#        '함양군', '합천군'], dtype=object)

# %%
program_ggd = culture_program[culture_program['ONE_AREA_NM']=='경기도']

# %%
program_ggd
# Out:
#        lib_code   LBRRY_NM ONE_AREA_NM TWO_AREA_NM  \
# 0          1500  포천시립중앙도서관         경기도         포천시
# 1          1500  포천시립중앙도서관         경기도         포천시
# 2          1500  포천시립중앙도서관         경기도         포천시
# 3          1500  포천시립중앙도서관         경기도         포천시
# 4          1500  포천시립중앙도서관         경기도         포천시
# ...         ...        ...         ...         ...
# 39978      1506  포천시립선단도서관         경기도         포천시
# 39979      1506  포천시립선단도서관         경기도         포천시
# 39980      1506  포천시립선단도서관         경기도         포천시
# 39981      1506  포천시립선단도서관         경기도         포천시
# 39982      1506  포천시립선단도서관         경기도         포천시
#
#                                     title          place            target
# 0        [전국책읽는도시협의회]'낭만 in 도서관' - 낭만 영화관       온라인 ZOOM                성인
# 1       [2021 독서의 달]그림책과 뉴스로 배우는 미디어 탐구생활      온라인(ZOOM)          초등 4~6학년
# 2            [2021 독서의 달]학부모를 위한 미디어 리터러시              줌                성인
# 3       [2021 독서의 달]체험행사 <반짝반짝 빛나는> '아이편'         어린이자료실                아동
# 4       [2021 독서의 달]체험행사 <반짝반짝 빛나는> '어른편'          종합자료실          청소년 ~ 성인
# ...                                   ...            ...               ...
# 39978  [독서의달 프로그램]작곡이 처음인데 노래를 만들 수 있다고요?     비대면 ZOOM강의             성인10명
# 39979         [2021 독서의 달]체험행사 <반짝반짝 빛나는>          종합자료실          청소년 ~ 성인
# 39980         [2021 독서의 달]체험행사 <반짝반짝 빛나는>         어린이자료실                아동
# 39981   2021하반기 독서문화프로그램 장르소설 개요부터 시놉시스까지     ZOOM온라인 수업    장르소설을 배우고싶은 성인
# 39982            공공도서관 문화가 있는 날 비대면 온라인공연  유튜브 URL 문자 발송  음악과 마술을 좋아하는 누구나
#
# [36001 rows x 7 columns]

# %%
program_ggd['TWO_AREA_NM'].unique()
# Out:
# array(['포천시', '부천시', '안성시', '고양시 일산동구', '고양시 덕양구', '고양시 일산서구', '양주시',
#        '동두천시', '김포시', '의정부시', '화성시', '성남시 분당구', '성남시 수정구', '성남시 중원구',
#        '시흥시', '과천시'], dtype=object)

# %%
program_ggd_north = program_ggd[program_ggd['TWO_AREA_NM']==('포천시'or '고양시 일산동구' or '고양시 덕양구' or'고양시 일산서구'or'양주시'or'동두천시'or'김포시'or'의정부시')]
program_ggd_north
# Out:
#        lib_code   LBRRY_NM ONE_AREA_NM TWO_AREA_NM  \
# 0          1500  포천시립중앙도서관         경기도         포천시
# 1          1500  포천시립중앙도서관         경기도         포천시
# 2          1500  포천시립중앙도서관         경기도         포천시
# 3          1500  포천시립중앙도서관         경기도         포천시
# 4          1500  포천시립중앙도서관         경기도         포천시
# ...         ...        ...         ...         ...
# 39978      1506  포천시립선단도서관         경기도         포천시
# 39979      1506  포천시립선단도서관         경기도         포천시
# 39980      1506  포천시립선단도서관         경기도         포천시
# 39981      1506  포천시립선단도서관         경기도         포천시
# 39982      1506  포천시립선단도서관         경기도         포천시
#
#                                     title          place            target
# 0        [전국책읽는도시협의회]'낭만 in 도서관' - 낭만 영화관       온라인 ZOOM                성인
# 1       [2021 독서의 달]그림책과 뉴스로 배우는 미디어 탐구생활      온라인(ZOOM)          초등 4~6학년
# 2            [2021 독서의 달]학부모를 위한 미디어 리터러시              줌                성인
# 3       [2021 독서의 달]체험행사 <반짝반짝 빛나는> '아이편'         어린이자료실                아동
# 4       [2021 독서의 달]체험행사 <반짝반짝 빛나는> '어른편'          종합자료실          청소년 ~ 성인
# ...                                   ...            ...               ...
# 39978  [독서의달 프로그램]작곡이 처음인데 노래를 만들 수 있다고요?     비대면 ZOOM강의             성인10명
# 39979         [2021 독서의 달]체험행사 <반짝반짝 빛나는>          종합자료실          청소년 ~ 성인
# 39980         [2021 독서의 달]체험행사 <반짝반짝 빛나는>         어린이자료실                아동
# 39981   2021하반기 독서문화프로그램 장르소설 개요부터 시놉시스까지     ZOOM온라인 수업    장르소설을 배우고싶은 성인
# 39982            공공도서관 문화가 있는 날 비대면 온라인공연  유튜브 URL 문자 발송  음악과 마술을 좋아하는 누구나
#
# [63 rows x 7 columns]

# %%
program_ggd_south = program_ggd[program_ggd['TWO_AREA_NM']==('부천시'or '안성시'or'화성시'or'성남시 분당구'or '성남시 수정구'or '성남시 중원구'or '시흥시'or '과천시')]
program_ggd_south
# Out:
#       lib_code   LBRRY_NM ONE_AREA_NM TWO_AREA_NM  \
# 239       4300  부천시립상동도서관         경기도         부천시
# 240       4300  부천시립상동도서관         경기도         부천시
# 241       4300  부천시립상동도서관         경기도         부천시
# 242       4300  부천시립상동도서관         경기도         부천시
# 243       4300  부천시립상동도서관         경기도         부천시
# ...        ...        ...         ...         ...
# 4290      4342  부천시립역곡도서관         경기도         부천시
# 4291      4342  부천시립역곡도서관         경기도         부천시
# 4292      4342  부천시립역곡도서관         경기도         부천시
# 4293      4342  부천시립역곡도서관         경기도         부천시
# 4294      4342  부천시립역곡도서관         경기도         부천시
#
#                                    title              place       target
# 239           (온라인_상동) 2021년 시민작가교실 회원모집  온라인(유튜브, 네이버까페 등)           성인
# 240   [유명작가콘서트] 황영미작가의 「체리새우: 비밀글입니다」 강연        온라인 줌(ZOOM)  청소년(중,고등학교)
# 241                 (비대면)창의통통 동화로 색종이 접기                유튜브  유아 및 초등 저학년
# 242                     (비대면)잼난 집콕 미술 놀이               zoom     초등 1-2학년
# 243               (비대면) 나도 3D 모델링 전문가(1)               zoom     초등 3-4학년
# ...                                  ...                ...          ...
# 4290                            세계 시민 교육        온라인강의(zoom)         초등학생
# 4291                 [클래식 특강] 오선지 위의 인문학        온라인강의(zoom)          누구나
# 4292                          하브루타 독서 수업        온라인강의(zoom)         초등학생
# 4293                           그림책 원예 교실        온라인강의(zoom)           성인
# 4294                              세계시민교육                NaN     초등 4~6학년
#
# [331 rows x 7 columns]

# %%
program_ggd_south['title'].describe()
# Out:
# count                 331
# unique                315
# top       교구와 창의 수학(겨울방학)
# freq                    2
# Name: title, dtype: object

# %%
program_ggd_north['title'].describe()
# Out:
# count                              63
# unique                             54
# top       [2021 독서의 달]체험행사 <반짝반짝 빛나는>
# freq                                4
# Name: title, dtype: object

# %%
clean_data = program_ggd_north['title'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# %%
import numpy as np 

clean_data = clean_data.replace({'': np.nan})
clean_data = clean_data.replace(r'^\s*$', None, regex=True)

# %%
clean_data.dropna(how='any', inplace=True)

# %%
clean_data = clean_data.reset_index (drop = True)

# %%
clean_data
# Out:
# 0        전국책읽는도시협의회  낭만    도서관    낭만 영화관
# 1            독서의 달 그림책과 뉴스로 배우는 미디어 탐구생활
# 2                 독서의 달 학부모를 위한 미디어 리터러시
# 3            독서의 달 체험행사  반짝반짝 빛나는   아이편
# 4            독서의 달 체험행사  반짝반짝 빛나는   어른편
#                      ...
# 58     독서의달 프로그램 작곡이 처음인데 노래를 만들 수 있다고요
# 59                 독서의 달 체험행사  반짝반짝 빛나는
# 60                 독서의 달 체험행사  반짝반짝 빛나는
# 61         하반기 독서문화프로그램 장르소설 개요부터 시놉시스까지
# 62              공공도서관 문화가 있는 날 비대면 온라인공연
# Name: title, Length: 63, dtype: object

# %%
import konlpy

# %%
from konlpy.tag import Okt

# %%
text = "".join(clean_data)
text
# Out:
# ' 전국책읽는도시협의회  낭만    도서관    낭만 영화관      독서의 달 그림책과 뉴스로 배우는 미디어 탐구생활      독서의 달 학부모를 위한 미디어 리터러시      독서의 달 체험행사  반짝반짝 빛나는   아이편       독서의 달 체험행사  반짝반짝 빛나는   어른편  전국책읽는도시협의회  낭만    도서관    낭만 문학관입문자를 위한 그림책 이야기 평생학습관 프로그램  전국책읽는도시협의회  낭만    도서관    낭만 미술관 전국책읽는도시협의회  낭만    도서관    낭만 음악관     년 하반기 독서문화 나의 이야기  나의 책   독립출판     년 하반기 독서문화 도서관에서 과학하기   공룡시대 전국책읽는도시협의회  낭만    도서관    낭만 음악회송년체험행사 도서관에    책  온책읽기  어른편 송년체험행사 도서관에    책  온책읽기  아이편 안녕  외계인 작가님 박연철 작가와의 만남       독서의 달 체험행사  반짝반짝 빛나는       독서의 달 체험행사  반짝반짝 빛나는      북스타트 부모교육 강연    년 송년행사  엄마와 함께 크리스마스 선물만들기    월   일    년 송년행사  엄마와 함께 크리스마스 선물만들기    월   일    년 송년행사  책과 함께 떠나는 크리스마스 여행     년 송년행사  이종철 작가와의 만남  월 문화가 있는 날   유하정 작가와의 만남 월 문화가 있는 날   정순희 작가와의 만남독서의 달 체험행사  반짝반짝 빛나는   아이편 독서의 달 체험행사  반짝반짝 빛나는   어른편  월 문화가 있는 날   정진호 작가와의 만남 월 문화가 있는 날   정진호 작가와의 만남  월 문화가 있는 날   백온유 작가와의 만남  월 문화가 있는 날   사이다 작가와의 만남  월 문화가 있는 날   김개미 작가와의 만남  월 문화가 있는 날   이현 작가와의 만남송년체험행사 도서관에    책  온책읽기  아이편 송년체험행사 도서관에    책  온책읽기  어른편     년 독서의 달   체험행사   반짝반짝 빛나는    어른편     년 독서의 달   체험행사   반짝반짝 빛나는    아이편     년 독서의 달   분야별 문학책 잘 읽기  조대한 문학평론가 특강     년 독서의 달   사람과 사회를 향한 관심의 글쓰기  은유 작가와의 만남     년 독서의 달   책 속으로 모험을 떠나자  김남중 작가와의 만남     년 독서의 달   체험행사  반짝반짝 빛나는   어른편     년 독서의 달   체험행사  반짝반짝 빛나는   아이편 이원석 작가와의 만남   서평 쓰는 법포천 북살롱  기 코스모스 함께 읽기    년 하반기 독서문화프로그램   나를 찾아 떠나는 여행  에니어그램 포천 북살롱  기 죄와벌 함께 읽기최소희 작가와의 만남 포천시 독서동아리 네트워크 작가강연 지원 프로그램조민영 작가와의 만남 포천시 독서동아리 네트워크 작가강연 지원 프로그램남낙현 작가와의 만남 포천시 독서동아리 네트워크 작가강연 지원 프로그램원은정 작가와의 만남 포천시 독서동아리 네트워크 작가강연 지원 프로그램이지현 작가와의 만남 포천시 독서동아리 네트워크 작가강연 지원 프로그램송년체험행사 도서관에    책  온책읽기  어른편 송년체험행사 도서관에    책  온책읽기  아이편  독서의달 프로그램 이석구 작가와의 만남      독서의 달 체험행사  반짝반짝 빛나는   어른편       독서의 달 체험행사  반짝반짝 빛나는    아이편     하반기 독서문화프로그램 초보자를 위한 이모티콘 만들기선단도서관 길 위의 인문학  팬데믹시대 치유를 위한 포천인문학강의 선단도서관 독서토론 리더심화과정  선단책방  수강생 모집 독서의달 프로그램 작곡이 처음인데 노래를 만들 수 있다고요       독서의 달 체험행사  반짝반짝 빛나는       독서의 달 체험행사  반짝반짝 빛나는     하반기 독서문화프로그램 장르소설 개요부터 시놉시스까지공공도서관 문화가 있는 날 비대면 온라인공연'

# %%
# file = open("text.txt", "w") 
# file.write(text)
# file.close()
#다시 켤 떄 저장된 파일로 하기 
# file = open("text.txt", "r") 
# text = file.read()

# %%
#konlpy(코엔엘파이) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word=['포천시','정진호','이종철','문화','체험','행사','전국책','추가','시작','강좌','비대','면', '도서관', '프로그램', '강의', '모집', '교실', '작가' ,'접수', '화상', '대면','부천','특강','독서','하반기']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)
        

count = Counter(noun_list) #단어별 숫자세주기


#most_common() > 데이터의 개수가 많은 순으로 정렬된 배열을 리턴하는 메서드
#인자로 숫자 n을 넘기면 그 숫자 만큼만 리턴하기 때문에, 가장 개수가 많은 n개의 데이터를 얻을 수도 있습니다.
#(글자, 나온 횟수)를 요소로 가진 리스트를 반환함
data =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data)
df = pd.DataFrame(series, columns=['cnt'])

df = df.reset_index()
df.head(50)

#data10 = df[:10]
#data10
# Out:
#     index  cnt
# 0      만남   18
# 1      낭만   10
# 2      아이    8
# 3      어른    8
# 4      송년    8
# 5      강연    6
# 6      도시    5
# 7      협의    5
# 8     포천시    5
# 9     동아리    5
# 10   네트워크    5
# 11     지원    5
# 12  크리스마스    3
# 13    만들기    3
# 14     포천    3
# 15     선단    3
# 16    그림책    2
# 17    미디어    2
# 18    이야기    2
# 19     음악    2
# 20     엄마    2
# 21     선물    2
# 22     여행    2
# 23     살롱    2
# 24    인문학    2
# 25    영화관    1
# 26     뉴스    1
# 27   탐구생활    1
# 28    학부모    1
# 29     리터    1
# 30     러시    1
# 31    문학관    1
# 32     입문    1
# 33     평생    1
# 34     습관    1
# 35    미술관    1
# 36     독립    1
# 37     출판    1
# 38     과학    1
# 39   공룡시대    1
# 40     회송    1
# 41     안녕    1
# 42    외계인    1
# 43     박연    1
# 44    스타트    1
# 45     부모    1
# 46     교육    1
# 47    유하정    1
# 48    정순희    1
# 49     온유    1

# %%
from wordcloud import WordCloud
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns

#generate_from_frequencies 미리 정의된 단어의 빈도수 dict를 이용하여 워드 클라우드를 그림
#  워드 클라우드를 generate할 때 마다 스타일이 미세하게 다르게 형성되는데,random_state 인자를 지정해주면 생성할 때마다 완전히 동일한 결과
wordcloud = WordCloud(font_path='GmarketSansTTFBold.ttf', width= 4000, 
                      height = 3000, random_state=1, background_color='white', 
                      colormap='Dark2', max_words=161).generate_from_frequencies(data)
plt.figure(figsize = (11, 11))
plt.imshow(wordcloud) #이미지 표시
plt.axis('off') #축 지우기
# Out:
# (-0.5, 3999.5, 2999.5, -0.5)
