# %% [markdown]
# 불필요한 컬럼 삭제 후 csv파일로 저장

# %%
import pandas as pd
df = pd.read_csv('NL_CD_LIBRARY_202206.csv')
df
# Out:
#       LBRRY_CD      LBRRY_NM                LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1         1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                       ...        ...         ...
# 1386     33413  전라북도교육청무주도서관       전라북도 무주군 무주읍 향한로 37  36.010656  127.660441
# 1387     33414  전라북도교육청장수도서관       전라북도 장수군 장수읍 호비로 58  35.651032  127.521415
# 1388     33415  전라북도교육청임실도서관      전라북도 임실군 임실읍 봉황로 145  35.613882  127.278782
# 1389     33416  전라북도교육청순창도서관      전라북도 순창군 순창읍 장류로 379  35.376605  127.144051
# 1390     33417  전라북도교육청고창도서관     전라북도 고창군 고창읍 천변북로 109  35.434142  126.703975
#
# ...

# %% [markdown]
# ![Screen Shot 2022-08-21 at 3.58.54 PM.png](attachment:d083304d-5d9f-4053-b660-a52513881eb8.png)
#
# ```
# 초록: 살려
# 빨랑: 죽여
# 파랑: 나중에필요할지도..하지만일단죽여
# ```

# %%
basic_info = df.drop(columns =["LBRRY_NO", "API_LBRRY_NO", "TELNO", "FXNO", "ZIP", "FOND_MBY_VALUE", "X_CORT_VLUE", "Y_CORT_VLUE", "MUMM_LON_YEAR", "OPNNG_TIME","CLOSEDON_DC","LBRRY_NCM_NM", "ETC_LBRRY_NM", "TWO_ETC_LBRRY_NM", "ONE_AREA_CD","TWO_AREA_CD", "ETC_LBRRY_CD", "AREA_CD", "ETC_LBRRY_ADDR", "BSNS_PARTCPTN_YEAR", "MASTR_LBRRY_CD", "OPNNG_YEAR", "HMPG_VALUE", "WETHER_ARCD","REPRSNT_YN", "LBRRY_TY_CD" ], axis=1)

# %% [markdown]
# ![Screen Shot 2022-08-21 at 3.59.44 PM.png](attachment:14dce256-252d-4051-aeec-1c1669c50d41.png)

# %%
basic_info.to_csv('도서관정보.csv')

# %%
basic_info_rep = df1[df1['REPRSNT_YN']=='Y'] #대표도서관
basic_info_rep.to_csv('대표도서관.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 basic_info_rep = df1[df1['REPRSNT_YN']=='Y'] #대표도서관
#       2 basic_info_rep.to_csv('대표도서관.csv')
#
# NameError: name 'df1' is not defined

# %%
basic_info
# Out:
#       LBRRY_CD      LBRRY_NM                LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0         1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1         1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2         1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3         1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4         1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...        ...           ...                       ...        ...         ...
# 1386     33413  전라북도교육청무주도서관       전라북도 무주군 무주읍 향한로 37  36.010656  127.660441
# 1387     33414  전라북도교육청장수도서관       전라북도 장수군 장수읍 호비로 58  35.651032  127.521415
# 1388     33415  전라북도교육청임실도서관      전라북도 임실군 임실읍 봉황로 145  35.613882  127.278782
# 1389     33416  전라북도교육청순창도서관      전라북도 순창군 순창읍 장류로 379  35.376605  127.144051
# 1390     33417  전라북도교육청고창도서관     전라북도 고창군 고창읍 천변북로 109  35.434142  126.703975
#
# ...

# %%
country = '대한민국'
basic_info['국가'] = country

# %%
basic_info.head()
# Out:
#    LBRRY_CD      LBRRY_NM                LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0      1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1      1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2      1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3      1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4      1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
#
#   ONE_AREA_NM TWO_AREA_NM LBRRY_TY_NM    국가
# 0         경기도         포천시          공공  대한민국
# 1         경기도         포천시          공공  대한민국
# 2         경기도         포천시          공공  대한민국
# 3         경기도         포천시          공공  대한민국
# 4         경기도         포천시          공공  대한민국

# %%
basic_info.columns
# Out:
# Index(['LBRRY_CD', 'LBRRY_NM', 'LBRRY_ADDR', 'LBRRY_LA', 'LBRRY_LO',
#        'ONE_AREA_NM', 'TWO_AREA_NM', 'LBRRY_TY_NM', '국가'],
#       dtype='object')

# %%
basic_info.columns = ['도서관 코드','도서관명','주소','위도','경도','시도','시군구','종류','국가']
basic_info
# Out:
#       도서관 코드          도서관명                        주소         위도          경도  \
# 0       1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1       1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2       1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3       1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4       1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
# ...      ...           ...                       ...        ...         ...
# 1386   33413  전라북도교육청무주도서관       전라북도 무주군 무주읍 향한로 37  36.010656  127.660441
# 1387   33414  전라북도교육청장수도서관       전라북도 장수군 장수읍 호비로 58  35.651032  127.521415
# 1388   33415  전라북도교육청임실도서관      전라북도 임실군 임실읍 봉황로 145  35.613882  127.278782
# 1389   33416  전라북도교육청순창도서관      전라북도 순창군 순창읍 장류로 379  35.376605  127.144051
# 1390   33417  전라북도교육청고창도서관     전라북도 고창군 고창읍 천변북로 109  35.434142  126.703975
#
#         시도  시군구  종류    국가
# 0      경기도  포천시  공공  대한민국
# ...

# %%
lib = pd.pivot_table(basic_info,
                      index = ['국가','시도','시군구'],
                      values = '도서관명',
                      aggfunc = 'sum')
lib
# Out:
#                                                              도서관명
# 국가   시도   시군구
# 대한민국 강원도  강릉시                                      강릉교육문화관명주교육도서관
#           고성군                                             고성교육도서관
#           동해시      동해교육도서관동해시립북삼도서관동해시립발한도서관이도작은도서관무릉작은도서관등대작은도서관
#           삼척시                                             삼척교육문화관
#           속초시                       속초교육문화관속초교육도서관속초시립도서관풀이음작은도서관
# ...                                                           ...
#      충청북도 청주시 상당구                     미원교육도서관청주시립도서관(임시청사)청주상당도서관
#           청주시 서원구                        충청북도교육도서관청주서원도서관청주기적의도서관
#           청주시 청원구                충청북도교육문화원청주청원도서관청주오창도서관청주오창호수도서관
#           청주시 흥덕구         청주오송도서관청주흥덕도서관청주신율봉어린이도서관청주강내도서관청주옥산도서관
#           충주시                                  충청북도중원교육문화원중원교육도서관
#
# [258 rows x 1 columns]

# %%
lib.to_csv('lib.csv')
