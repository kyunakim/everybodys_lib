# %%
노원 종로 광진 동작 관악 중랑

# %%
import pandas as pd

# %%
seoul= pd.read_csv('처음에받아온데이터서울만뽑음.csv')
nowon= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/nowon.csv')
jongno= pd.read_csv('/Users/thing/DATA_ANALYSIS/998. projects/2. git/daemawang/haerin/종로구도서관.csv')
gwangjin= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/haerin/광진구도서관.csv')
gangbuk22= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/gangbuk.csv')
gangbuk21= pd.read_csv('gangbuk.csv')
gwanak = pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/gwanak.csv')
geumcheon= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/geumcheon.csv')
seongdong= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/sd_all.csv')
seodaemun= pd.read_csv('~/DATA_ANALYSIS/998. projects/2. git/daemawang/hanni/sdm.csv')
dobong= pd.read_csv('dobong.csv')
mapo= pd.read_csv('mapo (2).csv')
yongsan= pd.read_csv('용산구.csv')
seongbuk= pd.read_excel('성북구도서관.xlsx')
dongjak= pd.read_csv('dongjak.csv')
jungnang= pd.read_excel('Book3.xlsx')
guro= pd.read_excel('Book3.xlsx')

# %%
jongno
# Out:
#     분관명                                                강좌명   대상  \
# 0    삼청                          그림책 팝업북 만들기           ...  전연령
# 1    평창                          감각을 일 깨우는 톡톡 책놀이      ...  어린이
# 2    평창                          사고력과 표현력을 쑥쑥 키우는 책놀이  ...  어린이
# 3    청운                          독서의 달 행사 <곽재식 작가와의 만남 ...   성인
# 4    청운                          독서의 달 행사 <동화로 만나는 클레이>...  전연령
# ..   ..                                                ...  ...
# 108  청운                           동화 만들기               ...  어린이
# 109  청운                          나와 내가 만나는 시간 그림책      ...  어린이
# 110  청운                           다산처럼 읽고 연암처럼 써라      ...  전연령
# 111  국학                           우리가 모르는 북한, 그들이 모르는 남...  전연령
# 112  국학                           종로구 한책선정단 모집         ...  전연령
#
#                         강좌기간          강좌장소
# 0    2022-09-03 ~ 2022-09-03     삼청공원숲속도서관
# 1    2022-09-05 ~ 2022-09-28  꿈꾸는평창동 작은도서관
# 2    2022-09-05 ~ 2022-09-28   꿈꾸는평창동작은도서관
# ...

# %%
seoul.rename(columns={'TWO_AREA_NM': '지역', 'title':'제목','target':'대상'}, inplace=True)
seoul=seoul[['지역', '제목', '대상']]
seoul
# Out:
#        지역                                     제목   대상
# 0    동대문구                        손에 잡히는 경제인문학 여행   성인
# 1    동대문구                     북튜버 양성과정 - 나도 북튜버-   성인
# 2    동대문구                           신나는 AR/VR 세상  어린이
# 3    동대문구                      서양 고전문학이 주는 삶의 지혜   성인
# 4    동대문구                 할머니가 들려주는 이야기책 함흥차사 공연  어린이
# ..    ...                                    ...  ...
# 757  영등포구   책 읽는 영등포 '다시, 초록' 북콘서트 <타일러 라쉬> (대면)  전연령
# 758  영등포구             영등포 한 책 토론모임 (성인/비대면토론) 신청  전연령
# 759  영등포구              영등포 한 책 토론모임 (초등/현장토론) 신청  어린이
# 760  영등포구  책 읽는 영등포 '다시, 초록' 북콘서트 <타일러 라쉬> (비대면)  전연령
# 761  영등포구   책 읽는 영등포 '다시, 초록' 북콘서트 <타일러 라쉬> (대면)  전연령
#
# [762 rows x 3 columns]

# %%
nowon.rename(columns={'행사명':'제목','target':'대상'}, inplace=True)
nowon['지역']='노원구'
nowon = nowon[['지역', '제목', '대상']]
nowon
# Out:
#       지역                                          제목   대상
# 0    노원구            [2022년 하반기 성인인문학] 삶의 쉼표가 되는 옛 그림   성인
# 1    노원구  이금이 작가와의 만남 - 페르마타, 이탈리아 (Fermata, Italia)  전연령
# 2    노원구    문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 2회차   전연령
# 3    노원구                          먹고 입고 살아가는 이야기 세계사  전연령
# 4    노원구     문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 1회차  전연령
# ..   ...                                         ...  ...
# 337  노원구             1.6(수) 2,3차수령(15-18시) 안심도서대출서비스  전연령
# 338  노원구               1.5(화) 1차수령(11-14시) 안심도서대출서비스  전연령
# 339  노원구             1.5(화) 2,3차수령(15-18시) 안심도서대출서비스  전연령
# 340  노원구               1.3(일) 1차수령(11-14시) 안심도서대출서비스  전연령
# 341  노원구             1.3(일) 2,3차수령(15-18시) 안심도서대출서비스  전연령
#
# [342 rows x 3 columns]

# %%
jongno.rename(columns={'강좌명':'제목'}, inplace=True)
jongno['지역']='종로구'
jongno = jongno[['지역', '제목', '대상']]
jongno
# Out:
#       지역                                                 제목   대상
# 0    종로구                          그림책 팝업북 만들기           ...  전연령
# 1    종로구                          감각을 일 깨우는 톡톡 책놀이      ...  어린이
# 2    종로구                          사고력과 표현력을 쑥쑥 키우는 책놀이  ...  어린이
# 3    종로구                          독서의 달 행사 <곽재식 작가와의 만남 ...   성인
# 4    종로구                          독서의 달 행사 <동화로 만나는 클레이>...  전연령
# ..   ...                                                ...  ...
# 108  종로구                           동화 만들기               ...  어린이
# 109  종로구                          나와 내가 만나는 시간 그림책      ...  어린이
# 110  종로구                           다산처럼 읽고 연암처럼 써라      ...  전연령
# 111  종로구                           우리가 모르는 북한, 그들이 모르는 남...  전연령
# 112  종로구                           종로구 한책선정단 모집         ...  전연령
#
# [113 rows x 3 columns]

# %%
gwangjin.rename(columns={'강좌명':'제목'}, inplace=True)
gwangjin['지역']='광진구'
gwangjin = gwangjin[['지역', '제목', '대상']]
gwangjin
# Out:
#       지역                                                 제목   대상
# 0    광진구                  [한 주제로 함께 읽기] <책들의 부엌> 김지혜 작가 북토크  전연령
# 1    광진구                            [팹라이브러리] 장비사용안전교육(9/24)  전연령
# 2    광진구                            [팹라이브러리] 장비사용안전교육(9/17)  전연령
# 3    광진구                   [미디어창작관] 9월: OBS를 활용한 책 소개 영상 제작   성인
# 4    광진구              마지막 주 문화가 있는 수요일 < 설거지 비누 만들기> [9/28]  청소년
# ..   ...                                                ...  ...
# 339  광진구   [메이커-작업] 성인창작(3D프린터 모델링/팅커캐드) 팹라이브러리 프로그램 참가자 모집   성인
# 340  광진구  자양한강도서관 2021년 인문학프로그램 '트렌드코리아 2021, 새로운 시대를 읽다...  전연령
# 341  광진구                           [메이커-교육] 웹툰창작 성인반 참가자 모집   성인
# 342  광진구              방구석 랜선 여행 2 - 여행, 그림이 되다(ZOOM 온라인 강의)  전연령
# 343  광진구           2021년 광진정보도서관 겨울 독서교실 <기후는 변하는데 놀면 뭐하니?>  어린이
#
# [344 rows x 3 columns]

# %%
dongjak.rename(columns={'Unnamed: 2':'대상'}, inplace=True)
dongjak['지역']='동작구'
dongjak = dongjak[['지역', '제목', '대상']]
dongjak
# Out:
#      지역                            제목   대상
# 0   동작구          [솔밭공작소]도자기 공예 1차 페인팅  어린이
# 1   동작구                   그림책 탐험대(초등)  어린이
# 2   동작구                   그림책 탐험대(유아)  어린이
# 3   동작구  까망돌도서관 9월 야간특별프로그램 <별 헤는 ...  어린이
# 4   동작구        그림책 인문학(그림책으로 배우는 인문학)  어린이
# 5   동작구                       공동육아나눔터  어린이
# 6   동작구     [9월 독서의 달] 신기한 슈링클스! (유아)  어린이
# 7   동작구     [9월 독서의 달] 신기한 슈링클스! (초등)  어린이
# 8   동작구           [그림책 특성화] 이예숙 작가 특강  어린이
# 9   동작구     [9월 독서의 달] 복화술, 버블쇼! (공연)  어린이
# 10  동작구  [서경덕 교수 토크콘서트] 세계를 향한 무한도...  전연령
# 11  동작구             [성인프로그램] 건강허브 테라피   성인
# 12  동작구         [오디오북 활용프로그램] 귀를 기울이면  어린이
# 13  동작구  [까망돌 동네배움터] 반드시 성공하는 엄마표 ...   성인
# 14  동작구            그림책과 함께하는 마크라메 만들기   성인
# 15  동작구        [어린이 독서동아리] 그림책 공작소 3기  어린이
# 16  동작구                  우리역사알기(9월1일)  어린이
# 17  동작구              (초3-4학년) 맛있는 글쓰기  어린이
# 18  동작구                (초1-2) 맛있는 글쓰기  어린이
# 19  동작구                AI시대의 인문학적 글쓰기   성인
# 20  동작구                 우리역사알기(9월29일)  어린이
# ...

# %%
gwanak.rename(columns={'title':'제목','target':'대상'}, inplace=True)
gwanak['지역']='관악구'
gwanak = gwanak[['지역', '제목', '대상']]
gwanak
# Out:
#      지역                                              제목   대상
# 0   관악구                          사서와 함께 하는 별별 그림책 탐독 시간  어린이
# 1   관악구                             <종말의 아이들> 출간 기념 북토크  전연령
# 2   관악구      [봉현 X 피치마켓] 찾아가는 시니어 디지털 금융교육 (1기 , 2기 접수)   성인
# 3   관악구                     (Zoom)아주 아주 느슨한 그림책 독서모임 2기   성인
# 4   관악구                   (Zoom)우리아이 문해력을 키우는 그림책 북큐레이션   성인
# 5   관악구  독서아카데미 '일상의 쉼표, 여행' 김요한의 <MBTI, 나와 너를 이어주는 다리>  전연령
# 6   관악구      2022 도서관다문화서비스 지원사업 – 작가와의 만남 : 우리는 모두 달라요  어린이
# 7   관악구                                북아트로 고려를 알아보자go~  어린이
# 8   관악구             [현재 접수중입니다] 소소(小笑) 인문살롱 2. _ 책이는당나귀   성인
# 9   관악구               [현재 접수중입니다] 소소(小笑) 인문살롱 1. _자상한시간   성인
# 10  관악구               [현재 접수중입니다] 소소(小笑) 인문살롱 3. _ 밝은책방   성인
# 11  관악구              [현재 접수중입니다] 소소(小笑) 인문살롱 4. _ 이나영책방  전연령
# 12  관악구                           정명섭 작가와 함께하는 "도서관 1열"  청소년
# 13  관악구                초등학생을 위한 "여름방학 독서클라쓰(고학년)" 추가 모집  어린이
# ...

# %%
jungnang.rename(columns={'title':'제목','target':'대상'}, inplace=True)
jungnang['지역']='중랑구'
jungnang = jungnang[['지역', '제목', '대상']]
jungnang
# Out:
#       지역                                              제목   대상
# 0    중랑구  [양원숲] [양원]양원숲속도서관 청소년운영위원회 <어린이 독서골든벨> 안내  NEW  어린이
# 1    중랑구              [통합] [중랑] 독서의 달 프로그램 - 취향으로 채우는 일상   성인
# 2    중랑구       [통합] [중랑] 독서의 달 프로그램 - 오직 당신만을 위해, 마음을 담아  전연령
# 3    중랑구  [통합] [중랑] 독서의 달 프로그램 - (건강한 내 몸을 위한) 우리들의 요리교실  어린이
# 4    중랑구                [통합] [상봉] '그림책나래'의 책놀이 교실 참여자 모집  어린이
# ..   ...                                             ...  ...
# 301  중랑구              [통합] [양원] 2021 청소년 독서토론 주말 프로그램 안내  청소년
# 302  중랑구                      [면목] 청소년, 하브루타로 철학적 독서토론하기  청소년
# 303  중랑구         [통합] [상봉] ON(溫)택트 방학특강 ‘조물조물 동화책 요리’ 안내  어린이
# 304  중랑구                       [중랑] 2021년 미디어 리터러시 교육 안내  어린이
# 305  중랑구              [중랑] 2021년 꿈독과 함께하는 겨울방학 독서토론교실 안내  어린이
#
# [306 rows x 3 columns]

# %%
gangbuk22.rename(columns={'행사명':'제목'}, inplace=True)
gangbuk22['지역']='강북구'
gangbuk22 = gangbuk22[['지역', '제목', '대상']]
gangbuk22
# Out:
#       지역                               제목   대상
# 0    강북구       할로코드로 살펴보는 인공지능 / 초등 4~6학년  어린이
# 1    강북구      나도 할 수 있다! 일러스트레이터 / 중고생~성인  청소년
# 2    강북구  9월 상상공작소 장비활용교육(3D프린터) / 중고생~성인  청소년
# 3    강북구       9월 명화와 함께하는 3D펜 / 초등 4-6학년  어린이
# 4    강북구       9월 명화와 함께하는 3D펜 / 초등 1-3학년  어린이
# ..   ...                              ...  ...
# 243  강북구        [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 244  강북구         [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 245  강북구         [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 246  강북구         [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 247  강북구         [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [248 rows x 3 columns]

# %%
gangbuk21.rename(columns={'행사명':'제목'}, inplace=True)
gangbuk21['지역']='강북구'
gangbuk21 = gangbuk21[['지역', '제목', '대상']]
gangbuk21
# Out:
#       지역                               제목   대상
# 0    강북구       할로코드로 살펴보는 인공지능 / 초등 4~6학년  어린이
# 1    강북구      나도 할 수 있다! 일러스트레이터 / 중고생~성인  청소년
# 2    강북구  9월 상상공작소 장비활용교육(3D프린터) / 중고생~성인  청소년
# 3    강북구       9월 명화와 함께하는 3D펜 / 초등 4-6학년  어린이
# 4    강북구       9월 명화와 함께하는 3D펜 / 초등 1-3학년  어린이
# ..   ...                              ...  ...
# 243  강북구        [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 244  강북구         [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 245  강북구         [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 246  강북구         [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 247  강북구         [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [248 rows x 3 columns]

# %%
mj = pd.concat((seoul,nowon,jongno, gwangjin, dongjak, gwanak, jungnang, gangbuk21, gangbuk22)) 
# 노원 종로 광진 동작 관악 중랑

# %%
mj.to_csv('기본노원종로광진동작관악중랑강북.csv', encoding="utf-8-sig", index=False)

# %%
gangbuk_df.to_csv('강북구도서관2022.csv', encoding="utf-8-sig", index=False) 이 형식으로 해줄수있으깝쇼 ..?

# %%
pd.read_csv('서울 공공도서관 프로그램_all.csv')
# Out:
#        지역                                          제목   대상
# 0     금천구  [시흥]도서관지혜학교:전통시기 중국문인의 시,서,화에서 얻은 지혜 행사 안내  전연령
# 1     금천구                 [독산] 8월 문화가 있는날- 김해원 깊이읽기 4  어린이
# 2     금천구              [독산] 대숲소리 북콘서트Ⅳ : 여름밤 영화음악회 안내  전연령
# 3     금천구                 [독산] 7월 문화가 있는날- 김해원 깊이읽기 3   성인
# 4     금천구              [금나래]길 위의 인문학 "차이 '안'나는 클라스 진행   성인
# ...   ...                                         ...  ...
# 3131  강북구                   [삼각산]2022년 겨울 독서교실(초등5학년)  어린이
# 3132  강북구                    [삼각산]2022년 겨울독서교실(초등4학년)  어린이
# 3133  강북구                    [삼각산]2022년 겨울독서교실(초등3학년)  어린이
# 3134  강북구                    [삼각산]2022년 겨울독서교실(초등2학년)  어린이
# 3135  강북구                    [삼각산]2022년 겨울독서교실(초등1학년)  어린이
#
# [3136 rows x 3 columns]
