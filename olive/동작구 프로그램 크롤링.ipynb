# %%
서울특별시 공공도서관 (199)

# %%
강북구 gangbuk https://www.gblib.or.kr/gangbuk/event/list.do
관악구 gwanak https://lib.gwanak.go.kr/galib/menu/10028/program/30006/lectureList.do
광진구 gwangjin https://www.gwangjinlib.seoul.kr/intro.do / 프로그램 신청(준비중)...
구로구 guro https://grlib.sen.go.kr/grlib/module/teach/index.do?menu_idx=15&searchCate1=16
금천구 geumcheon https://geumcheonlib.seoul.kr/cop/bbs/selectBoardList.do?bbsId=BBSMSTR_000000000002&menuId=MNU_0000000000000018
노원구 nowon https://connect.nowonlib.kr/function_list
동작구 dongjak https://lib.dongjak.go.kr/dj/module/teach/index.do?menu_idx=32&searchCate1=16
마포구 mapo https://mplib.mapo.go.kr/mcl/MENU1069/PGM3021/lectureList.do
성동구 sd https://www.sdlib.or.kr/SD/edusat/list.do
성북구 sb https://www.sblib.seoul.kr/library/menu/10038/bbs/20001/bbsArticleList.do?currentPageNo=1&bbsArticleIdx=0
종로구 jongno https://lib.jongno.go.kr/bbs/board.php?bo_table=ReadingPgm
중랑구 jungnang https://www.jungnanglib.seoul.kr/library/index.php?g_page=community&m_page=community01

# %%
import pandas as pd
dongjak_df = pd.DataFrame(columns = ['lib','title','target'])
dongjak_df
# Out:
# Empty DataFrame
# Columns: [lib, title, target]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests

url = 'http://www.jungnanglib.seoul.kr/library/index.php?g_page=community&m_page=community01'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
jungnang = requests.get(url, headers = headers)
bs = BeautifulSoup(jungnang.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.jungnanglib.seoul.kr', port=443): Max retries exceeded with url: /library/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Input In [66], in <cell line: 6>()
#       4 url = 'http://www.jungnanglib.seoul.kr/library/index.php?g_page=community&m_page=community01'
#       5 headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# ----> 6 jungnang = requests.get(url, headers = headers)
#       7 bs = BeautifulSoup(jungnang.text, 'html.parser')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     559         raise ProxyError(e, request=request)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
# --> 563         raise SSLError(e, request=request)
#     565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='www.jungnanglib.seoul.kr', port=443): Max retries exceeded with url: /library/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
bs.select_one('#wd_print > table > tbody > tr:nth-child(1) > td.sg_t_subject > a')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.jungnanglib.seoul.kr', port=443): Max retries exceeded with url: /library/index.php?g_page=community&m_page=community01 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Input In [62], in <cell line: 6>()
#       4 url = 'https://www.jungnanglib.seoul.kr/library/index.php?g_page=community&m_page=community01'
#       5 headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# ----> 6 jn = requests.get(url, headers = headers)
#       7 bs = BeautifulSoup(jn.text, 'html.parser')
#      10 bs.select_one('#wd_print > table > tbody > tr:nth-child(1) > td.sg_t_subject > a')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:563, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     559         raise ProxyError(e, request=request)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
# --> 563         raise SSLError(e, request=request)
#     565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='www.jungnanglib.seoul.kr', port=443): Max retries exceeded with url: /library/index.php?g_page=community&m_page=community01 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))

# %%
from bs4 import BeautifulSoup
import requests


url = 'https://www.jungnanglib.seoul.kr/library/index.php?g_page=community&m_page=community01'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
dongjak = requests.get(url, headers = headers)
bs = BeautifulSoup(dongjak.text, 'html.parser')


ind=0
for j in range(1,61):
    try:
        lib = bs.select_one('#wd_print > table > tbody > tr:nth-child(1) > td.sg_t_subject > a').text
        title = bs.select_one('#contentArea > div > div.op_wrap > div > table > tbody > tr:nth-child('+str(j) +') > td.title.td3 > dl > dt > a').text
        target = bs.select_one('#contentArea > div > div.op_wrap > div > table > tbody > tr:nth-child('+str(j) +') > td.title.td3 > dl > dd:nth-child(2)').text
        dongjak_df.loc[ind] = [lib, title, target]
        ind += 1
    except:
        print(None)

dongjak_df
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Empty DataFrame
# Columns: [lib, title, target]
# Index: []

# %%
dongjak_df.target.unique().tolist()

# %%
dongjak_df.target.value_counts()

# %%
dongjak_df.to_csv('dongjak.csv')

# %%
dongjak_df

# %%
dj = pd.read_excel('Book2.xlsx')
dj.drop(columns='Unnamed: 3', inplace=True)
dj = dj.dropna()
dj.to_csv('dongjak.csv', header=1, index=0)

# %%
pd.read_csv('dongjak.csv')
# Out:
#       도서관명                            제목 Unnamed: 2
# 0     사당솔밭          [솔밭공작소]도자기 공예 1차 페인팅        어린이
# 1    대방어린이                   그림책 탐험대(초등)        어린이
# 2    대방어린이                   그림책 탐험대(유아)        어린이
# 3      까망돌  까망돌도서관 9월 야간특별프로그램 <별 헤는 ...        어린이
# 4    대방어린이        그림책 인문학(그림책으로 배우는 인문학)        어린이
# 5    대방어린이                       공동육아나눔터        어린이
# 6    대방어린이     [9월 독서의 달] 신기한 슈링클스! (유아)        어린이
# 7    대방어린이     [9월 독서의 달] 신기한 슈링클스! (초등)        어린이
# 8    대방어린이           [그림책 특성화] 이예숙 작가 특강        어린이
# 9    대방어린이     [9월 독서의 달] 복화술, 버블쇼! (공연)        어린이
# 10  구립 김영삼  [서경덕 교수 토크콘서트] 세계를 향한 무한도...        전연령
# 11  구립 김영삼             [성인프로그램] 건강허브 테라피         성인
# 12  구립 김영삼         [오디오북 활용프로그램] 귀를 기울이면        어린이
# 13     까망돌  [까망돌 동네배움터] 반드시 성공하는 엄마표 ...         성인
# 14     까망돌            그림책과 함께하는 마크라메 만들기         성인
# 15  구립 김영삼        [어린이 독서동아리] 그림책 공작소 3기        어린이
# 16    동작샘터                  우리역사알기(9월1일)        어린이
# 17   동작어린이              (초3-4학년) 맛있는 글쓰기        어린이
# 18   동작어린이                (초1-2) 맛있는 글쓰기        어린이
# 19      약수                AI시대의 인문학적 글쓰기         성인
# 20    동작샘터                 우리역사알기(9월29일)        어린이
# 21    동작샘터                 우리역사알기(9월22일)        어린이
# 22    동작샘터                 우리역사알기(9월15일)        어린이
# 23     까망돌      창의 팡팡! 3D펜&메이커융합키트 체험 안내        어린이
# 24      약수        필(必) 환경시대, 문학에서 길을 찾다.         성인
# 25    사당솔밭            [저자강연] 최은옥 작가와의 만남        어린이
# 26      약수                     수학 천재 되다?        어린이
# 27      약수           [독서의 달] 나만의 무드등 만들기        어린이
# 28    사당솔밭        [어린이 독서동아리] 솔밭 그림책 공작소        어린이
# 29      약수           [독서의 달] 김리리 작가와의 만남        어린이
# 30     까망돌         3D프린팅으로 설계하는 커스텀 도서용품         성인
# 31  구립 김영삼           허연 시인과 함께 하는 가을 북토크        전연령
# 32   동작어린이  [독서의달] 옛이야기와 함께하는 신나는 스토리...         성인
# 33   동작어린이  [독서의달] 강혜숙작가와의 만남 - 호랑이 생...        어린이
# 34     까망돌         추석맞이 비누 송편 만들기(4-6학년)        어린이
# 35     까망돌         추석맞이 비누 송편 만들기(1-3학년)        어린이
# 36     까망돌  [까망돌]프랑스 향기를 찾아서 : 프렌치 고전...        어린이
# 37  구립 김영삼              창의력아트 학부모 인성멘토교실         성인
# 38    다울작은            색다른 힐링, 컬러&그림책 테라피         성인
# 39  구립 김영삼       아이와 양육자가 함께하는 슈가클레이 만들기        어린이
# 40    동작샘터           [김민영작가] 꾸준한 글쓰기 노하우         성인
# 41    사당솔밭  [모두의인문학:학부모특강)]쓰면서 자라는 아이...         성인
# 42     까망돌       [까망돌](가족 단위)MBTI 제대로 알기        청소년
# 43  구립 김영삼          2022년 꿈다락 토요문화학교(2기)        어린이
# 44    사당솔밭  [청소년] 나만의 독립출판물 제작 함께 해요?...        청소년
# 45      약수  북스타트 <책이랑 놀래요> 3~18개월 영아 ...        어린이
# 46      약수  북스타트 프로그램 <책이랑 놀래요> 19~36...        어린이
# 47     까망돌  2022년 도서관 지혜학교 <대중음악을 통해 ...         성인
# 48    사당솔밭             [북스타트]자원활동 동아리 모집         성인
# 49    다울작은  어린이 사서체험 동아리 <꼬마 사서의 하루>(...        어린이
# 50    사당솔밭  2022 도서관 지혜학교 | 서양고전에서 배우...         성인
# 51  구립 김영삼  [성인] 신문스크랩 동아리 <알.쓸.신.모.>...         성인
# 52  구립 김영삼      2022 독서아카데미, MBTI에 길을 묻다         성인
# 53    다울작은                      다울 독서동아리         성인
# 54  구립 김영삼       구립 김영삼도서관 청소년 동아리 모집 안내        청소년
# 55     까망돌            청소년 독서토론 동아리 모집 안내        청소년
# 56     까망돌            사서와 함께하는 어린이 독서동아리        어린이
# 57    다울작은      어린이 직업체험 동아리 <꼬마 사서의 하루>        어린이
# 58   대방어린이               초등 독서동아리(꿈독) 모집        어린이
# 59   대방어린이             청소년 독서동아리(북씨앗) 모집        청소년

# %%
# Out:
#        도서관명                            제목 Unnamed: 2
# 0      사당솔밭          [솔밭공작소]도자기 공예 1차 페인팅        어린이
# 3     대방어린이                   그림책 탐험대(초등)        어린이
# 6     대방어린이                   그림책 탐험대(유아)        어린이
# 9       까망돌  까망돌도서관 9월 야간특별프로그램 <별 헤는 ...        어린이
# 12    대방어린이        그림책 인문학(그림책으로 배우는 인문학)        어린이
# 15    대방어린이                       공동육아나눔터        어린이
# 18    대방어린이     [9월 독서의 달] 신기한 슈링클스! (유아)        어린이
# 21    대방어린이     [9월 독서의 달] 신기한 슈링클스! (초등)        어린이
# 24    대방어린이           [그림책 특성화] 이예숙 작가 특강        어린이
# 27    대방어린이     [9월 독서의 달] 복화술, 버블쇼! (공연)        어린이
# 30   구립 김영삼  [서경덕 교수 토크콘서트] 세계를 향한 무한도...        전연령
# 33   구립 김영삼             [성인프로그램] 건강허브 테라피         성인
# 36   구립 김영삼         [오디오북 활용프로그램] 귀를 기울이면        어린이
# 39      까망돌  [까망돌 동네배움터] 반드시 성공하는 엄마표 ...         성인
# 42      까망돌            그림책과 함께하는 마크라메 만들기         성인
# 45   구립 김영삼        [어린이 독서동아리] 그림책 공작소 3기        어린이
# 48     동작샘터                  우리역사알기(9월1일)        어린이
# 51    동작어린이              (초3-4학년) 맛있는 글쓰기        어린이
# 54    동작어린이                (초1-2) 맛있는 글쓰기        어린이
# 57       약수                AI시대의 인문학적 글쓰기         성인
# 60     동작샘터                 우리역사알기(9월29일)        어린이
# 63     동작샘터                 우리역사알기(9월22일)        어린이
# 66     동작샘터                 우리역사알기(9월15일)        어린이
# 69      까망돌      창의 팡팡! 3D펜&메이커융합키트 체험 안내        어린이
# 72       약수        필(必) 환경시대, 문학에서 길을 찾다.         성인
# 75     사당솔밭            [저자강연] 최은옥 작가와의 만남        어린이
# 78       약수                     수학 천재 되다?        어린이
# 81       약수           [독서의 달] 나만의 무드등 만들기        어린이
# 84     사당솔밭        [어린이 독서동아리] 솔밭 그림책 공작소        어린이
# 87       약수           [독서의 달] 김리리 작가와의 만남        어린이
# 90      까망돌         3D프린팅으로 설계하는 커스텀 도서용품         성인
# 93   구립 김영삼           허연 시인과 함께 하는 가을 북토크        전연령
# 96    동작어린이  [독서의달] 옛이야기와 함께하는 신나는 스토리...         성인
# 99    동작어린이  [독서의달] 강혜숙작가와의 만남 - 호랑이 생...        어린이
# 102     까망돌         추석맞이 비누 송편 만들기(4-6학년)        어린이
# 105     까망돌         추석맞이 비누 송편 만들기(1-3학년)        어린이
# 108     까망돌  [까망돌]프랑스 향기를 찾아서 : 프렌치 고전...        어린이
# 111  구립 김영삼              창의력아트 학부모 인성멘토교실         성인
# 114    다울작은            색다른 힐링, 컬러&그림책 테라피         성인
# 117  구립 김영삼       아이와 양육자가 함께하는 슈가클레이 만들기        어린이
# 120    동작샘터           [김민영작가] 꾸준한 글쓰기 노하우         성인
# 123    사당솔밭  [모두의인문학:학부모특강)]쓰면서 자라는 아이...         성인
# 126     까망돌       [까망돌](가족 단위)MBTI 제대로 알기        청소년
# 129  구립 김영삼          2022년 꿈다락 토요문화학교(2기)        어린이
# 132    사당솔밭  [청소년] 나만의 독립출판물 제작 함께 해요?...        청소년
# 135      약수  북스타트 <책이랑 놀래요> 3~18개월 영아 ...        어린이
# 138      약수  북스타트 프로그램 <책이랑 놀래요> 19~36...        어린이
# 141     까망돌  2022년 도서관 지혜학교 <대중음악을 통해 ...         성인
# 144    사당솔밭             [북스타트]자원활동 동아리 모집         성인
# 147    다울작은  어린이 사서체험 동아리 <꼬마 사서의 하루>(...        어린이
# 150    사당솔밭  2022 도서관 지혜학교 | 서양고전에서 배우...         성인
# 153  구립 김영삼  [성인] 신문스크랩 동아리 <알.쓸.신.모.>...         성인
# 156  구립 김영삼      2022 독서아카데미, MBTI에 길을 묻다         성인
# 159    다울작은                      다울 독서동아리         성인
# 162  구립 김영삼       구립 김영삼도서관 청소년 동아리 모집 안내        청소년
# 165     까망돌            청소년 독서토론 동아리 모집 안내        청소년
# 168     까망돌            사서와 함께하는 어린이 독서동아리        어린이
# 171    다울작은      어린이 직업체험 동아리 <꼬마 사서의 하루>        어린이
# 174   대방어린이               초등 독서동아리(꿈독) 모집        어린이
# 177   대방어린이             청소년 독서동아리(북씨앗) 모집        청소년

# %%
dj
# Out:
#       도서관명                             제목 Unnamed: 2
# 0     사당솔밭           [솔밭공작소]도자기 공예 1차 페인팅        어린이
# 1      NaN  대상 : 6-7세 어린이를 포함한 가족 10팀 10명        NaN
# 2      NaN                   장소 : 3층 문화교실        NaN
# 3    대방어린이                    그림책 탐험대(초등)        어린이
# 4      NaN               대상 : 초등1~2학년 10명        NaN
# ..     ...                            ...        ...
# 175    NaN                대상 : 초등4~6학년 8명        NaN
# 176    NaN                 장소 : 온라인(zoom)        NaN
# 177  대방어린이              청소년 독서동아리(북씨앗) 모집        청소년
# 178    NaN              대상 : 중학생 1~3학년 5명        NaN
# 179    NaN                 장소 : 온라인(zoom)        NaN
#
# [180 rows x 3 columns]
