# %% [markdown]
# # 도서관 이용률

# %%
# 도서관 이용률 (성인)

import pandas as pd

df3 = pd.read_excel('./data/도서관_이용률__성인__20220816151930.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df3
# Out:
# 통계분류(2)                2019                 2021
# 통계분류(2)                 사례수 도서관 이용   비이용     사례수 도서관 이용   비이용
# 전체           소계      6000.0   23.9  76.1  6000.0   16.9  83.1
# 성별           남성      2990.0   20.4  79.6  2991.0   16.5  83.5
#              여성      3010.0   27.2  72.8  3009.0   17.2  82.8
# 연령           19~29세  1057.0   46.6  53.4  1016.0   41.2  58.8
#              30~39세  1022.0   32.8  67.2   964.0   22.3  77.7
#              40~49세  1158.0   25.1  74.9  1123.0   15.9  84.1
#              50~59세  1192.0   13.5  86.5  1173.0    8.5  91.5
#              60세 이상  1571.0    9.7  90.3  1724.0    5.9  94.1
# 학력           중졸 이하    934.0    4.2  95.8   900.0    1.2  98.8
#              고졸, 고퇴  2127.0   11.7  88.3  2136.0    7.8  92.2
#              대재 이상   2939.0   38.9  61.1  2964.0   28.2  71.8
# 연간독서량(종이책기준) 없음      2872.0    4.4  95.6  3557.0    3.0  97.0
#              1~5권    1701.0   30.8  69.2  1628.0   30.0  70.0
# ...

# %%
df3_total=df3.loc[['전체']]
df3_total
# Out:
# 통계분류(2)    2019                 2021
# 통계분류(2)     사례수 도서관 이용   비이용     사례수 도서관 이용   비이용
# 전체 소계    6000.0   23.9  76.1  6000.0   16.9  83.1

# %%
total3=pd.DataFrame({'2019':['23.9','76.1'],
                      '2021':['16.9','83.1']},
                    index=['도서관 이용','비이용'])
total3
# Out:
#         2019  2021
# 도서관 이용  23.9  16.9
# 비이용     76.1  83.1

# %%
total3 = total3.apply(pd.to_numeric)

# %%
total3.plot(kind='bar', color=['pink','green'], figsize=(10,5), alpha=0.5)
plt.title("도서관 이용률",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '도서관 이용'), Text(1, 0, '비이용')])

# %% [markdown]
# # 도서관 이용 목적

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# 도서관 이용 목적 (성인)

import pandas as pd

df1 = pd.read_excel('./data/도서관_이용_목적__성인__20220816151825.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df1
# Out:
# 통계분류(2)                2019                                           2021  \
# 통계분류(2)                 사례수 독서, 도서 대출 공부,학습 자료 조사 도서관의 행사, 프로그램 참가     사례수
# 전체           소계      1431.0      59.8  25.1  11.8              2.0  1013.0
# 성별           남성       611.0      49.7  30.1  18.2              1.5   494.0
#              여성       820.0      67.3  21.4   7.0              2.3   519.0
# 연령별          19~29세   492.0      31.5  53.8  13.3              1.4   419.0
#              30~39세   336.0      74.7  12.2  10.5              1.0   215.0
#              40~49세   291.0      75.7   8.7  11.2              2.6   179.0
#              50~59세   160.0      69.4   8.9  17.7              2.6   100.0
#              60세 이상   152.0      77.7   9.6   4.6              4.0   101.0
# 학력별          중졸 이하     39.0      65.5  10.6   8.7              0.0    11.0
#              고졸/고퇴    249.0      74.5  11.0  10.9              3.3   166.0
# ...

# %%
df1.index
# Out:
# MultiIndex([(          '전체',     '소계'),
#             (          '성별',     '남성'),
#             (          '성별',     '여성'),
#             (         '연령별', '19~29세'),
#             (         '연령별', '30~39세'),
#             (         '연령별', '40~49세'),
#             (         '연령별', '50~59세'),
#             (         '연령별', '60세 이상'),
#             (         '학력별',  '중졸 이하'),
#             (         '학력별',  '고졸/고퇴'),
#             (         '학력별',   '대재이상'),
#             ('연간독서량(종이책기준)',     '없음'),
#             ('연간독서량(종이책기준)',   '1~5권'),
#             ('연간독서량(종이책기준)',  '6~10권'),
#             ('연간독서량(종이책기준)', '11~15권'),
#             ('연간독서량(종이책기준)', '16~20권'),
#             ('연간독서량(종이책기준)', '21권 이상')],
#            )

# %%
df1.columns
# Out:
# MultiIndex([('2019',              '사례수'),
#             ('2019',        '독서, 도서 대출'),
#             ('2019',            '공부,학습'),
#             ('2019',            '자료 조사'),
#             ('2019', '도서관의 행사, 프로그램 참가'),
#             ('2021',              '사례수'),
#             ('2021',        '독서, 도서 대출'),
#             ('2021',            '공부,학습'),
#             ('2021',            '자료 조사'),
#             ('2021',          '전자자료 이용'),
#             ('2021', '도서관의 행사, 프로그램 참가')],
#            names=['통계분류(2)', '통계분류(2)'])

# %%
df1_total=df1.loc[['전체']]
df1_total
# Out:
# 통계분류(2)    2019                                           2021            \
# 통계분류(2)     사례수 독서, 도서 대출 공부,학습 자료 조사 도서관의 행사, 프로그램 참가     사례수 독서, 도서 대출
# 전체 소계    1431.0      59.8  25.1  11.8              2.0  1013.0      63.3
#
# 통계분류(2)
# 통계분류(2) 공부,학습 자료 조사 전자자료 이용 도서관의 행사, 프로그램 참가
# 전체 소계    24.8   9.0     2.5              0.2

# %%
total=pd.DataFrame({'2019':['59.8','25.1','11.8','0','2.0'],
                      '2021':['63.3','24.8','9.0','2.5','0.2']},
                    index=['독서, 도서 대출','공부,학습','자료 조사','전자자료 이용','도서관의 행사, 프로그램 참가'])
total
# Out:
#                   2019  2021
# 독서, 도서 대출         59.8  63.3
# 공부,학습             25.1  24.8
# 자료 조사             11.8   9.0
# 전자자료 이용              0   2.5
# 도서관의 행사, 프로그램 참가   2.0   0.2

# %%
total = total.apply(pd.to_numeric)

# %%
# 한글폰트 적용
import matplotlib.pyplot as plt
plt.rc("font",family="AppleGothic")

#마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus']=False

# %%
total.plot(kind='bar', color=['yellow','blue'], figsize=(10,5), alpha=0.5)
plt.title("도서관 이용 목적",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '독서, 도서 대출'),
#   Text(1, 0, '공부,학습'),
#   Text(2, 0, '자료 조사'),
#   Text(3, 0, '전자자료 이용'),
#   Text(4, 0, '도서관의 행사, 프로그램 참가')])

# %% [markdown]
# # 도서관 이용하지 않는 이유

# %%
# 도서관 이용하지 않는 이유 (성인)

import pandas as pd

df2 = pd.read_excel('./data/도서관을_이용하지_않는_이유__성인__20220816151854.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df2
# Out:
# 통계분류(2)                2019                                   \
# 통계분류(2)                 사례수 책을 읽지 않는다 일이 바빠서 갈 시간이 없다 집에서 멀다
# 전체           소계      4569.0      37.8            39.9    9.4
# 성별           남성      2378.0      34.3            44.9    7.8
#              여성      2190.0      41.5            34.5   11.2
# 연령별          19~29세   565.0      22.4            49.0    9.5
#              30~39세   686.0      20.0            60.3    7.1
#              40~49세   867.0      28.6            51.5    7.5
#              50~59세  1032.0      42.4            40.6    6.1
#              60세 이상  1419.0      54.8            18.9   14.2
# 학력별          중졸 이하    895.0      60.4            14.7   14.4
#              고졸/고퇴   1878.0      44.8            37.4    7.7
#              대재이상    1796.0      19.2            55.1    8.8
# 연간독서량(종이책기준) 없음      2747.0      59.0            28.2    5.6
#              1~5권    1177.0       6.7            58.1   14.8
# ...

# %%
df2.index
# Out:
# MultiIndex([(          '전체',     '소계'),
#             (          '성별',     '남성'),
#             (          '성별',     '여성'),
#             (         '연령별', '19~29세'),
#             (         '연령별', '30~39세'),
#             (         '연령별', '40~49세'),
#             (         '연령별', '50~59세'),
#             (         '연령별', '60세 이상'),
#             (         '학력별',  '중졸 이하'),
#             (         '학력별',  '고졸/고퇴'),
#             (         '학력별',   '대재이상'),
#             ('연간독서량(종이책기준)',     '없음'),
#             ('연간독서량(종이책기준)',   '1~5권'),
#             ('연간독서량(종이책기준)',  '6~10권'),
#             ('연간독서량(종이책기준)', '11~15권'),
#             ('연간독서량(종이책기준)', '16~20권'),
#             ('연간독서량(종이책기준)', '21권 이상')],
#            )

# %%
df2.columns
# Out:
# MultiIndex([('2019',               '사례수'),
#             ('2019',         '책을 읽지 않는다'),
#             ('2019',   '일이 바빠서 갈 시간이 없다'),
#             ('2019',            '집에서 멀다'),
#             ('2019', '읽고 싶은 책은 구입해서 읽는다'),
#             ('2019',       '읽을 만한 책이 없다'),
#             ('2021',               '사례수'),
#             ('2021',         '책을 읽지 않는다'),
#             ('2021',   '일이 바빠서 갈 시간이 없다'),
#             ('2021',            '집에서 멀다'),
#             ('2021', '읽고 싶은 책은 구입해서 읽는다'),
#             ('2021',       '읽을 만한 책이 없다')],
#            names=['통계분류(2)', '통계분류(2)'])

# %%
df2_total=df2.loc[['전체']]
df2_total
# Out:
# 통계분류(2)    2019                                                     \
# 통계분류(2)     사례수 책을 읽지 않는다 일이 바빠서 갈 시간이 없다 집에서 멀다 읽고 싶은 책은 구입해서 읽는다
# 전체 소계    4569.0      37.8            39.9    9.4               5.2
#
# 통계분류(2)                2021                                   \
# 통계분류(2) 읽을 만한 책이 없다     사례수 책을 읽지 않는다 일이 바빠서 갈 시간이 없다 집에서 멀다
# 전체 소계           2.7  4987.0      46.2            30.3   11.6
#
# 통계분류(2)
# 통계분류(2) 읽고 싶은 책은 구입해서 읽는다 읽을 만한 책이 없다
# 전체 소계                 3.5         3.3

# %%
df2 = df2.apply(pd.to_numeric)

# %%
total2=pd.DataFrame({'2019':['37.8','39.9','9.4','5.2','2.7'],
                      '2021':['46.2','30.3','11.6','3.5','3.3']},
                    index=['책을 읽지 않는다','일이 바빠서 갈 시간이 없다','집에서 멀다','읽고 싶은 책은 구입해서 읽는다','읽을 만한 책이 없다'])
total2
# Out:
#                    2019  2021
# 책을 읽지 않는다          37.8  46.2
# 일이 바빠서 갈 시간이 없다    39.9  30.3
# 집에서 멀다              9.4  11.6
# 읽고 싶은 책은 구입해서 읽는다   5.2   3.5
# 읽을 만한 책이 없다         2.7   3.3

# %%
total2 = total2.apply(pd.to_numeric)

# %%
# 한글폰트 적용
import matplotlib.pyplot as plt
plt.rc("font",family="AppleGothic")

#마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus']=False

# %%
total2.plot(kind='bar', color=['orange','pink'], figsize=(10,5), alpha=0.5)
plt.title("도서관 이용하지 않는 이유",fontsize=15)
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '책을 읽지 않는다'),
#   Text(1, 0, '일이 바빠서 갈 시간이 없다'),
#   Text(2, 0, '집에서 멀다'),
#   Text(3, 0, '읽고 싶은 책은 구입해서 읽는다'),
#   Text(4, 0, '읽을 만한 책이 없다')])

# %% [markdown]
# # 독서 활동 참여율

# %%
# 독서 활동 참여율 (성인)

import pandas as pd

df4 = pd.read_excel('./data/독서_활동_참여율__성인__20220816164215.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df4.head()
# Out:
# 통계분류(2)       2019               2021
# 통계분류(2)        사례수   참여   비참여     사례수   참여   비참여
# 전체  소계      6000.0  3.0  97.0  6000.0  1.7  98.3
# 성별  남성      2990.0  1.7  98.3  2991.0  1.3  98.7
#     여성      3010.0  4.4  95.6  3009.0  2.1  97.9
# 연령별 19~29세  1057.0  4.5  95.5  1016.0  4.3  95.7
#     30~39세  1022.0  4.5  95.5   964.0  3.5  96.5

# %%
df4_total=df4.loc[['전체']]
df4_total
# Out:
# 통계분류(2)    2019               2021
# 통계분류(2)     사례수   참여   비참여     사례수   참여   비참여
# 전체 소계    6000.0  3.0  97.0  6000.0  1.7  98.3

# %%
total4=pd.DataFrame({'2019':['3.0','97.0'],
                      '2021':['1.7','98.3']},
                    index=['참여','비참여'])
total4
# Out:
#      2019  2021
# 참여    3.0   1.7
# 비참여  97.0  98.3

# %%
total4 = total4.apply(pd.to_numeric)

# %%
total4.plot(kind='bar', color=['skyblue','violet'], figsize=(10,5), alpha=0.5)
plt.title("독서 활동 참여율",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '참여'), Text(1, 0, '비참여')])

# %% [markdown]
# # 참여해본 독서 활동

# %%
# 참여해본 독서 활동 (성인)

import pandas as pd

df5 = pd.read_excel('./data/참여해본_독서_활동__성인__20220816164257.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df5.head()
# Out:
# 통계분류(2)     2019                                      2021                    \
# 통계분류(2)      사례수  독서행사  독후활동 독서캠페인  독서교육 독서치유 기타 활동    사례수  독서행사  독후활동 독서캠페인
# 전체 소계      182.0  35.2  29.4  19.9  20.3  6.5   8.9  102.0  62.8  17.6  16.0
# 성별 남자       51.0  51.6  19.6   4.2  28.0  6.6   7.7   38.0  78.0  14.0   9.7
#    여자      131.0  28.8  33.2  26.0  17.4  6.5   9.4   64.0  53.6  19.8  19.8
# 연령 19~29세   47.0  36.6  32.5  15.1  27.8  3.6   1.4   44.0  76.5  20.7   7.8
#    30~39세   46.0  43.8  28.3  21.7  13.6  2.0  13.1   34.0  66.2   7.9  21.4
#
# 통계분류(2)
# 통계분류(2)    독서교육 독서치유 기타 활동
# 전체 소계      11.4  7.5   3.3
# 성별 남자       7.1  4.1   2.5
#    여자      14.0  9.5   3.7
# 연령 19~29세   8.4  3.6   0.0
#    30~39세   4.8  1.6   4.5

# %%
total5=pd.DataFrame({'2019':['35.2','29.4','19.9','20.3','6.5','8.9'],
                      '2021':['62.8','17.6','16.0','11.4','7.5','3.3']},
                    index=['독서행사','독후활동','독서캠페인','독서교육','독서치유','기타 활동'])
total5
# Out:
#        2019  2021
# 독서행사   35.2  62.8
# 독후활동   29.4  17.6
# 독서캠페인  19.9  16.0
# 독서교육   20.3  11.4
# 독서치유    6.5   7.5
# 기타 활동   8.9   3.3

# %%
total5 = total5.apply(pd.to_numeric)

# %%
total5.plot(kind='bar', color=['skyblue','violet'], figsize=(10,5), alpha=0.5)
plt.title("참여해본 독서 활동",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '독서행사'),
#   Text(1, 0, '독후활동'),
#   Text(2, 0, '독서캠페인'),
#   Text(3, 0, '독서교육'),
#   Text(4, 0, '독서치유'),
#   Text(5, 0, '기타 활동')])

# %% [markdown]
# # 독서 활동 참여 계기

# %%
# 독서 활동 참여 계기 (성인)

import pandas as pd

df6 = pd.read_excel('./data/독서_활동_참여_계기__성인__20220816172831.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df6.head()
# Out:
# 통계분류(2)     2019                                                      \
# 통계분류(2)      사례수 주변 사람의 권유로 알게 되어서 스스로 정보를 찾아서 직장 (학교), 단체 등에서  권장해서
# 전체 소계      182.0              26.4        29.1                  14.2
# 성별 남성       51.0              17.6        28.9                  21.5
#    여성      131.0              29.7        29.1                  11.4
# 연령 19~29세   47.0              19.3        42.4                  21.8
#    30~39세   46.0              22.5        29.4                   6.8
#
# 통계분류(2)                                                 2021  \
# 통계분류(2)   관공서, 도서관 등의 안내가 있어서 인터넷, SNS 등에 정보나 권유가 있어서    사례수
# 전체 소계                    23.5                     6.3  102.0
# 성별 남성                    31.9                     0.0   38.0
#    여성                    20.3                     8.8   64.0
# 연령 19~29세                16.5                     0.0   44.0
#    30~39세                28.1                    11.2   34.0
#
# ...

# %%
total6=pd.DataFrame({'2019':['26.4','29.1','14.2','23.5','6.3'],
                      '2021':['37.2','21.0','15.3','14.4','12.0']},
                    index=['주변 사람의 권유로 알게 되어서','스스로 정보를 찾아서','직장 (학교), 단체 등에서 권장해서','관공서, 도서관 등의 안내가 있어서','인터넷, SNS 등에 정보나 권유가 있어서'])
total6
# Out:
#                          2019  2021
# 주변 사람의 권유로 알게 되어서        26.4  37.2
# 스스로 정보를 찾아서              29.1  21.0
# 직장 (학교), 단체 등에서 권장해서     14.2  15.3
# 관공서, 도서관 등의 안내가 있어서      23.5  14.4
# 인터넷, SNS 등에 정보나 권유가 있어서   6.3  12.0

# %%
total6 = total6.apply(pd.to_numeric)

# %%
total6.plot(kind='bar', color=['skyblue','violet'], figsize=(10,5), alpha=0.5)
plt.title("독서 활동 참여 계기",fontsize=15)
plt.xticks(rotation=50)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '주변 사람의 권유로 알게 되어서'),
#   Text(1, 0, '스스로 정보를 찾아서'),
#   Text(2, 0, '직장 (학교), 단체 등에서 권장해서'),
#   Text(3, 0, '관공서, 도서관 등의 안내가 있어서'),
#   Text(4, 0, '인터넷, SNS 등에 정보나 권유가 있어서')])

# %% [markdown]
# # 독서 활동 비참여 이유

# %%
# 독서 활동 비참여 이유 (성인)

import pandas as pd

df7 = pd.read_excel('./data/독서_활동_비참여_이유__성인__20220816173419.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df7.head()
# Out:
# 통계분류(2)       2019                                                   \
# 통계분류(2)        사례수 책읽기에 관심이 없어서 참여할 만한 기회가 없어서 참여하고 싶지만 시간적 여유가 없어서
# 전체  소계      5818.0         35.2           28.1                 12.2
# 성별  남성      2939.0         34.5           28.7                 12.6
#     여성      2879.0         35.8           27.6                 11.9
# 연령별 19~29세  1010.0         19.3           33.5                 15.3
#     30~39세   976.0         21.3           34.3                 16.8
#
# 통계분류(2)                                                            2021  \
# 통계분류(2)    참여하고 싶은 프로그램이 없어서 어떤 프로그램이 있는지 알지 못해서 함께 참여할 사람이 없어서     사례수
# 전체  소계                  10.6                10.9            2.0  5898.0
# 성별  남성                  11.6                10.0            1.6  2952.0
#     여성                   9.6                11.8            2.3  2945.0
# 연령별 19~29세              16.9                12.7            1.9   972.0
# ...

# %%
total7=pd.DataFrame({'2019':['35.2','28.1','12.2','10.6','10.9','2.0'],
                      '2021':['38.4','22.7','15.0','10.8','10.6','2.4']},
                    index=['책읽기에 관심이 없어서','참여할 만한 기회가 없어서','참여하고 싶지만 시간적 여유가 없어서','참여하고 싶은 프로그램이 없어서','어떤 프로그램이 있는지 알지 못해서','함께 참여할 사람이 없어서'])
total7
# Out:
#                       2019  2021
# 책읽기에 관심이 없어서          35.2  38.4
# 참여할 만한 기회가 없어서        28.1  22.7
# 참여하고 싶지만 시간적 여유가 없어서  12.2  15.0
# 참여하고 싶은 프로그램이 없어서     10.6  10.8
# 어떤 프로그램이 있는지 알지 못해서   10.9  10.6
# 함께 참여할 사람이 없어서         2.0   2.4

# %%
total7 = total7.apply(pd.to_numeric)

# %%
total7.plot(kind='bar', color=['skyblue','violet'], figsize=(10,5), alpha=0.5)
plt.title("독서 활동 비참여 이유",fontsize=15)
plt.xticks(rotation=50)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '책읽기에 관심이 없어서'),
#   Text(1, 0, '참여할 만한 기회가 없어서'),
#   Text(2, 0, '참여하고 싶지만 시간적 여유가 없어서'),
#   Text(3, 0, '참여하고 싶은 프로그램이 없어서'),
#   Text(4, 0, '어떤 프로그램이 있는지 알지 못해서'),
#   Text(5, 0, '함께 참여할 사람이 없어서')])

# %% [markdown]
# # 참여하고 싶은 독서 활동

# %%
# 참여하고 싶은 독서 활동 (성인)

import pandas as pd

df8 = pd.read_excel('./data/참여하고_싶은_독서_활동__성인__20220816170045.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df8.head()
# Out:
# 통계분류(2)       2019                                        2021              \
# 통계분류(2)        사례수  독서행사 독서캠페인  독서치유  독서교육  독후활동 기타 활동     사례수  독서행사 독서캠페인
# 전체  소계      6000.0  27.1  27.5  34.2  21.6  15.0  16.3  6000.0  34.0  31.3
# 성별  남성      2990.0  26.1  27.8  33.4  21.0  13.7  17.9  2991.0  34.3  32.0
#     여성      3010.0  28.1  27.2  35.0  22.2  16.3  14.8  3009.0  33.7  30.5
# 연령별 19~29세  1057.0  35.6  32.4  30.7  27.3  20.7  10.8  1016.0  40.9  39.6
#     30~39세  1022.0  27.9  32.0  35.3  26.8  16.9  11.6   964.0  41.6  35.2
#
# 통계분류(2)
# 통계분류(2)     독서치유  독서교육  독후활동
# 전체  소계      31.1  23.1  20.3
# 성별  남성      28.7  23.3  20.2
#     여성      33.5  22.9  20.4
# 연령별 19~29세  31.9  25.4  24.9
#     30~39세  28.0  27.9  23.1

# %%
total8=pd.DataFrame({'2019':['27.1','27.5','34.2','21.6','15.0','16.3'],
                      '2021':['34.0','31.3','31.1','23.1','20.3','0']},
                    index=['독서행사','독서캠페인','독서치유','독서교육','독후활동','기타 활동'])
total8
# Out:
#        2019  2021
# 독서행사   27.1  34.0
# 독서캠페인  27.5  31.3
# 독서치유   34.2  31.1
# 독서교육   21.6  23.1
# 독후활동   15.0  20.3
# 기타 활동  16.3     0

# %%
total8 = total8.apply(pd.to_numeric)

# %%
total8.plot(kind='bar', color=['skyblue','violet'], figsize=(10,5), alpha=0.5)
plt.title("참여하고 싶은 독서 활동",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '독서행사'),
#   Text(1, 0, '독서캠페인'),
#   Text(2, 0, '독서치유'),
#   Text(3, 0, '독서교육'),
#   Text(4, 0, '독후활동'),
#   Text(5, 0, '기타 활동')])

# %% [markdown]
# # 독서 동아리 참여율

# %%
# 독서 동아리 참여율 (성인)

import pandas as pd

df9 = pd.read_excel('./data/독서_동아리_참여율__성인__20220816170144.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df9.head()
# Out:
# 통계분류(2)       2019               2021
# 통계분류(2)        사례수   참여   비참여     사례수   참여   비참여
# 전체  소계      6000.0  1.7  98.3  6000.0  0.9  99.1
# 성별  남성      2990.0  1.2  98.8  2991.0  0.4  99.6
#     여성      3010.0  2.2  97.8  3009.0  1.4  98.6
# 연령별 19~29세  1057.0  3.9  96.1  1016.0  2.6  97.4
#     30~39세  1022.0  1.9  98.1   964.0  1.3  98.7

# %%
total9=pd.DataFrame({'2019':['1.7','98.3'],
                      '2021':['0.9','99.1']},
                    index=['참여','비참여'])
total9
# Out:
#      2019  2021
# 참여    1.7   0.9
# 비참여  98.3  99.1

# %%
total9 = total9.apply(pd.to_numeric)

# %%
total9.plot(kind='bar', color=['yellow','orange'], figsize=(10,5), alpha=0.5)
plt.title("독서 동아리 참여율",fontsize=15)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '참여'), Text(1, 0, '비참여')])

# %% [markdown]
# # 참여해본 독서 동아리

# %%
# 참여해본 독서 동아리 (성인)

import pandas as pd

df10 = pd.read_excel('./data/참여해본_독서_동아리__성인__20220816170156.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df10.head()
# Out:
# 통계분류(2)     2019                                                     \
# 통계분류(2)      사례수 직장(또는 학교)독서 동아리 지역(동네) 독서 동아리 온라인 독서 동아리(인터넷 카페 등)
# 전체 소계      100.0            36.1          18.4                 14.2
# 성별 남성       34.0            43.9           7.5                 19.4
#    여성       65.0            31.9          24.2                 11.4
# 연령 19~29세   41.0            58.1           1.1                 19.5
#    30~39세   19.0            18.0          21.3                 27.9
#
# 통계분류(2)                                 2021                                \
# 통계분류(2)   공공도서관등 기관지원 독서 동아리 서점 독서 동아리   사례수 직장(또는 학교)독서 동아리 지역(동네) 독서 동아리
# 전체 소계                   23.3       2.9  53.0            38.3          24.5
# 성별 남성                   25.9       3.3  12.0            63.2          13.5
#    여성                   21.9       2.7  41.0            31.1          27.7
# 연령 19~29세               18.8       2.6  26.0            64.5           8.8
# ...

# %%
total10=pd.DataFrame({'2019':['36.1','18.4','14.2','0','23.3','2.9','0','0'],
                      '2021':['38.3','24.5','21.4','11.4','9.3','2.5','1.6','1.4']},
                    index=['직장(또는 학교)독서 동아리','지역(동네) 독서 동아리','온라인 독서 동아리(인터넷 카페 등)','가족 독서 동아리','공공도서관등 기관지원 독서 동아리','서점 독서 동아리','유료 독서 동아리','출판사 북클럽'])
total10
# Out:
#                       2019  2021
# 직장(또는 학교)독서 동아리       36.1  38.3
# 지역(동네) 독서 동아리         18.4  24.5
# 온라인 독서 동아리(인터넷 카페 등)  14.2  21.4
# 가족 독서 동아리                0  11.4
# 공공도서관등 기관지원 독서 동아리    23.3   9.3
# 서점 독서 동아리              2.9   2.5
# 유료 독서 동아리                0   1.6
# 출판사 북클럽                  0   1.4

# %%
total10 = total10.apply(pd.to_numeric)

# %%
total10.plot(kind='bar', color=['yellow','orange'], figsize=(10,5), alpha=0.5)
plt.title("참여해본 독서 동아리",fontsize=15)
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, '직장(또는 학교)독서 동아리'),
#   Text(1, 0, '지역(동네) 독서 동아리'),
#   Text(2, 0, '온라인 독서 동아리(인터넷 카페 등)'),
#   Text(3, 0, '가족 독서 동아리'),
#   Text(4, 0, '공공도서관등 기관지원 독서 동아리'),
#   Text(5, 0, '서점 독서 동아리'),
#   Text(6, 0, '유료 독서 동아리'),
#   Text(7, 0, '출판사 북클럽')])

# %% [markdown]
# # 독서 동아리에 참여하지 않은 이유

# %%
# 독서 동아리에 참여하지 않은 이유 (성인)

import pandas as pd

df11 = pd.read_excel('./data/독서_동아리에_참여하지_않은_이유__성인__20220816170757.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df11.head()
# Out:
# 통계분류(2)       2019                                                      \
# 통계분류(2)        사례수 책 읽기에 관심이 없어서 참여할 만한 기회가 없어서 참여하고 싶었지만 시간적 여유가  없어서
# 전체  소계      5900.0          35.1           28.6                   12.4
# 성별  남성      2955.0          35.2           27.9                   12.1
#     여성      2945.0          35.0           29.3                   12.7
# 연령별 19~29세  1016.0          21.2           33.6                   13.9
#     30~39세  1003.0          19.8           32.8                   17.4
#
# 통계분류(2)                                             2021                \
# 통계분류(2)    참여하고 싶은 모임이 없어서 독서 동아리에 대한 정보를 알지 못해서     사례수 책 읽기에 관심이 없어서
# 전체  소계                13.2                   9.6  5947.0          37.8
# 성별  남성                14.6                   8.9  2979.0          36.8
#     여성                11.8                  10.2  2968.0          38.8
# 연령별 19~29세            18.0                  12.5   990.0          14.0
# ...

# %%
total11=pd.DataFrame({'2019':['35.1','28.6','12.4','13.2','9.6'],
                      '2021':['37.8','23.4','15.3','12.0','11.3']},
                    index=['책 읽기에 관심이 없어서','참여할 만한 기회가 없어서','참여하고 싶었지만 시간적 여유가 없어서','참여하고 싶은 모임이 없어서','독서 동아리에 대한 정보를 알지 못해서'])
total11
# Out:
#                        2019  2021
# 책 읽기에 관심이 없어서          35.1  37.8
# 참여할 만한 기회가 없어서         28.6  23.4
# 참여하고 싶었지만 시간적 여유가 없어서  12.4  15.3
# 참여하고 싶은 모임이 없어서        13.2  12.0
# 독서 동아리에 대한 정보를 알지 못해서   9.6  11.3

# %%
total11 = total11.apply(pd.to_numeric)

# %%
total11.plot(kind='bar', color=['yellow','orange'], figsize=(10,5), alpha=0.5)
plt.title("독서 동아리에 참여하지 않은 이유",fontsize=15)
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '책 읽기에 관심이 없어서'),
#   Text(1, 0, '참여할 만한 기회가 없어서'),
#   Text(2, 0, '참여하고 싶었지만 시간적 여유가 없어서'),
#   Text(3, 0, '참여하고 싶은 모임이 없어서'),
#   Text(4, 0, '독서 동아리에 대한 정보를 알지 못해서')])

# %% [markdown]
# # 참여 희망 독서 동아리

# %%
# 참여 희망 독서 동아리(성인)

import pandas as pd

df12 = pd.read_excel('./data/참여_희망_독서_동아리_성인__20220816170825.xlsx',
                 header =[0,1],
                 index_col=[0,1],
                )

df12.head()
# Out:
# 통계분류(2)      2019                                                \
# 통계분류(2)       사례수 지역(동네)독서동아리 공공도서관등 기관에서 지원하는 독서동아리 온라인 독서 동아리
# 전체 소계      6000.0        48.4                   19.6       22.7
# 성별 남성      2990.0        44.0                   21.8       21.9
#    여성      3010.0        52.9                   17.4       23.5
# 연령 19~29세  1057.0        25.6                   38.4       24.3
#    30~39세  1022.0        38.6                   31.5       26.0
#
# 통계분류(2)                                2021              \
# 통계분류(2)   직장(또는학교) 독서 동아리 서점 독서 동아리     사례수 지역(동네)독서동아리
# 전체 소계                13.5       6.6  6000.0        47.8
# 성별 남성                16.2       6.7  2991.0        43.8
#    여성                10.8       6.4  3009.0        51.9
# 연령 19~29세            27.6       9.6  1016.0        28.4
#    30~39세            17.5       9.1   964.0        35.6
#
# 통계분류(2)                                                                        \
# ...

# %%
total12=pd.DataFrame({'2019':['48.4','19.6','22.7','13.5','6.6','0','0'],
                      '2021':['47.8','29.3','16.9','13.7','10.4','6.9','2.9']},
                    index=['지역(동네)독서동아리','공공도서관등 기관에서 지원하는 독서동아리','온라인 독서 동아리','직장(또는학교) 독서 동아리','서점 독서 동아리','출판사 북클럽','유료 독서동아리'])
total12
# Out:
#                         2019  2021
# 지역(동네)독서동아리             48.4  47.8
# 공공도서관등 기관에서 지원하는 독서동아리  19.6  29.3
# 온라인 독서 동아리              22.7  16.9
# 직장(또는학교) 독서 동아리         13.5  13.7
# 서점 독서 동아리                6.6  10.4
# 출판사 북클럽                    0   6.9
# 유료 독서동아리                   0   2.9

# %%
total12 = total12.apply(pd.to_numeric)

# %%
total12.plot(kind='bar', color=['yellow','orange'], figsize=(10,5), alpha=0.5)
plt.title("참여 희망 독서 동아리",fontsize=15)
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, '지역(동네)독서동아리'),
#   Text(1, 0, '공공도서관등 기관에서 지원하는 독서동아리'),
#   Text(2, 0, '온라인 독서 동아리'),
#   Text(3, 0, '직장(또는학교) 독서 동아리'),
#   Text(4, 0, '서점 독서 동아리'),
#   Text(5, 0, '출판사 북클럽'),
#   Text(6, 0, '유료 독서동아리')])
