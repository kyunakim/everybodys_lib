# %% [markdown]
# ## 도서관 컬럼정보

# %% [markdown]
# # 도서관 현황

# %%
import pandas as pd

df2 = pd.read_excel('./data/도서관 정보_컬럼정의서.xlsx',
                )

df2
# Out:
#     순서               컬럼영문명     컬럼한글명    데이터타입    길이 PK여부 NOT NULL여부
# 0    1            LBRRY_CD     도서관코드      int     1    Y          Y
# 1    2            LBRRY_NM      도서관명  varchar   100    N          N
# 2    3          LBRRY_ADDR     도서관주소  varchar   100    N          N
# 3    4            LBRRY_LA     도서관위도  varchar    10    N          N
# 4    5            LBRRY_LO     도서관경도  varchar    11    N          N
# 5    6         ONE_AREA_NM      1지역명  varchar    45    N          N
# 6    7         TWO_AREA_NM      2지역명  varchar    45    N          N
# 7    8            LBRRY_NO     도서관번호  varchar    10    N          N
# 8    9        API_LBRRY_NO  API도서관번호  varchar    10    N          N
# 9   10               TELNO      전화번호  varchar    14    N          N
# 10  11                FXNO      팩스번호  varchar    14    N          N
# 11  12          HMPG_VALUE     홈페이지값  varchar   100    N          N
# 12  13          OPNNG_TIME      개관시간  varchar  1000    N          N
# ...

# %%
df2['컬럼영문명'].tolist()
# Out:
# ['LBRRY_CD',
#  'LBRRY_NM',
#  'LBRRY_ADDR',
#  'LBRRY_LA',
#  'LBRRY_LO',
#  'ONE_AREA_NM',
#  'TWO_AREA_NM',
#  'LBRRY_NO',
#  'API_LBRRY_NO',
#  'TELNO',
#  'FXNO',
#  'HMPG_VALUE',
#  'OPNNG_TIME',
#  'CLOSEDON_DC',
#  'LBRRY_TY_CD',
#  'LBRRY_TY_NM',
#  'FOND_MBY_VALUE',
#  'OPNNG_YEAR',
#  'ZIP',
#  'X_CORT_VLUE',
#  'Y_CORT_VLUE',
#  'MUMM_LON_YEAR',
#  'BSNS_PARTCPTN_YEAR',
#  'MASTR_LBRRY_CD',
#  'LBRRY_NCM_NM',
#  'ETC_LBRRY_CD',
#  'AREA_CD',
#  'ETC_LBRRY_ADDR',
#  'ETC_LBRRY_NM',
#  'TWO_ETC_LBRRY_NM',
#  'REPRSNT_YN',
#  'ONE_AREA_CD',
#  'TWO_AREA_CD',
#  'WETHER_ARCD']

# %%
df2['컬럼한글명'].tolist()
# Out:
# ['도서관코드',
#  '도서관명',
#  '도서관주소',
#  '도서관위도',
#  '도서관경도',
#  '1지역명',
#  '2지역명',
#  '도서관번호',
#  'API도서관번호',
#  '전화번호',
#  '팩스번호',
#  '홈페이지값',
#  '개관시간',
#  '휴관일설명',
#  '도서관유형코드',
#  '도서관유형명',
#  '설립주체값',
#  '개관년도',
#  '우편번호',
#  'X좌표값',
#  'Y좌표값',
#  '최소대출년도',
#  '사업참여년도',
#  '마스터도서관코드',
#  '도서관별칭명',
#  '기타도서관코드',
#  '지역코드',
#  '기타도서관주소',
#  '기타도서관명',
#  '2기타도서관명',
#  '대표여부',
#  '1지역코드',
#  '2지역코드',
#  '날씨지역코드']

# %%
import pandas as pd

df = pd.read_csv('./data/NL_CD_LIBRARY_202206.csv'
                )

df.head()
# Out:
#    LBRRY_CD      LBRRY_NM                LBRRY_ADDR   LBRRY_LA    LBRRY_LO  \
# 0      1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376
# 1      1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534
# 2      1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456
# 3      1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302
# 4      1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170
#
#   ONE_AREA_NM TWO_AREA_NM  LBRRY_NO  API_LBRRY_NO         TELNO  ...  \
# 0         경기도         포천시  141333.0      141333.0  031-538-3911  ...
# 1         경기도         포천시  141172.0      141172.0  031-538-3952  ...
# 2         경기도         포천시  141094.0      141094.0  031-538-3932  ...
# 3         경기도         포천시  141102.0      141102.0  031-538-3945  ...
# 4         경기도         포천시  141520.0      141520.0  031-538-3972  ...
#
#   LBRRY_NCM_NM ETC_LBRRY_CD AREA_CD         ETC_LBRRY_ADDR  ETC_LBRRY_NM  \
# ...

# %%
df.columns = ['도서관코드',
 '도서관명',
 '도서관주소',
 '도서관위도',
 '도서관경도',
 '1지역명',
 '2지역명',
 '도서관번호',
 'API도서관번호',
 '전화번호',
 '팩스번호',
 '홈페이지값',
 '개관시간',
 '휴관일설명',
 '도서관유형코드',
 '도서관유형명',
 '설립주체값',
 '개관년도',
 '우편번호',
 'X좌표값',
 'Y좌표값',
 '최소대출년도',
 '사업참여년도',
 '마스터도서관코드',
 '도서관별칭명',
 '기타도서관코드',
 '지역코드',
 '기타도서관주소',
 '기타도서관명',
 '2기타도서관명',
 '대표여부',
 '1지역코드',
 '2지역코드',
 '날씨지역코드']

# %%
df.head()
# Out:
#    도서관코드          도서관명                     도서관주소      도서관위도       도서관경도 1지역명  \
# 0   1500     포천시립중앙도서관  경기도 포천시 신북면 중앙로207번길 26   37.905303  127.206376  경기도
# 1   1501     포천시립소흘도서관    경기도 포천시 소흘읍 송우로 101-29  37.829605  127.137534  경기도
# 2   1502     포천시립일동도서관      경기도 포천시 일동면 화동로 1021  37.954936  127.315456  경기도
# 3   1503  포천시립영중꿈나무도서관       경기도 포천시 영중면 양문로 151  38.005629  127.245302  경기도
# 4   1504     포천시립영북도서관        경기도 포천시 영북면 운천안길 3  38.087682  127.274170  경기도
#
#   2지역명     도서관번호  API도서관번호          전화번호  ... 도서관별칭명 기타도서관코드 지역코드  \
# 0  포천시  141333.0  141333.0  031-538-3911  ...     중앙      MA    7
# 1  포천시  141172.0  141172.0  031-538-3952  ...     소흘      MB    7
# 2  포천시  141094.0  141094.0  031-538-3932  ...     일동      MC    7
# 3  포천시  141102.0  141102.0  031-538-3945  ...     영중      MD    7
# 4  포천시  141520.0  141520.0  031-538-3972  ...     영북      ME    7
#
#                  기타도서관주소        기타도서관명    2기타도서관명 대표여부 1지역코드 2지역코드 날씨지역코드
# ...

# %%
df['1지역명'].value_counts()
# Out:
# 경기도        367
# 서울특별시      312
# 경상북도       104
# 경상남도        94
# 충청남도        72
# 전라북도        58
# 대구광역시       57
# 전라남도        52
# 부산광역시       46
# 강원도         45
# 충청북도        37
# 울산광역시       35
# 인천광역시       33
# 대전광역시       26
# 광주광역시       22
# 세종특별자치시     16
# 제주특별자치도     15
# Name: 1지역명, dtype: int64

# %%
gyeonggi = df[df['1지역명']=='경기도']

# %%
seoul = df[df['1지역명']=='서울특별시']

# %%
gyeongbuk = df[df['1지역명']=='경상북도']

# %%
gyeongnam = df[df['1지역명']=='경상남도']

# %%
chungbuk = df[df['1지역명']=='충청북도']

# %%
chungnam = df[df['1지역명']=='충청남도']

# %%
junbuk = df[df['1지역명']=='전라북도']

# %%
junnam = df[df['1지역명']=='전라남도']

# %%
daegue = df[df['1지역명']=='대구광역시']

# %%
pusan = df[df['1지역명']=='부산광역시']

# %%
gangwon = df[df['1지역명']=='강원도']

# %%
ulsan = df[df['1지역명']=='울산광역시']

# %%
incheon = df[df['1지역명']=='인천광역시']

# %%
daejeon = df[df['1지역명']=='대전광역시']

# %%
gwangju = df[df['1지역명']=='광주광역시']

# %%
sejong = df[df['1지역명']=='세종특별자치시']

# %%
jeju = df[df['1지역명']=='제주특별자치도']
