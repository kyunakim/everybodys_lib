# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 노원 중앙

# %%
import pandas as pd
nowon_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon_df
# Out:
# Empty DataFrame
# Columns: [행사명, 대상, 행사일시]
# Index: []

# %%
from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,3): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=1&lib=&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-26&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon_df
# Out:
#                                                   행사명           대상  \
# 0                    [2022년 하반기 성인인문학] 삶의 쉼표가 되는 옛 그림  대상 : 청소년 이상
# 1          이금이 작가와의 만남 - 페르마타, 이탈리아 (Fermata, Italia)  대상 : 청소년 이상
# 2            문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 2회차      대상 : 누구나
# 3                                  먹고 입고 살아가는 이야기 세계사  대상 : 청소년 이상
# 4             문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 1회차     대상 : 누구나
# 5                                          너와 나의 메타버스  대상 : 청소년 이상
# 6   [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제3회 오늘, 다시 마주한 우리...      대상 : 성인
# 7   [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제2회 경계를 넘어 : 과학과 예술    대상 : 14세이상
# 8        [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제1회 보편적인 청춘의 문장      대상 : 성인
# 9                애덤 스미스 국부론(노원정보도서관 성인인문학 경제고전 함께 읽기)   대상 : 전체이용자
# 10         [도.도.야][개관기념] 개관 15주년 행사 "그래도, 도서관은 계속된다!"   대상 : 전체이용자
# 11                  [도.도.야][개관기념] "별이 빛나는 밤에" 반 고흐 전시   대상 : 전체이용자
# 12                     1.17(일) 1차수령(11-14시) 안심도서대출서비스   대상 : 전체이용자
# ...

# %%
nowon_df['대상'] = nowon_df['대상'].str.replace('대상 : ', '')
nowon_df['행사일시'] = nowon_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon_df
# Out:
#                                                   행사명      대상  \
# 0                    [2022년 하반기 성인인문학] 삶의 쉼표가 되는 옛 그림  청소년 이상
# 1          이금이 작가와의 만남 - 페르마타, 이탈리아 (Fermata, Italia)  청소년 이상
# 2            문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 2회차      누구나
# 3                                  먹고 입고 살아가는 이야기 세계사  청소년 이상
# 4             문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 1회차     누구나
# 5                                          너와 나의 메타버스  청소년 이상
# 6   [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제3회 오늘, 다시 마주한 우리...      성인
# 7   [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제2회 경계를 넘어 : 과학과 예술    14세이상
# 8        [인문학북콘서트] <인지하지 못했던 사사로운 것들> 제1회 보편적인 청춘의 문장      성인
# 9                애덤 스미스 국부론(노원정보도서관 성인인문학 경제고전 함께 읽기)   전체이용자
# 10         [도.도.야][개관기념] 개관 15주년 행사 "그래도, 도서관은 계속된다!"   전체이용자
# 11                  [도.도.야][개관기념] "별이 빛나는 밤에" 반 고흐 전시   전체이용자
# 12                     1.17(일) 1차수령(11-14시) 안심도서대출서비스   전체이용자
# 13                   1.17(일) 2,3차수령(15-18시) 안심도서대출서비스   전체이용자
# ...

# %% [markdown]
# # 상계도서관

# %%
import pandas as pd
nowon1_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon1_df

from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,4): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=2&lib=2&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-26&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon1 = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon1.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon1_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon1_df

nowon1_df['대상'] = nowon1_df['대상'].str.replace('대상 : ', '')
nowon1_df['행사일시'] = nowon1_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon1_df
# Out:
#                                                  행사명           대상  \
# 0                           어르신들을 위한 스마트폰, 키오스크 활용교육          어르신
# 1                      (류한수 교수와 함께 하는)우크라이나-러시아 역사전쟁       청소년 이상
# 2                                 [7월] 애들아, 도서관에서 놀자  초등학교 4~6학년
# 3                       [5월 상주작가 미니북토크] 도서관과 작가가 만나면           성인
# 4                                        [5월]야호! 책놀이       유아6~7세
# 5                                [5월] 상주작가 유혜율 특별소개전          누구나
# 6                     [4월] 도서관주간행사 <제1회 도서관 마스코트 선거>           초등
# 7                나를 찾아줘 <상계도서관 개관10주년 & 도서관 주간 특별미션>          누구나
# 8               [3월] 상계도서관 개관 10주년 기념 축하 메세지 보내기 이벤트          누구나
# 9                              [2월] 우와!한상상 그림책 원화 전시          누구나
# 10                              [1월] 상계Library 사진 전시          누구나
# 11               [12월] 우와!한 상상 공간 개선 기념 행사(행사 시간 변경)       어린이 이상
# 12              [11월] 4차 북큐레이션 일상의 발견 : 김호연 작가 강연 안내           성인
# ...

# %% [markdown]
# # 월계도서관

# %%
    
import pandas as pd
nowon2_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon2_df

from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,6): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=3&lib=3&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-27&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon2 = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon2.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon2_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon2_df

nowon2_df['대상'] = nowon2_df['대상'].str.replace('대상 : ', '')
nowon2_df['행사일시'] = nowon2_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon2_df
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#                                             행사명          대상  \
# 0                          [9월] 월계도서관 자원봉사 사전교육  중고등학생 및 성인
# 1   [2022 노원구 한 책 읽기] 채경화살롱 #1. 영화 <남매의 여름밤> GV         누구나
# 2                        (어르신을 위한) 처음 만나는 언택트시대         어르신
# 3                          [8월] 월계도서관 자원봉사 사전교육  중고등학생 및 성인
# 4        「순례주택」 온라인 독서퀴즈대회(with 연세대학교 도서관희망원정대)         누구나
# ..                                          ...         ...
# 63            1.6(수) 2,3차수령(15-18시) 안심도서대출서비스           누구나
# 64               1.5(화) 1차수령(11-14시) 안심도서대출서비스          누구나
# 65             1.5(화) 2,3차수령(15-18시) 안심도서대출서비스          누구나
# 66               1.3(일) 1차수령(11-14시) 안심도서대출서비스          누구나
# 67             1.3(일) 2,3차수령(15-18시) 안심도서대출서비스          누구나
#
#                        행사일시
# 0   2022.09.06 ~ 2022.09.06
# ...

# %% [markdown]
# # 노원구어린이도서관

# %%
import pandas as pd
nowon3_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon3_df

from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,7): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=4&lib=4&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-27&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon3 = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon3.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon3_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon3_df

nowon3_df['대상'] = nowon3_df['대상'].str.replace('대상 : ', '')
nowon3_df['행사일시'] = nowon3_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon3_df
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#                                                   행사명   대상  \
# 0             부모에게도 교육이 필요한 시대!_[4강] 아이를 변화시키는 부모의 말!   성인
# 1   부모에게도 교육이 필요한 시대!_[3강] 부모와 자녀의 행복한 소통, 가정에서 기르...   성인
# 2     부모에게도 교육이 필요한 시대!_[2강] 부모와 아이 중 한 사람은 어른이어야 한다.   성인
# 3       부모에게도 교육이 필요한 시대!_[1강] 아이의 뇌에 어떤 스토리를 심을 것인가?   성인
# 4                                 아빠와 함께 하는 리듬톡톡 북놀이터   성인
# ..                                                ...  ...
# 72                     1.6(수) 2차수령(15-18시) 안심도서대출서비스   누구나
# 73                      1.5(화) 1차수령(11-14시) 안심도서대출서비스  누구나
# 74                      1.5(화) 2차수령(15-18시) 안심도서대출서비스  누구나
# 75                      1.3(일) 1차수령(11-14시) 안심도서대출서비스  누구나
# ...

# %% [markdown]
# # 노원 휴먼 라이브러리

# %%
import pandas as pd
nowon4_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon4_df

from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,2): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=4&lib=4&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-27&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon4 = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon4.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon4_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon4_df

nowon4_df['대상'] = nowon4_df['대상'].str.replace('대상 : ', '')
nowon4_df['행사일시'] = nowon4_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon4_df
# Out:
#                                                   행사명        대상  \
# 0             부모에게도 교육이 필요한 시대!_[4강] 아이를 변화시키는 부모의 말!        성인
# 1   부모에게도 교육이 필요한 시대!_[3강] 부모와 자녀의 행복한 소통, 가정에서 기르...        성인
# 2     부모에게도 교육이 필요한 시대!_[2강] 부모와 아이 중 한 사람은 어른이어야 한다.        성인
# 3       부모에게도 교육이 필요한 시대!_[1강] 아이의 뇌에 어떤 스토리를 심을 것인가?        성인
# 4                                 아빠와 함께 하는 리듬톡톡 북놀이터        성인
# 5                                 엄마와 함께 하는 리듬톡톡 북놀이터        성인
# 6                                     [여름방학특별]경제야 놀자!  초등 3~6학년
# 7                                          이야기가 있는 코딩  초등 4~6학년
# 8                                  [여름방학특별]책읽GO 표현하GO        초등
# 9                                      책읽GO 생각하GO_중학년  초등 3~4학년
# 10                                     책읽GO 생각하GO_고학년  초등 5~6학년
# 11                                     책읽GO 생각하GO_저학년  초등 1~2학년
# 12                                    [칠교연극놀이]아가씨와 여우      7~8세
# 13                                          도서관 펜팔 친구        초등
# ...

# %% [markdown]
# # 불암도서관

# %%
import pandas as pd
nowon5_df = pd.DataFrame(columns = ['행사명','대상','행사일시'])
nowon5_df

from bs4 import BeautifulSoup
import requests


#main_content > div > ul > li > dl > dt > a


ind = 0 #행번호


for i in range(0,7): #range안에는 페이지수, 넉넉하게 넣기 #여기는 15페이지까지 가겠네  
    
    url = 'https://connect.nowonlib.kr/function_list?tab=6&lib=6&s_auth2=a&s_auth1=&sdate=2021-01-01&edate=2022-08-27&s_auth3=&s_value=&start=' +str(i * 13)
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    nowon5 = requests.get(url, headers = headers, verify=False)
    bs = BeautifulSoup(nowon5.text, 'html.parser')
    
    for j in range(1,13):
        try:                    
            
            title = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > h3').text
            target = bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(1)').text  
            period =bs.select_one('body > div.container > div > div.tableBox.mTable.functionTable > ul > li:nth-child('+str(j) +') > a > div:nth-child(2) > ul > li:nth-child(4)').text
            nowon5_df.loc[ind] = [title, target, period]
            ind += 1
        except Exception as e:
            print(e)


nowon5_df

nowon5_df['대상'] = nowon5_df['대상'].str.replace('대상 : ', '')
nowon5_df['행사일시'] = nowon5_df['행사일시'].str.replace('프로그램 기간 : ', '')
nowon5_df
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
#                                          행사명        대상  \
# 0             [9월] 랜선 낭독회 “소리나는 독서, 소리듣는 독서”        성인
# 1                   [9월] 독서의 달 " 책 빌려가방" 만들기        유아
# 2                             [9월] 청소년 진로백서   청소년 및 성인
# 3   『마틸다』번역가가 들려주는 『봄의 방정식』이야기 - 김난령번역가와의 만남    청소년~성인
# 4                       [8월] 불암도서관 자원봉사 사전교육     중학생이상
# ..                                       ...       ...
# 75           1.6(수) 2,3차수령(15-18시) 안심도서대출서비스       누구나
# 76             1.5(화) 1차수령(11-14시) 안심도서대출서비스       누구나
# 77           1.5(화) 2,3차수령(15-18시) 안심도서대출서비스       누구나
# 78             1.3(일) 1차수령(11-14시) 안심도서대출서비스       누구나
# 79           1.3(일) 2,3차수령(15-18시) 안심도서대출서비스       누구나
#
#                        행사일시
# 0   2022.09.14 ~ 2022.09.28
# 1   2022.09.08 ~ 2022.09.08
# 2   2022.09.04 ~ 2022.09.04
# ...

# %%
nowon_df = pd.concat([nowon_df, nowon1_df, nowon2_df, nowon3_df, nowon4_df, nowon5_df], axis=0)
nowon_df
# Out:
#                                            행사명      대상  \
# 0             [2022년 하반기 성인인문학] 삶의 쉼표가 되는 옛 그림  청소년 이상
# 1   이금이 작가와의 만남 - 페르마타, 이탈리아 (Fermata, Italia)  청소년 이상
# 2     문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 2회차      누구나
# 3                           먹고 입고 살아가는 이야기 세계사  청소년 이상
# 4      문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 1회차     누구나
# ..                                         ...     ...
# 75             1.6(수) 2,3차수령(15-18시) 안심도서대출서비스     누구나
# 76               1.5(화) 1차수령(11-14시) 안심도서대출서비스     누구나
# 77             1.5(화) 2,3차수령(15-18시) 안심도서대출서비스     누구나
# 78               1.3(일) 1차수령(11-14시) 안심도서대출서비스     누구나
# 79             1.3(일) 2,3차수령(15-18시) 안심도서대출서비스     누구나
#
#                        행사일시
# 0   2022.09.15 ~ 2022.10.06
# 1   2022.06.11 ~ 2022.06.11
# 2   2022.04.30 ~ 2022.04.30
# 3   2022.04.21 ~ 2022.06.02
# 4   2022.04.02 ~ 2022.04.02
# ..                      ...
# 75  2021.01.06 ~ 2021.01.06
# 76  2021.01.05 ~ 2021.01.05
# 77  2021.01.05 ~ 2021.01.05
# ...

# %%
nowon_df.reset_index(inplace = True)

# %%
nowon_df.drop(columns ='index', axis = 1 , inplace = True)

# %%
nowon_df
# Out:
#                                             행사명      대상  \
# 0              [2022년 하반기 성인인문학] 삶의 쉼표가 되는 옛 그림  청소년 이상
# 1    이금이 작가와의 만남 - 페르마타, 이탈리아 (Fermata, Italia)  청소년 이상
# 2      문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 2회차      누구나
# 3                            먹고 입고 살아가는 이야기 세계사  청소년 이상
# 4       문화가 있는 날 인문학북콘서트 <인지하지 못했던 사사로운 것들> 1회차     누구나
# ..                                          ...     ...
# 337             1.6(수) 2,3차수령(15-18시) 안심도서대출서비스     누구나
# 338               1.5(화) 1차수령(11-14시) 안심도서대출서비스     누구나
# 339             1.5(화) 2,3차수령(15-18시) 안심도서대출서비스     누구나
# 340               1.3(일) 1차수령(11-14시) 안심도서대출서비스     누구나
# 341             1.3(일) 2,3차수령(15-18시) 안심도서대출서비스     누구나
#
#                         행사일시
# 0    2022.09.15 ~ 2022.10.06
# 1    2022.06.11 ~ 2022.06.11
# 2    2022.04.30 ~ 2022.04.30
# 3    2022.04.21 ~ 2022.06.02
# 4    2022.04.02 ~ 2022.04.02
# ..                       ...
# 337  2021.01.06 ~ 2021.01.06
# 338  2021.01.05 ~ 2021.01.05
# ...

# %%
nowon_df.to_csv('노원구도서관2022.csv', encoding="utf-8-sig", index=False)
